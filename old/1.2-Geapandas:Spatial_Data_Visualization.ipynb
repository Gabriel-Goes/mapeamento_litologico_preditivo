# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %matplotlib widget

# %%
from src.funcs_importar import importar_geometrias

# %%
proj_aerogeof = importar_geometrias('proj_aerogeof')
# Out:
# # -- Lista de camadas vetoriais disponiveis no Geopackage: ['litologia_1kk', 'litologia_250k', 'litologia_100k', 'litologia_50k', 'aflora', 'am_petro', 'proj_cprm', 'proj_aerogeof', 'socorro_250k', 'ocorr_min_cprm']

# %%
proj_aerogeof.boundary.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <AxesSubplot:>

# %%
proj_aerogeof_0m = proj_aerogeof[proj_aerogeof['ESPACAMENT'] == '0']

# %%
proj_aerogeof_500m = proj_aerogeof[proj_aerogeof['ESPACAMENT'] == '500']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7330/3161570187.py in <module>
# ----> 1 proj_aerogeof_500m = proj_aerogeof[proj_aerogeof['ESPACAMENT'] == '500']
#
# NameError: name 'proj_aerogeof' is not defined

# %%
proj_aerogeof_500m
# Out:
#      ID_PROJETO                                             TITULO  \
# 1          1100  Projeto Aerogeofísico Escudo do Rio Grande do Sul
# 4          1113       Projeto Aerogeofísico Sudeste do Mato Grosso
# 5          1068          Projeto Aerogeofísico Sudeste de Rondônia
# 6          1119           Projeto Aerogeofísicos Serra dos Apiacás
# 10         1057  Projeto Aerogeofísico Reserva Nacional do Cobr...
# ..          ...                                                ...
# 277        1018                               Serro (Área-Detalhe)
# 281        3067                Campo Alegre de Lourdes - Mortugaba
# 288        1067             Projeto Aerogeofísico Pernambuco-Piauí
# 290        1088                       Projeto Aerogeofísico Gurupi
# 295        3087  Área 18 Minas Gerais - Porto Cajueiro - São Fr...
#
#                                METODOS ALTURA_VOO  AREA_LEVAN  QUILOMETRA  \
# 1    Gamaespectrometria, Magnetometria        100   75.600,00  159.789,21
# 4    Gamaespectrometria, Magnetometria        100  100.955,49     213.390
# 5    Gamaespectrometria, Magnetometria        100      43.018   93.189,12
# 6    Gamaespectrometria, Magnetometria        100      24.693      53.551
# 10   Gamaespectrometria, Magnetometria        100    \t 24300    51688.10
# ..                                 ...        ...         ...         ...
# 277       Cintilometria, Magnetometria        150       3.700       8.050
# 281  Magnetometria, Gamaespectrometria        100       71519        None
# 288  Gamaespectrometria, Magnetometria        100      48.796  104.119,98
# 290  Gamaespectrometria, Magnetometria        100      35.881   76.754,18
# 295  Magnetometria, Gamaespectrometria        100       19479        None
#
#     DIRECAO_LV DIRECAO_LC ESPACAMENT ESPACAME_1  ID_SERIE  \
# 1          N-S        E-W        500         10      1000
# 4          N-S        E-W        500         10      1000
# 5          N-S        E-W        500         10      1000
# 6          N-S        E-W        500         10      1000
# 10        N45E       N45W        500         10      1000
# ..         ...        ...        ...        ...       ...
# 277        E-W        N-S        500          6      1000
# 281        E-W        N-S        500          5      3000
# 288        N-S        E-W        500         10      1000
# 290        N-S        E-W        500         10      1000
# 295        N-S        E-W        500         10      3000
#
#                                                  SERIE  \
# 1    Projetos conduzidos pelo Departamento Nacional...
# 4    Projetos conduzidos pelo Departamento Nacional...
# 5    Projetos conduzidos pelo Departamento Nacional...
# 6    Projetos conduzidos pelo Departamento Nacional...
# 10   Projetos conduzidos pelo Departamento Nacional...
# ..                                                 ...
# 277  Projetos conduzidos pelo Departamento Nacional...
# 281  Projetos conduzidos pelos governos estaduais e...
# 288  Projetos conduzidos pelo Departamento Nacional...
# 290  Projetos conduzidos pelo Departamento Nacional...
# 295  Projetos conduzidos pelos governos estaduais e...
#
#                                             DISPONIBIL  \
# 1    http://www.cprm.gov.br/publique/media/Como%20a...
# 4    http://www.cprm.gov.br/publique/media/Como%20a...
# 5    http://www.cprm.gov.br/publique/media/Como%20a...
# 6    http://www.cprm.gov.br/publique/media/Como%20a...
# 10   http://www.cprm.gov.br/publique/media/Como%20a...
# ..                                                 ...
# 277  http://www.cprm.gov.br/publique/media/Como%20a...
# 281                                               None
# 288  http://www.cprm.gov.br/publique/media/Como%20a...
# 290  http://www.cprm.gov.br/publique/media/Como%20a...
# 295                                               None
#
#                                           IMAGENS  SHAPE_AREA  SHAPE_LEN  \
# 1    http://gd.cprm.gov.br/geof_download/1100.rar    7.063200  10.987009
# 4    http://gd.cprm.gov.br/geof_download/1113.rar    8.515580  15.020750
# 5    http://gd.cprm.gov.br/geof_download/1068.rar    3.575730  11.067582
# 6    http://gd.cprm.gov.br/geof_download/1119.rar    2.000000   7.000000
# 10   http://gd.cprm.gov.br/geof_download/1057.zip    1.972249   9.666732
# ..                                            ...         ...        ...
# 277  http://gd.cprm.gov.br/geof_download/1018.zip    0.309746   2.407702
# 281                                          None    5.932671  14.875903
# 288  http://gd.cprm.gov.br/geof_download/1067.rar    4.000064  10.000081
# 290  http://gd.cprm.gov.br/geof_download/1088.rar    2.915734   8.905194
# 295                                          None    1.628200   7.563863
#
#                                               geometry
# 1    POLYGON ((-52.25000 -29.75050, -52.25000 -30.0...
# 4    POLYGON ((-50.75452 -14.62450, -50.75450 -15.1...
# 5    POLYGON ((-59.75051 -13.16708, -59.73385 -13.9...
# 6    POLYGON ((-58.00000 -8.04971, -58.00000 -9.045...
# 10   POLYGON ((-54.00046 0.99966, -54.00046 0.83299...
# ..                                                 ...
# 277  POLYGON ((-43.43224 -19.09458, -43.47013 -19.0...
# 281  POLYGON ((-43.35000 -9.25000, -43.35000 -9.320...
# 288  POLYGON ((-39.00035 -7.50041, -39.00035 -9.000...
# 290  POLYGON ((-45.49944 -1.26148, -45.49947 -1.415...
# 295  POLYGON ((-44.30796 -15.92306, -44.30000 -15.9...
#
# [111 rows x 17 columns]

# %%
proj_aerogeof_0m
# Out:
#     ID_PROJETO                  TITULO  \
# 14        1016  Monte Carmelo (Área I)
# 35        1040                 Talismã
#
#                                               METODOS ALTURA_VOO AREA_LEVAN  \
# 14  Cintilometria, Eletromagnetometria, Magnetometria         80        881
# 35  Cintilometria, Eletromagnetometria, Magnetometria         80       1050
#
#    QUILOMETRA DIRECAO_LV DIRECAO_LC ESPACAMENT ESPACAME_1  ID_SERIE  \
# 14      3.060       N40E          0          0        300      1000
# 35      2.650       N60W          0          0        500      1000
#
#                                                 SERIE DISPONIBIL IMAGENS  \
# 14  Projetos conduzidos pelo Departamento Nacional...       None    None
# 35  Projetos conduzidos pelo Departamento Nacional...       None    None
#
#     SHAPE_AREA  SHAPE_LEN                                           geometry
# 14    0.071680   1.071816  POLYGON ((-47.36933 -18.78380, -47.55488 -18.9...
# 35    0.098196   1.604468  POLYGON ((-49.16711 -13.01710, -49.25000 -13.1...

# %%
proj_aerogeof_0m.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <AxesSubplot:>

# %%
litologia_1kk = geometrias('litologia_1kk')

# %%
litologia_250k = geometrias('litologia_250k')
litologia_100k = geometrias('litologia_100k')
litologia_50k = geometrias('litologia_50k')

# %%
metadataframe(litologia_1kk)
# Out:
#                dType  Valores null  Valores unicos
# ID_UNIDADE     int64             0            2334
# SIGLA         object             0            2334
# HIERARQUIA    object             0              30
# NOME          object             0            2299
# AMBIENTE_T    object         30843               9
# SUB_AMBIEN    object         37895              28
# SIGLA_PAI     object         31035             380
# NOME_PAI      object         31035             380
# LEGENDA       object            13            2095
# ESCALA        object             0               1
# MAPA          object             0              45
# LITOTIPOS     object             0            1637
# RANGE         object             0             112
# IDADE_MIN      int64             0              43
# IDADE_MAX      int64             0              44
# EON_MIN       object             0               3
# EON_MAX       object             0               3
# ERA_MIN       object             0               9
# ERA_MAX       object             0              10
# SISTEMA_MI    object          1943              21
# SISTEMA_MA    object          2534              21
# EPOCA_MIN     object          1943              15
# EPOCA_MAX     object          2534              15
# SIGLAS_HIS    object         18820            1103
# SHAPE_AREA   float64             0           46705
# SHAPE_LEN    float64             0           46705
# geometry    geometry             0           46705

# %%
grafita_xistos_1kk = filtro(litologia_1kk,'Grafita xisto')
#litologia_grafitica_1kk = filtro(litologia_1kk,'graf')

# %%
dic_list_litotipos_legenda = describe_geologico(grafita_xistos_1kk)

# %%
dic_list_litotipos_legenda['lista_litotipos']
# Out:
# ['Anfibolito, Grafita xisto, Metapelito, Quartzito',
#  'Formação ferrífera bandada, Grafita xisto, Metachert, Rocha metassedimentar, Rocha metavulcânica ultramáfica, Serpentinito',
#  'Biotita-anfibólio xisto, Biotita-quartzo xisto, Filito, Grafita xisto, Mármore calcítico, Mármore dolomítico, Metatufo, Quartzo-mica xisto, Rocha calcissilicática, Xisto carbonático',
#  'Clorita xisto, Grafita xisto, Hornblenda gnaisse, Metacalcário, Muscovita quartzito, Muscovita-biotita xisto, Quartzito ferruginoso, Talco xisto',
#  'Clorita xisto, Grafita xisto, Metachert, Metadacito, Metatufo, Xisto',
#  'Biotita gnaisse, Gnaisse, Gondito, Grafita xisto, Granada gnaisse, Kinzigito, Mármore, Muscovita quartzito, Quartzito, Rocha calcissilicática, Sericita xisto, Xisto',
#  'Grafita xisto, Metachert, Muscovita quartzito, Quartzito ferruginoso, Xisto, Xisto aluminoso',
#  'Clorita xisto, Cloritito, Formação ferrífera bandada, Grafita xisto, Muscovita-biotita xisto, Piroxenito, Serpentinito, Talco xisto, Xisto magnesiano',
#  'Biotita xisto, Biotita-muscovita-quartzo xisto, Grafita xisto, Granada-biotita-muscovita-quartzo xisto, Granada-clorita xisto, Mármore, Metaconglomerado suportado por clastos, Metapsamito, Metarcóseo, Quartzito ferruginoso',
#  'Filito, Grafita xisto, Quartzo-mica xisto',
#  'Ardósia, Filito, Grafita xisto, Metarenito, Metargilito, Metassiltito, Mica xisto, Sericita xisto, Xisto',
#  'Biotita gnaisse, Clorita xisto, Grafita xisto, Metaconglomerado, Metapelito, Metarritmito, Mica xisto, Paragnaisse, Turmalinito',
#  'Biotita gnaisse, Biotita xisto, Grafita xisto, Mármore, Muscovita-biotita xisto, Rocha calcissilicática, Talco xisto',
#  'Grafita xisto, Metadiamictito, Metapelito, Quartzito ferruginoso',
#  'Formação ferrífera bandada, Grafita xisto, Mármore, Metakomatiíto, Metamáfica, Quartzito ferruginoso, Rocha calcissilicática, Xisto',
#  'Formação ferrífera bandada, Grafita xisto, Kinzigito, Metamáfica, Paragnaisse, Rocha calcissilicática, Rocha metaultramáfica',
#  'Grafita xisto, Metabasito, Metachert',
#  'Formação ferrífera bandada, Grafita xisto, Mármore, Metabasalto, Metachert, Metagabro, Metakomatiíto, Mica xisto, Rocha calcissilicática',
#  'Formação ferrífera bandada, Grafita xisto, Metabasalto, Metachert',
#  'Grafita xisto, Metabasalto, Metachert, Metamáfica, Metatufo, Muscovita quartzito, Muscovita-biotita xisto, Rocha metaultramáfica, Sericita xisto, Turmalinito',
#  'Grafita xisto, Metadiamictito, Quartzo xisto, Rocha calcissilicática',
#  'Biotita xisto, Formação ferrífera bandada, Gnaisse, Grafita xisto, Mármore, Metagrauvaca, Metamáfica, Metamarga, Metavulcanoclástica, Mica xisto, Ortoanfibolito, Paragnaisse, Rocha calcissilicática, Rocha metaultramáfica',
#  'Anfibolito, Clorita xisto, Grafita xisto, Granada-biotita xisto, Paragnaisse, Quartzito micáceo, Talco xisto, Turmalinito',
#  'Grafita xisto, Xisto aluminoso, Xisto carbonático',
#  'Biotita gnaisse, Grafita xisto, Metachert, Metarriolito, Metatufo, Xisto, Xisto aluminoso, Xisto carbonático',
#  'Grafita xisto',
#  'Chert, Clorita xisto, Grafita xisto, Metaconglomerado, Metatufo, Xisto',
#  'Dolomito, Filito, Formação ferrífera bandada, Grafita xisto, Metachert, Quartzo xisto, Xisto',
#  'Formação ferrífera bandada, Grafita xisto, Metachert, Sericita xisto']

# %%
ax = litologia_1kk.plot('HIERARQUIA')

grafita_xistos_1kk.plot(color='Red',ax=ax,legend=True, \
                legend_kwds={'loc' : 'center left', 'bbox_to_anchor':(1,0.5)})
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <AxesSubplot:>

# %% [markdown]
# ## THE PLOTTING TECHNIQUES WITH PYTHON LIBRARIES ARE NOT FULLY UNDERSTOOD TO PRODUCE MAPS WITH CARTOGRAPHIC RIGOR, HENCE THE PRODUCTION OF MAPS WILL BE EXECUTED WITH QGIS

# %% [markdown]
# ### To do so, we have to export layers that we produced to our local machine with GeoDataFrame.to_file('PATH') function.
