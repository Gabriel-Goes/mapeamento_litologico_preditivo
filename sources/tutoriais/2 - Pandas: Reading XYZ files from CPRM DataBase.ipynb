# %%
import pandas as pd
import my_funcs as f
gdb = '/home/ggrl/geodatabase/'

# %%
# Os arquivos XYZ disponibilizados pela CPRM

# %% [markdown]
# #### LEVANTAMENTO DE CÓDIGO 1105 SP-RJ

# %%
gama_cols = 'KB DATA BARO UB THB COSMICO CTB UUP ALTURA KPERC eU eTH CTEXP UTHRAZAO X Y UKRAZAO MDT THKRAZAO LIVE_TIME CTCOR KCOR THCOR UCOR HORA GPSALT LATITUDE FIDUCIAL TEMP LONGITUDE'.split(" ")

gTie_cols = 'KB DATA BARO UB THB COSMICO CTB UUP ALTURA KPERC eU eTH CTEXP UTHRAZAO X Y UKRAZAO MDT THKRAZAO LIVE_TIME CTCOR KCOR THCOR UCOR HORA GPSALT LATITUDE FIDUCIAL TEMP LONGITUDE __X __Y'.split(" ")

mag_cols = 'DATA BARO ALTURA X Y MDT HORA GPSALT LATITUDE FIDUCIAL LONGITUDE ALTURA_1 IGRF MAGBASE MAGBRU MAGCOM MAGCOR MAGIGRF MAGMIC MAGNIV'.split(" ")

# %%
gLine_1105 = pd.read_csv(gdb+'xyz/1105_XYZ/1105_GamaLine.XYZ',
                         names=gama_cols,
                         delim_whitespace=True,
                         skiprows=11,
                         usecols=["X","Y","LATITUDE","LONGITUDE",
                                  "KPERC","eU","eTH","CTCOR","MDT"])

gTie_1105 = pd.read_csv(gdb+'xyz/1105_XYZ/1105_GamaTie.XYZ',
                         names=gTie_cols,
                         delim_whitespace=True,
                         skiprows=11,
                         usecols=["X","Y","LATITUDE","LONGITUDE",
                                  "KPERC","eU","eTH","CTCOR","MDT"])

g_1105 = pd.concat([gTie_1105,gLine_1105], ignore_index=True)

# %%
# DADOS DE GAMA FLIGHT LINES AEROLEVANTAMENTO 1105
df_describe=f.descricao(gLine_1105)
# Out:
# # --- # Listagem de dados do aerolevantamento:
# Lista de atributos geofísicos = ['KPERC', 'eU', 'eTH', 'MDT', 'CTCOR']
# lista de atributos geograficos = ['LATITUDE', 'LONGITUDE']
# lista de atributos projetados = ['X', 'Y']

# %%
df_describe[0]
# Out:
#              dType  Valores Faltantes  Valores Únicos  Amostragem
# KPERC      float64               4325            6955     1169659
# eU         float64               4325            8168     1169659
# eTH        float64               4325           61336     1169659
# X          float64               4325          888292     1169659
# Y          float64               4325         1134332     1169659
# MDT        float64               4325          165213     1169659
# CTCOR      float64               4325           56613     1169659
# LATITUDE   float64               4325          851263     1169659
# LONGITUDE  float64               4325          728161     1169659

# %%
df_describe[4].T
# Out:
#            count        mean         std     min   0.1%      25%      50%  \
# KPERC  1169659.0    0.959790    0.854709  -0.500 -0.355    0.382    0.757
# eU     1169659.0    1.736779    1.092923  -0.500 -0.381    1.008    1.673
# eTH    1169659.0   19.289047   11.065808  -4.048 -0.722   12.290   18.382
# MDT    1169659.0  872.675007  408.562445  -4.100  0.000  641.520  887.680
# CTCOR  1169659.0   14.176621   10.738090 -11.575 -1.641    6.608   11.263
#
#             75%      99.5%       max
# KPERC     1.306     4.5300    14.577
# eU        2.373     5.3830    23.934
# eTH      25.207    59.1560   241.474
# MDT    1113.550  1933.6113  2751.590
# CTCOR    19.699    56.5420   246.600

# %%
# Tie Lines
df_describe = f.descricao(gTie_1105)
# Out:
# # --- # Listagem de dados do aerolevantamento:
# Lista de atributos geofísicos = ['KPERC', 'eU', 'eTH', 'MDT', 'CTCOR']
# lista de atributos geograficos = ['LATITUDE', 'LONGITUDE']
# lista de atributos projetados = ['X', 'Y']

# %%
df_describe[0] , df_describe[4].T
# Out:
# (             dType  Valores Faltantes  Valores Únicos  Amostragem
#  KPERC      float64                157            6119       72995
#  eU         float64                157            6714       72995
#  eTH        float64                157           34952       72995
#  X          float64                157           72894       72995
#  Y          float64                157           54433       72995
#  MDT        float64                157           53569       72995
#  CTCOR      float64                157           29717       72995
#  LATITUDE   float64                157           42652       72995
#  LONGITUDE  float64                157           69955       72995,
#           count        mean         std    min      0.1%       25%      50%  \
#  KPERC  72995.0    1.435259    1.202120 -0.497 -0.420006    0.5710    1.120
#  eU     72995.0    2.251975    1.260987 -4.185 -0.567030    1.3950    2.075
#  eTH    72995.0   24.108517   12.815317 -0.563  0.655970   14.9705   22.102
#  MDT    72995.0  968.736030  351.547221  0.000  0.000000  769.2200  928.200
#  CTCOR  72995.0   19.116214    9.418760 -0.692  1.761898   12.8215   17.974
#
#               75%       99.5%       max
#  KPERC     1.9860     6.30206    11.681
#  eU        2.8900     7.14703    16.681
#  eTH      30.6215    73.54442   263.870
#  MDT    1178.3500  1966.83150  2625.530
#  CTCOR    23.9865    53.95729   162.800  )

# %%
# DADOS DE GAMA LINE + TIE AEROLEVANTAMENTO 1105
g_1105.dropna(inplace=True)
descricao(g_1105)
# Out:
# # --- # Listagem de dados do aerolevantamento:
# Lista de atributos geofísicos = ['KPERC', 'eU', 'eTH', 'MDT', 'CTCOR']
# lista de atributos geograficos = ['LATITUDE', 'LONGITUDE']
# lista de atributos projetados = ['X', 'Y']
# (             dType  Valores Faltantes  Valores Únicos  Amostragem
#  KPERC      float64                  0            7305     1242654
#  eU         float64                  0            8616     1242654
#  eTH        float64                  0           62948     1242654
#  X          float64                  0          958978     1242654
#  Y          float64                  0         1185116     1242654
#  MDT        float64                  0          167518     1242654
#  CTCOR      float64                  0           57163     1242654
#  LATITUDE   float64                  0          872260     1242654
#  LONGITUDE  float64                  0          775641     1242654,
#  ['KPERC', 'eU', 'eTH', 'MDT', 'CTCOR'],
#  ['LATITUDE', 'LONGITUDE'],
#  ['X', 'Y'],
#                KPERC            eU           eTH           MDT         CTCOR
#  count  1.242654e+06  1.242654e+06  1.242654e+06  1.242654e+06  1.242654e+06
#  mean   9.877193e-01  1.767042e+00  1.957215e+01  8.783177e+02  1.446678e+01
#  std    8.860026e-01  1.110133e+00  1.123345e+01  4.060636e+02  1.072816e+01
#  min   -5.000000e-01 -4.185000e+00 -4.048000e+00 -4.100000e+00 -1.157500e+01
#  0.1%  -3.603470e-01 -3.850000e-01 -7.080000e-01  0.000000e+00 -1.606000e+00
#  25%    3.910000e-01  1.030000e+00  1.243400e+01  6.487800e+02  6.793000e+00
#  50%    7.720000e-01  1.695000e+00  1.856300e+01  8.899400e+02  1.173000e+01
#  75%    1.340000e+00  2.403000e+00  2.551100e+01  1.118090e+03  2.008000e+01
#  99.5%  4.683735e+00  5.554000e+00  6.043747e+01  1.936722e+03  5.635774e+01
#  max    1.457700e+01  2.393400e+01  2.638700e+02  2.751590e+03  2.466000e+02)

# %%
df.query('KPERC < 0')['KPERC'].count()
# Out:
# 49199

# %%
mLine_1105 = pd.read_csv(gdb+'xyz/1105_XYZ/1105_MagLine.XYZ',
                         names=mag_cols,
                         delim_whitespace=True,
                         skiprows=11,
                         usecols=["X","Y","LATITUDE","LONGITUDE",
                                  "MAGIGRF","MDT"])

mTie_1105 = pd.read_csv(gdb+'xyz/1105_XYZ/1105_MagTie.XYZ',
                         names=mag_cols,
                         delim_whitespace=True,
                         skiprows=11,
                         usecols=["X","Y","LATITUDE","LONGITUDE",
                                  "MAGIGRF","MDT"])

m_1105 = pd.concat([mLine_1105,mTie_1105], ignore_index=True)

m_1105 = m_1105.dropna(inplace=False)

# %%
descricao(mTie_1105)
# Out:
# # --- # Listagem de dados do aerolevantamento:
# Lista de atributos geofísicos = ['MDT', 'MAGIGRF']
# lista de atributos geograficos = ['LATITUDE', 'LONGITUDE']
# lista de atributos projetados = ['X', 'Y']
# (             dType  Valores Faltantes  Valores Únicos  Amostragem
#  X          float64                143          696622      705018
#  Y          float64                143          237894      705018
#  MDT        float64                143          149552      705018
#  LATITUDE   float64                143          162747      705018
#  LONGITUDE  float64                143          625468      705018
#  MAGIGRF    float64                143          312399      705018,
#  ['MDT', 'MAGIGRF'],
#  ['LATITUDE', 'LONGITUDE'],
#  ['X', 'Y'],
#                   MDT        MAGIGRF
#  count  705018.000000  705018.000000
#  mean      880.383106     -11.989520
#  std       414.364158     118.860106
#  min         9.470000   -1278.826000
#  0.1%       10.000000    -564.229589
#  25%       668.360000     -59.223000
#  50%       892.745000     -15.585500
#  75%      1127.900000      31.635750
#  99.5%    1902.600000     414.818580
#  max      2625.050000    1782.368000)

# %%
g_1105.to_csv(gdb+'geof/g_1105',index=False)
m_1105.to_csv(gdb+'geof/m_1105', index=False)

# %% [markdown]
# ### LEVANTAMENTO 1039 ANTIGO

# %%
cols_1039 = 'UTME UTMN LONG LAT MAGR THC UC KC CTC MAGB MAGC MAGD THB UB KB CTB FIDU TEMP ALTE ALTB'.split(" ")

usecols=["UTME","UTMN","LAT","LONG","KC","UC","THC","CTC","MAGR"]


geof_1039 = pd.read_csv(gdb+'xyz/1039_XYZ/spaulo_rjaneiro_sp.xyz',
                         names=cols_1039,
                         delim_whitespace=True,
                         skiprows=6,
                         usecols=usecols,
                         encoding='latin-1') # foi adicionado um novo tipo de econding diferente de UTF-8
# Out:
#            UTME       UTMN       LONG        LAT    MAGR    THC     UC  \
# 0       684002.  7335281.0 -49.190033 -24.083740 -144.49  45.56   5.05
# 1       684003.  7335381.0 -49.190048 -24.082840 -147.53  53.58   0.00
# 2       684004.  7335481.0 -49.190048 -24.081940 -144.57  52.58  14.07
# 3       684005.  7335581.0 -49.190048 -24.081039 -146.61  51.68   0.00
# 4       684006.  7335681.0 -49.190048 -24.080124 -156.65  62.20  21.64
# ...         ...        ...        ...        ...     ...    ...    ...
# 539897  329329.  7563776.0 -46.653473 -22.022064   92.53  70.13  20.86
# 539898  329426.  7563774.0 -46.652527 -22.022095  100.51  54.54  19.79
# 539899  329523.  7563771.0 -46.651596 -22.022125  100.50  74.22  19.75
# 539900  329620.  7563769.0 -46.650650 -22.022156   96.48  68.61   5.81
# 539901  329717.  7563767.0 -46.649719 -22.022186   93.46  64.39  15.35
#
#             KC      CTC
# 0        14.96   714.25
# 1        27.56   708.61
# 2        15.95   837.01
# 3        46.94   862.91
# 4        12.20   898.35
# ...        ...      ...
# 539897  245.36  2177.98
# 539898  279.66  2144.92
# 539899  236.94  2081.99
# 539900  235.28  1978.74
# 539901  244.92  2025.09
#
# [539902 rows x 9 columns]

# %%
geof_1039.dropna(inplace=True)

# %%
geof_1039.to_csv(gdb+'geof/geof_1039.csv',index=False)

# %%
geof_1039= gpd.read_file(gdb+'geof/geof_1039.csv')

# %% [markdown]
# #### LEVANTAMENTO 1089 FOLHA RIO PARAIM

# %%
gama_cols = 'X Y FIDUCIAL GPSALT BARO ALTURA MDT CTB KB UB THB UPU LIVE_TIME COS TEMP KPERC eU eth CTEXP CTCOR UCOR THCOR KCOR THKRAZAO UKRAZAO UTHRAZAO LONGITUDE LATITUDE DATA HORA'.split(" ")
 
mag_cols = 'X Y FIDUCIAL GPSALT BARO ALTURA MDT MAGBASE MAGBRU MAGCOM MAGCOR MAGNIV MAGMIC MAGIGRF IGRF LONGITUDE LATITUDE DATA HORA'.split(" ")

# %%
gLine_1089 = pd.read_csv(gdb+'xyz/1089_XYZ/XYZ/1089_GamaLine.XYZ',
                         names=gama_cols,
                         delim_whitespace=True,
                         skiprows=11,
                         usecols=["X","Y","LATITUDE","LONGITUDE",
                                  "KPERC","eU","eth","CTCOR","MDT"],
                         na_values=('*'))

gTie_1089 = pd.read_csv(gdb+'xyz/1089_XYZ/XYZ/1089_GamaTie.XYZ',
                         names=gama_cols,
                         delim_whitespace=True,
                         skiprows=11,
                         usecols=["X","Y","LATITUDE","LONGITUDE",
                                  "KPERC","eU","eth","CTCOR","MDT"],
                         na_values=('*'))
# Out:
# /root/anaconda3/envs/geologist_bot/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /root/anaconda3/envs/geologist_bot/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (0,1) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df = gLine_1089.drop(axis=0,columns=['X','Y','LATITUDE','LONGITUDE'])

datadict = pd.DataFrame(df.dtypes)
datadict["Valores Faltantes"] = df.isnull().sum()
datadict["Valores Únicos"] = df.nunique()
datadict["Contagem"] = df.count()
datadict = datadict.rename(columns = {0 : 'dType'})

print(datadict)

df_describe=df.describe(percentiles=[0.001,0.25,0.5,0.75,0.995])
df_describe.T
# Out:
#          dType  Valores Faltantes  Valores Únicos  Contagem
# MDT    float64                588           43029    635175
# KPERC  float64                588             534    635175
# eU     float64                590             872    635173
# eth    float64                588            4141    635175
# CTCOR  float64                590          171198    635173
#           count        mean         std     min       0.1%     25%     50%  \
# MDT    635175.0  508.893213   85.329824  290.64  312.14000  450.54  501.30
# KPERC  635175.0    0.520117    0.545391   -0.41   -0.12000    0.14    0.35
# eU     635173.0    1.107293    0.683094   -1.64   -0.29000    0.65    1.00
# eth    635175.0    9.470476    5.405462   -0.56    0.60000    5.79    8.40
# CTCOR  635173.0  836.493968  450.466561  -86.65   72.35128  513.82  754.03
#
#            75%      99.5%      max
# MDT     564.39   722.2900   795.55
# KPERC     0.72     2.9900     6.52
# eU        1.44     3.8800    25.50
# eth      11.99    29.2900    70.13
# CTCOR  1085.92  2424.6642  5958.82

# %%
df = gTie_1089.drop(axis=0,columns=['X','Y','LATITUDE','LONGITUDE'])

datadict = pd.DataFrame(df.dtypes)
datadict["Valores Faltantes"] = df.isnull().sum()
datadict["Valores Únicos"] = df.nunique()
datadict["Contagem"] = df.count()
datadict = datadict.rename(columns = {0 : 'dType'})

print(datadict)

df_describe=df.describe(percentiles=[0.001,0.25,0.5,0.75,0.995])
df_describe.T
# Out:
#          dType  Valores Faltantes  Valores Únicos  Contagem
# MDT    float64                 31           20628     33027
# KPERC  float64                 31             404     33027
# eU     float64                332             539     32726
# eth    float64                 31            2870     33027
# CTCOR  float64                332           29372     32726
#          count        mean         std     min       0.1%     25%      50%  \
# MDT    33027.0  509.481056   87.163062  304.35  314.92312  448.42  500.350
# KPERC  33027.0    0.547051    0.570724   -0.19   -0.11000    0.15    0.370
# eU     32726.0    1.113297    0.685322   -0.75   -0.40275    0.64    1.020
# eth    33027.0    9.884584    5.490838   -0.49    0.45052    6.07    8.900
# CTCOR  32726.0  870.196356  454.827734  -43.05   56.37525  536.21  794.305
#
#            75%      99.5%      max
# MDT     563.53   723.9975   780.98
# KPERC     0.75     2.9800     5.37
# eU        1.46     3.7000     7.27
# eth      12.64    29.5661    47.64
# CTCOR  1142.94  2402.6400  4187.34

# %%
g_1089 = pd.concat([gTie_1089,gLine_1089], ignore_index=True)

# %%
df = g_1089.drop(axis=0,columns=['X','Y','LATITUDE','LONGITUDE'])

datadict = pd.DataFrame(df.dtypes)
datadict["Valores Faltantes"] = df.isnull().sum()
datadict["Valores Únicos"] = df.nunique()
datadict["Contagem"] = df.count()
datadict = datadict.rename(columns = {0 : 'dType'})

print(datadict)

df_describe=df.describe(percentiles=[0.001,0.25,0.5,0.75,0.995])
df_describe.T
# Out:
#          dType  Valores Faltantes  Valores Únicos  Contagem
# MDT    float64                619           43219    668202
# KPERC  float64                619             540    668202
# eU     float64                922             875    667899
# eth    float64                619            4158    668202
# CTCOR  float64                922          173488    667899
#           count        mean         std     min       0.1%     25%     50%  \
# MDT    668202.0  508.922268   85.421387  290.64  312.20201  450.44  501.26
# KPERC  668202.0    0.521449    0.546701   -0.41   -0.12000    0.14    0.35
# eU     667899.0    1.107587    0.683204   -1.64   -0.29000    0.65    1.00
# eth    668202.0    9.490944    5.410454   -0.56    0.59000    5.80    8.42
# CTCOR  667899.0  838.145332  450.739608  -86.65   71.59694  514.85  755.90
#
#            75%       99.5%      max
# MDT     564.36   722.34995   795.55
# KPERC     0.73     2.99000     6.52
# eU        1.44     3.87000    25.50
# eth      12.02    29.30000    70.13
# CTCOR  1088.79  2424.13650  5958.82

# %%
g_1089 = g_1089.dropna(inplace=False)
g_1089.to_csv(gdb+'geof/g1089',index=False)

# %%
mLine_1089 = pd.read_csv(gdb+'xyz/1089_XYZ/XYZ/1089_MagLine.XYZ',
                         names=mag_cols,
                         delim_whitespace=True,
                         skiprows=11,
                         usecols=["X","Y","LATITUDE","LONGITUDE",
                                  "MAGIGRF","MDT"],
                         na_values=('*'))
# Out:
# /home/ggrl/Softwares/anaconda3/envs/mappingBot/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
mTie_1089 = pd.read_csv(gdb+'xyz/1089_XYZ/XYZ/1089_MagTie.XYZ',
                         names=mag_cols,
                         delim_whitespace=True,
                         skiprows=11,
                         usecols=["X","Y","LATITUDE","LONGITUDE",
                                  "MAGIGRF","MDT"],
                         na_values=('*'))
# Out:
# /home/ggrl/Softwares/anaconda3/envs/mappingBot/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (0,1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
m_1089 = pd.concat([mTie_1089,mLine_1089], ignore_index=True)

# %%
m_1089 = m_1089.dropna(inplace=False)
m_1089.to_csv(gdb+'geof/m1089',index=False)

# %% [markdown]
# ### LEVANTAMENTO 3022 'AREA_14'

# %%
gama_cols = 'ALTURA BARO COSMICO CTB CTCOR CTEXP DATA eTh eU FIDUCIAL GPSALT HORA KB KCOR KPERC LATITUDE LIVE_TIME LONGITUDE MDT TEMP THB THCOR THKRAZAO UB UCOR UKRAZAO UTHRAZAO UUP X X_WGS Y Y_WGS'.split(" ")

g_3022_raw = pd.read_csv(gdb+'xyz/3022_XYZ/Area_14_gama.XYZ',
                         names=gama_cols,
                         delim_whitespace=True,
                         skiprows=8,
                         usecols=["X","Y","LATITUDE","LONGITUDE",
                                  "KPERC","eU","eTh","CTCOR","MDT"],
                         encoding='latin-1')

# %% [markdown]
# ##### Este levantamento me foi disponibilizado pelo Professor Doutor Vinicius Aud Louro e provavelmente já foi pŕe tratado, por não apresentar Tie e Line separados e por não haver valores faltantes

# %%
df = g_3022_raw.drop(axis=0,columns=['X','Y','LATITUDE','LONGITUDE'])

datadict = pd.DataFrame(df.dtypes)
datadict["Valores Faltantes"] = df.isnull().sum()
datadict["Valores Únicos"] = df.nunique()
datadict["Contagem"] = df.count()
datadict = datadict.rename(columns = {0 : 'dType'})

datadict
# Out:
#          dType  Valores Faltantes  Valores Únicos  Contagem
# CTCOR  float64                  0          237255    676766
# eTh    float64                  0            1991    676766
# eU     float64                  0             575    676766
# KPERC  float64                  0            6191    676766
# MDT    float64                  0           72962    676766

# %%
df_describe=df.describe(percentiles=[0.001,0.25,0.5,0.75,0.995])
df_describe.T
# Out:
#           count        mean         std     min       0.1%     25%     50%  \
# MDT    635175.0  508.893213   85.329824  290.64  312.14000  450.54  501.30
# KPERC  635175.0    0.520117    0.545391   -0.41   -0.12000    0.14    0.35
# eU     635173.0    1.107293    0.683094   -1.64   -0.29000    0.65    1.00
# eth    635175.0    9.470476    5.405462   -0.56    0.60000    5.79    8.40
# CTCOR  635173.0  836.493968  450.466561  -86.65   72.35128  513.82  754.03
#
#            75%      99.5%      max
# MDT     564.39   722.2900   795.55
# KPERC     0.72     2.9900     6.52
# eU        1.44     3.8800    25.50
# eth      11.99    29.2900    70.13
# CTCOR  1085.92  2424.6642  5958.82

# %%
mag_cols = 'ALTURA BARO DATA FID GPSALT HORA IGRF LAT_WGS LONG_WGS MAGBASE MAGBRU MAGCOM MAGCOR MAGIGRF MAGMIC MAGNIV MDT X X_WGS Y Y_WGS'.split(" " )

m_3022_raw = pd.read_csv(gdb+'xyz/3022_XYZ/Area_14_mag.XYZ',
                         names=mag_cols,
                         delim_whitespace=True,
                         skiprows=8,
                         usecols=["X","Y","LAT_WGS","LONG_WGS",
                                  "MAGIGRF","MDT"],
                         na_values=('*'),   
                         dtype=('float'),
                         encoding='latin-1')

# %%
df = m_3022_raw

datadict = pd.DataFrame(df.dtypes)
datadict["Valores Faltantes"] = df.isna().sum()
datadict["Valores Únicos"] = df.nunique()
datadict["Contagem"] = df.count()
datadict = datadict.rename(columns = {0 : 'dType'})

datadict
# Out:
#             dType  Valores Faltantes  Valores Únicos  Contagem
# LAT_WGS   float64                  0          850671   6760982
# LONG_WGS  float64                  0         1868650   6760982
# MAGIGRF   float64                438          467041   6760544
# MDT       float64                  0           98537   6760982
# X         float64                  0         3323398   6760982
# Y         float64                  0         4572150   6760982

# %%
g_3022 = g_3022.dropna(inplace=False)
g_3022
# Out:
#          CTCOR  eTh   eU  KPERC   LATITUDE  LONGITUDE      MDT          X  \
# 0       644.27  6.9 -0.1  0.791 -21.236695 -47.054024   699.38  286856.47
# 1       577.39  6.5 -0.1  0.681 -21.237383 -47.054043   697.18  286855.49
# 2       520.33  5.9 -0.1  0.587 -21.238073 -47.054056   707.69  286855.13
# 3       494.39  5.3  0.1  0.566 -21.238763 -47.054064   721.80  286855.29
# 4       502.44  4.8  0.2  0.634 -21.239452 -47.054070   727.61  286855.66
# ...        ...  ...  ...    ...        ...        ...      ...        ...
# 676761  -21.96  0.7 -0.7  0.129 -21.069341 -44.001161  1067.13  603787.96
# 676762   10.95  1.0 -0.7  0.127 -21.069324 -44.000478  1058.53  603858.93
# 676763   19.16  1.1 -0.6  0.129 -21.069300 -43.999797  1065.43  603929.70
# 676764    1.20  0.8 -0.7  0.144 -21.069277 -43.999119  1087.47  604000.15
# 676765  -12.08  0.8 -0.8  0.150 -21.069256 -43.998441  1119.46  604070.60
#
#                  Y
# 0       7650282.76
# 1       7650206.55
# 2       7650130.13
# 3       7650053.72
# 4       7649977.42
# ...            ...
# 676761  7669863.86
# 676762  7669865.29
# 676763  7669867.51
# 676764  7669869.61
# 676765  7669871.49
#
# [676766 rows x 9 columns]

# %%
m_3022
# Out:
#            LAT_WGS   LONG_WGS  MAGIGRF      MDT          X           Y
# 0       -21.236695 -47.054024  114.455   699.38  286856.47  7650282.78
# 1       -21.236764 -47.054026  114.657   698.16  286856.37  7650275.15
# 2       -21.236833 -47.054028  114.859   697.60  286856.27  7650267.53
# 3       -21.236901 -47.054030  115.041   696.56  286856.17  7650259.90
# 4       -21.236970 -47.054032  115.213   695.89  286856.08  7650252.27
# ...            ...        ...      ...      ...        ...         ...
# 6760977 -21.069265 -43.998712   17.757  1106.07  604042.42  7669870.71
# 6760978 -21.069263 -43.998644   17.668  1108.44  604049.47  7669870.89
# 6760979 -21.069261 -43.998576   17.589  1112.29  604056.51  7669871.08
# 6760980 -21.069258 -43.998509   17.501  1115.51  604063.56  7669871.26
# 6760981 -21.069256 -43.998441   17.402  1119.46  604070.60  7669871.44
#
# [6760982 rows x 6 columns]

# %%
m_3022 = m_3022.dropna(inplace=False)
m_3022
# Out:
#            LAT_WGS   LONG_WGS  MAGIGRF      MDT          X           Y
# 0       -21.236695 -47.054024  114.455   699.38  286856.47  7650282.78
# 1       -21.236764 -47.054026  114.657   698.16  286856.37  7650275.15
# 2       -21.236833 -47.054028  114.859   697.60  286856.27  7650267.53
# 3       -21.236901 -47.054030  115.041   696.56  286856.17  7650259.90
# 4       -21.236970 -47.054032  115.213   695.89  286856.08  7650252.27
# ...            ...        ...      ...      ...        ...         ...
# 6760977 -21.069265 -43.998712   17.757  1106.07  604042.42  7669870.71
# 6760978 -21.069263 -43.998644   17.668  1108.44  604049.47  7669870.89
# 6760979 -21.069261 -43.998576   17.589  1112.29  604056.51  7669871.08
# 6760980 -21.069258 -43.998509   17.501  1115.51  604063.56  7669871.26
# 6760981 -21.069256 -43.998441   17.402  1119.46  604070.60  7669871.44
#
# [6760544 rows x 6 columns]

# %%
m_3022.to_csv(gdb+'geof/m3022.csv',index=False)
g_3022.to_csv(gdb+'geof/g3022.csv',index=False)
