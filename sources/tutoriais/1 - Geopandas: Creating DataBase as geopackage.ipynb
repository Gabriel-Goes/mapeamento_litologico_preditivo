# %% [markdown]
# ### Criando Banco de Dados Geológicos com [GeoPandas](https://geopandas.org/getting_started.html)

# %% [markdown]
# #### Importanto a biblioteca GeoPandas.

# %%
import geopandas as gpd

# %% [markdown]
# ####  Definindo um apelido de atalho para nossa base de dados local.

# %%
gdb = '/home/ggrl/geodatabase/'

# %% [markdown]
# ####  Lendo as geometrias litoestratigráficas  '.shp' e definindo a cama com um nome para cada escala.

# %%
# abrindo unidades litoestratigráficas em escala de 1 : 1.000.000 
l_1kk = gpd.read_file(gdb+'litostrat/1kk/Unidades_litoestratigráficas___1_1_000_000__2004_.shp')

l_1kk.to_file(gdb+'geodatabase.gpkg',
              driver='GPKG',
              layer='l_1kk')

# %%
# Unidades Litoestratigráficas na escala de 1 : 250.000
l_250k = gpd.read_file(gdb+'litostrat/250k/Unidades_litoestratigráficas___1_250_000.shp')

l_250k.to_file(gdb+'geodatabase.gpkg',
              driver='GPKG',
              layer='l_250k')

# %%
# Unidades Litoestratigráficas na escalada de 1 : 150.000
l_150k = gpd.read_file(gdb+'litostrat/150k/Unidades_litoestratigráficas___1_150_000.shp')

l_150k.to_file(gdb+'geodatabase.gpkg',
              driver='GPKG',
              layer='l_150k')
# Este shapefile está vazio, podendo ser um erro no download da base de dados do SGB ou apenas que não há mapas disponibilizado para esta escala.

# %%
# Unidades Litoestratigráficas na escalada de 1 : 100.000
l_100k = gpd.read_file(gdb+'litostrat/100k/Unidades_litoestratigráficas___1_100_000.shp')

l_100k.to_file(gdb+'geodatabase.gpkg',
              driver='GPKG',
              layer='l_100k')

# %%
# Unidades Litoestratigráficas na escalada de 1 : 50.000
l_50k = gpd.read_file(gdb+'litostrat/50k/Unidades_litoestratigráficas___1_50_000.shp')

l_50k.to_file(gdb+'geodatabase.gpkg',
              driver='GPKG',
              layer='l_50k')

# %% [markdown]
# #### Podemos, também, adicionar ao nosso GeoPackage geometrias outros tipos de geometria, como pontos de ocorrência mineral.

# %%
ocorr_min = gpd.read_file(gdb+'ocorr_min/Ocorrências_minerais.shp')

ocorr_min.to_file(gdb+'geodatabase.gpkg',
                  driver='GPKG',
                  layer='ocorr_min')

# %%
ocorr_min.shape
# Out:
# (34599, 33)

# %%
ocorr_min.columns
# Out:
# Index(['ID_AFLORAM', 'ORIGEM', 'METODO_GEO', 'TOPONIMIA', 'MUNICIPIO', 'UF',
#        'GEOLOGO', 'DATA_CADAS', 'TIPO_AFLOR', 'DESCRICAO', 'NUMERO_CAM',
#        'ROCHAS', 'SUREG', 'PROJETO', 'CODIGO_FOL', 'FOLHA', 'ID_OCORREN',
#        'PROVINCIA', 'STATUS_ECO', 'IMPORTANCI', 'LOCALIZACA', 'SITUACAO_M',
#        'MOTIVO_INA', 'SITUACAO_G', 'MOTIVO_I_1', 'SUBSTANCIA', 'ROCHAS_HOS',
#        'ROCHAS_ENC', 'CLASSES_UT', 'MORFOLOGIA', 'TEXTURAS', 'TIPOS_ALTE',
#        'geometry'],
#       dtype='object')

# %%
ocorr_min.set_geometry('geometry')
# Out:
#        ID_AFLORAM  ORIGEM                        METODO_GEO  \
# 0          197401  Oracle  Levantamento em mapa 1:2.500.000
# 1          192389  Oracle   Levantamento em carta 1:100.000
# 2          192375  Oracle   Levantamento em carta 1:100.000
# 3          192430  Oracle   Levantamento em carta 1:100.000
# 4          200652  Oracle   Levantamento em carta 1:100.000
# ...           ...     ...                               ...
# 34594      181780  Oracle   Levantamento em carta 1:250.000
# 34595      188582  Oracle   Levantamento em carta 1:250.000
# 34596      191887  Oracle   Levantamento em carta 1:250.000
# 34597      188405  Oracle   Levantamento em carta 1:250.000
# 34598      190320  Oracle   Levantamento em carta 1:250.000
#
#                 TOPONIMIA          MUNICIPIO  UF    GEOLOGO  DATA_CADAS  \
# 0       Benjamin Constant  Benjamin Constant  AM  A Definir  2006-11-24
# 1              Rio Traíra             Japurá  AM  A Definir  2006-11-24
# 2         Serra Esperança             Japurá  AM  A Definir  2006-11-24
# 3            Ig. Primeiro             Japurá  AM  A Definir  2006-11-24
# 4               Ig. Tatai             Japurá  AM  A Definir  2006-11-24
# ...                   ...                ...  ..        ...         ...
# 34594  Cumbe E Santa Cruz           Igarassu  PE  A Definir  2001-11-14
# 34595     Ilha do Bispo I        João Pessoa  PB  A Definir  2003-04-17
# 34596  Lagoa do Boqueirão            Caaporã  PB  A Definir  2001-11-14
# 34597   Fazenda Canabrava             Goiana  PE  A Definir  2006-11-24
# 34598          Rio Miriri          Rio Tinto  PB  A Definir  2006-11-24
#
#       TIPO_AFLOR DESCRICAO  ...  SITUACAO_G   MOTIVO_I_1 SUBSTANCIA  \
# 0           None      None  ...        None         None    Linhito
# 1           None      None  ...        None         None       Ouro
# 2           None      None  ...        None         None       Ouro
# 3           None      None  ...        None         None       Ouro
# 4           None      None  ...        None         None       Ouro
# ...          ...       ...  ...         ...          ...        ...
# 34594       None      None  ...  Inativo(a)  Exaurido(a)    Fósforo
# 34595       None      None  ...        None         None   Calcário
# 34596       None      None  ...        None         None  Diatomita
# 34597       None      None  ...        None         None   Calcário
# 34598       None      None  ...        None         None      Turfa
#
#       ROCHAS_HOS ROCHAS_ENC                           CLASSES_UT  \
# 0           None       None        Recursos minerais energéticos
# 1           None       None                        Metais nobres
# 2           None       None                        Metais nobres
# 3           None       None                        Metais nobres
# 4           None       None                        Metais nobres
# ...          ...        ...                                  ...
# 34594       None    Arenito             Insumos para agricultura
# 34595      Marga    Arenito        Rochas e minerais industriais
# 34596       None       None        Rochas e minerais industriais
# 34597       None   Andesito  Material de uso na construção civil
# 34598       None       None        Recursos minerais energéticos
#
#           MORFOLOGIA  TEXTURAS TIPOS_ALTE                    geometry
# 0               None      None       None  POINT (-70.10048 -4.38371)
# 1               None      None       None  POINT (-69.64242 -0.46648)
# 2               None      None       None  POINT (-69.55464 -0.66843)
# 3               None      None       None  POINT (-69.53437 -0.59037)
# 4               None      None       None  POINT (-69.52742 -0.86982)
# ...              ...       ...        ...                         ...
# 34594  Estratificada  Compacta       None  POINT (-34.89029 -7.86598)
# 34595  Estratificada  Compacta       None  POINT (-34.88807 -7.13681)
# 34596         Maciça  Granular       None  POINT (-34.87612 -7.48709)
# 34597  Estratificada    Maciça       None  POINT (-34.86529 -7.61820)
# 34598           None      None       None  POINT (-34.98362 -6.88375)
#
# [34599 rows x 33 columns]

# %%
ocorr_min.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
an_geoq_pre = gpd.read_file(gdb+'an_geoq/pre_2012/data.gdb')

an_geoq_pre.to_file(gdb+'geodatabase.gpkg',
                  driver='GPKG',
                  layer='an_geoq_pre')

# %%
an_geoq_pos = gpd.read_file(gdb+'an_geoq/pos_2012/data.gdb')

an_geoq_pos.to_file(gdb+'geodatabase.gpkg',
                  driver='GPKG',
                  layer='an_geoq_pos')

# %%
an_min_pos = gpd.read_file(gdb+'an_min/pos_2012/data.gdb')

an_min_pos.to_file(gdb+'geodatabase.gpkg',
                  driver='GPKG',
                  layer='an_min_pos')

# %%
an_min_pre = gpd.read_file(gdb+'an_min/pre_2012/data.gdb')

an_min_pre.to_file(gdb+'geodatabase.gpkg',
                  driver='GPKG',
                  layer='an_min_pre')

# %%
aflora = gpd.read_file(gdb+'aflora/Afloramentos_geológicos.shp')

aflora.to_file(gdb+'geodatabase.gpkg',
                  driver='GPKG',
                  layer='aflora')

# %%
am_petro = gpd.read_file(gdb+'am_petro/Amostras_petrográficas.shp')

am_petro.to_file(gdb+'geodatabase.gpkg',
                  driver='GPKG',
                  layer='am_petro')

# %%
proj_cprm = gpd.read_file(gdb+'projetos/aerogeof/Projetos_da_CPRM.shp')


proj_cprm.to_file(gdb+'geodatabase.gpkg',
                  driver='GPKG',
                  layer='proj_cprm')

# %%
proj_aerogeof = gpd.read_file(gdb+'projetos/aerogeof/Projetos_de_aerogeofísica.shp')

proj_aerogeof.to_file(gdb+'geodatabase.gpkg',
                  driver='GPKG',
                  layer='proj_aerogeof')

# %%
gdb = '/home/ggrl/geodatabase/'
def litologia(escala):
    lito =  gpd.read_file(gdb+'geodatabase.gpkg',
                        driver= 'GPKG',
                        layer= escala)
    return(lito)

# %%
l_1kk = litologia('l_1kk')

# %%
l_1kk.plot()
# Out:
# <AxesSubplot:>

# %%
l_1kk.MAPA.unique()
# Out:
# array(['Carta geológica da folha Contamana',
#        'Carta geológica da folha Javari',
#        'Carta geológica da folha Rio Branco',
#        'Carta geológica da folha Juruá', 'Carta geológica da folha Içá',
#        'Carta geológica da folha Pico da Neblina',
#        'Carta geológica da folha Guaporé',
#        'Carta geológica da folha Porto Velho',
#        'Carta geológica da folha Purus',
#        'Carta geológica da folha Manaus',
#        'Carta geológica da folha Boa Vista',
#        'Carta geológica da folha Corumbá',
#        'Carta geológica da folha Cuiabá',
#        'Carta geológica da folha Juruena',
#        'Carta geológica da folha Tapajós',
#        'Carta geológica da folha Santarém',
#        'Carta geológica da folha Tumucumaque',
#        'Carta geológica da folha Uruguaiana',
#        'Carta geológica da folha Campo Grande',
#        'Carta geológica da folha Asunción',
#        'Carta geológica da folha Lagoa Mirim',
#        'Carta geológica da folha Porto Alegre',
#        'Carta geológica da folha Curitiba',
#        'Carta geológica da folha Paranapanema',
#        'Carta geológica da folha Goiânia',
#        'Carta geológica da folha Goiás',
#        'Carta geológica da folha Tocantins',
#        'Carta geológica da folha Araguaia',
#        'Carta geológica da folha Belém',
#        'Carta geológica da folha Macapá',
#        'Carta geológica da folha Iguape',
#        'Carta geológica da folha Rio de Janeiro',
#        'Carta geológica da folha Belo Horizonte',
#        'Carta geológica da folha Brasília',
#        'Carta geológica da folha Rio São Francisco',
#        'Carta geológica da folha Teresina',
#        'Carta geológica da folha São Luis',
#        'Carta geológica da folha Vitória',
#        'Carta geológica da folha Rio Doce',
#        'Carta geológica da folha Salvador',
#        'Carta geológica da folha Aracaju',
#        'Carta geológica da folha Jaguaribe',
#        'Carta geológica da folha Fortaleza',
#        'Carta geológica da folha Recife',
#        'Carta geológica da folha Natal'], dtype=object)

# %%
def mapa(escala,nome):
    folha = escala[escala.MAPA == 'Carta geológica da folha '+nome]
    return(folha)

# %%
natal_1kk = mapa(l_1kk, 'Natal')

# %%
natal_1kk
# Out:
#        ID_UNIDADE           SIGLA    HIERARQUIA  \
# 5757         2456  NP3_gamma_3tn4         Corpo
# 5758         2427    NP3_gamma_3q         Corpo
# 5759         2342        NP23scqt    Litofácies
# 5760         2342        NP23scqt    Litofácies
# 5761          234            ENsm      Formação
# ...           ...             ...           ...
# 46710        2411  NP3_gamma_2di5         Corpo
# 46711         409            K12a      Formação
# 46712         219             ENb         Grupo
# 46713        2208             Q2l  Não definida
# 46714        1003             NQc  Não definida
#
#                                             NOME             AMBIENTE_T  \
# 5757                      Corpo Sienito Toritama                   None
# 5758                  Corpo Granitóide Queimadas                   None
# 5759   Litofácies Surubim - Caroalina, quartzito                   None
# 5760   Litofácies Surubim - Caroalina, quartzito                   None
# 5761                  Formação Serra dos Martins                   None
# ...                                          ...                    ...
# 46710               Corpo Plúton sem denominação                   None
# 46711                               Formação Açu                   None
# 46712                            Grupo Barreiras  Cobertura superficial
# 46713                       Depósitos litorâneos  Cobertura superficial
# 46714                 Depósitos colúvio-eluviais                   None
#
#                              SUB_AMBIEN      SIGLA_PAI  \
# 5757                               None  NP3_gamma_3tn
# 5758                               None  NP3_gamma_3tn
# 5759                               None         NP23sc
# 5760                               None         NP23sc
# 5761                               None           None
# ...                                 ...            ...
# 46710                              None  NP3_gamma_3di
# 46711                              None          K12ap
# 46712  Cobertura transportada(Clástica)           None
# 46713  Cobertura transportada(Clástica)           None
# 46714                              None           None
#
#                                          NOME_PAI  \
# 5757   NP3_gamma_3tn - Suíte intrusiva Terra Nova
# 5758   NP3_gamma_3tn - Suíte intrusiva Terra Nova
# 5759        NP23sc - Complexo Surubim - Caroalina
# 5760        NP23sc - Complexo Surubim - Caroalina
# 5761                                         None
# ...                                           ...
# 46710   NP3_gamma_3di - Suíte intrusiva Dona Inês
# 46711                         K12ap - Grupo Apodi
# 46712                                        None
# 46713                                        None
# 46714                                        None
#
#                                                  LEGENDA       ESCALA  ...  \
# 5757   Biotita-hornblenda sienito grosso; anfibólio-q...  1:1.000.000  ...
# 5758   Monzogranito porfirítico predominante quartzo-...  1:1.000.000  ...
# 5759   Muscovita quartzito a quartzito, gnaisses quar...  1:1.000.000  ...
# 5760   Muscovita quartzito a quartzito, gnaisses quar...  1:1.000.000  ...
# 5761   Arenitos finos a médios  conglomeráticos com n...  1:1.000.000  ...
# ...                                                  ...          ...  ...
# 46710  Biotita e/ou hornblenda granito e leucogranito...  1:1.000.000  ...
# 46711  Arenito quartzoso, arcóseo a subarcóseo de gra...  1:1.000.000  ...
# 46712  Predomínio de camadas horizontais de arenito c...  1:1.000.000  ...
# 46713  Areias quartzosas muito finas a médias, com pr...  1:1.000.000  ...
# 46714  Depósitos inconsolidados com matriz arenosa, a...  1:1.000.000  ...
#
#                ERA_MIN          ERA_MAX  SISTEMA_MI   SISTEMA_MA   EPOCA_MIN  \
# 5757   Neoproterozóico  Neoproterozóico  Ediacarano   Ediacarano  Pridoliano
# 5758   Neoproterozóico  Neoproterozóico  Ediacarano   Ediacarano  Pridoliano
# 5759   Neoproterozóico  Neoproterozóico  Ediacarano  Criogeniano  Pridoliano
# 5760   Neoproterozóico  Neoproterozóico  Ediacarano  Criogeniano  Pridoliano
# 5761         Cenozóico        Cenozóico     Neogeno    Paleogeno    Superior
# ...                ...              ...         ...          ...         ...
# 46710  Neoproterozóico  Neoproterozóico  Ediacarano   Ediacarano  Pridoliano
# 46711        Mesozóico        Mesozóico    Cretáceo     Cretáceo    Inferior
# 46712        Cenozóico        Cenozóico     Neogeno    Paleogeno    Superior
# 46713        Cenozóico        Cenozóico     Neogeno      Neogeno    Superior
# 46714        Cenozóico        Cenozóico     Neogeno      Neogeno    Superior
#
#         EPOCA_MAX      SIGLAS_HIS SHAPE_AREA SHAPE_LEN  \
# 5757   Pridoliano            None   0.001865  0.188621
# 5758   Pridoliano            None   0.001226  0.259505
# 5759   Ludlowiano  NP23scq, MNscq   0.002621  0.361828
# 5760   Ludlowiano  NP23scq, MNscq   0.003307  0.489980
# 5761        Médio             Esm   0.004974  0.927256
# ...           ...             ...        ...       ...
# 46710  Pridoliano    NP3_gamma_2n   0.001475  0.205617
# 46711    Inferior              Ka   0.000198  0.063927
# 46712       Médio            None   0.001544  0.344721
# 46713    Superior            None   0.016111  2.104951
# 46714    Superior            None   0.003880  0.363279
#
#                                                 geometry
# 5757   POLYGON ((-35.93344 -7.98077, -35.93715 -7.983...
# 5758   POLYGON ((-35.86578 -7.33875, -35.86560 -7.339...
# 5759   POLYGON ((-35.92047 -7.87995, -35.92095 -7.873...
# 5760   POLYGON ((-35.73778 -7.76898, -35.73580 -7.769...
# 5761   POLYGON ((-35.75342 -6.51227, -35.75119 -6.515...
# ...                                                  ...
# 46710  POLYGON ((-35.49911 -5.68559, -35.49694 -5.690...
# 46711  POLYGON ((-35.47999 -5.68443, -35.47936 -5.689...
# 46712  POLYGON ((-35.35470 -5.71613, -35.35892 -5.713...
# 46713  POLYGON ((-35.25426 -5.49971, -35.26418 -5.494...
# 46714  POLYGON ((-35.26487 -5.67317, -35.26047 -5.681...
#
# [394 rows x 27 columns]

# %%
socorro_250k = gpd.read_file(gdb+'litostrat/250k/socorro.shp')

# %%
socorro_250k.to_file(gdb+'geodatabase.gpkg',
                  driver='GPKG',
                  layer='socorro_250k')

# %%
socorro_250k.plot()
# Out:
# <AxesSubplot:>
