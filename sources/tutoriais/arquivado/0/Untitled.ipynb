# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import pyproj
from shapely import geometry
import matplotlib.pyplot as plt
import earthpy

# %matplotlib inline

# %%
test = pd.read_csv('../../../database/csv/interpolado/cut_d_atest.csv')

# %%
test['geometry'] = [geometry.Point(x, y) for x, y in zip(test['X'], test['Y'])]
crs = "+proj=utm +zone=21 +south +ellps=WGS84 +datum=WGS84 +units=m +no_defs"
test = gpd.GeoDataFrame(test, geometry='geometry', crs=crs)
test.head(100)
# Out:
#                 X             Y          MDT     MAGIGRF     KPERC        eU  \
# 0   305129.910666  7.608340e+06   813.000928  -77.087449  2.167981  1.245024
# 1   305631.772598  7.608340e+06   813.000928  -77.087449  2.089464  0.846822
# 2   306133.634529  7.608340e+06   839.177849  -20.013397  2.089464  0.846822
# 3   306635.496460  7.608340e+06   847.092857  -96.004227  1.794768  0.784984
# 4   307137.358392  7.608340e+06   826.688087 -140.954576  1.554663  1.397324
# ..            ...           ...          ...         ...       ...       ...
# 95  314665.287364  7.608645e+06   809.334973   69.923079  3.596374  0.479975
# 96  315167.149296  7.608645e+06   947.409437  -30.312159  2.863297  0.628615
# 97  315669.011227  7.608645e+06  1000.589740  -13.356311  3.276823  0.626802
# 98  316170.873159  7.608645e+06  1049.414866   16.924501  2.765869  1.120720
# 99  316672.735090  7.608645e+06  1148.104385  -57.469856  1.519495  0.990332
#
# ...

# %%
test.plot(figsize=(15,15))
# Out:
# <AxesSubplot:>

# %%
test.to_csv('../../../database/csv/interpolado/')
