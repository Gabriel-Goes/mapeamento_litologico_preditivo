# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import pyproj
from shapely import geometry
import matplotlib.pyplot as plt
import earthpy

# %matplotlib inline

# %%
data_caconde = gpd.read_file('../database/vectors/Estruturas.gpkg')

# %%
data_caconde.plot(figsize=(15,14))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###  Aqui podemos ver duas colunas, uma coluna 'Estrutura' com dados string descrevendo os lineamentos e uma segunda coluna 'geometry', uma tupla (x,y)

# %%
data_caconde
# Out:
#             Estrtutura                                           geometry
# 0                  LTG  MULTILINESTRING ((329425.985 7627160.154, 3303...
# 1                  LTG  MULTILINESTRING ((330217.701 7627750.392, 3306...
# 2                  LTG  MULTILINESTRING ((331142.747 7626376.925, 3318...
# 3                  LTG  MULTILINESTRING ((332918.669 7627561.580, 3321...
# 4                  LTG  MULTILINESTRING ((332651.645 7628258.810, 3327...
# 5                  LTG  MULTILINESTRING ((333039.466 7627856.154, 3341...
# 6                  LTG  MULTILINESTRING ((332175.320 7624671.979, 3324...
# 7                  LTG  MULTILINESTRING ((342964.050 7624423.736, 3424...
# 8                  LTG  MULTILINESTRING ((332388.100 7624427.676, 3323...
# 9                  LTG  MULTILINESTRING ((333775.110 7624541.947, 3343...
# 10                 LTG  MULTILINESTRING ((336099.928 7624451.319, 3370...
# 11                 LTG  MULTILINESTRING ((335430.065 7625747.700, 3370...
# ...
