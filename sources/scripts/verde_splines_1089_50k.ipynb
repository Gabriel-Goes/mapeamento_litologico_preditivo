# %%
import geopandas as gpd
import pandas as pd
import verde as vd
import numpy as np
from shapely import geometry

import pyproj


import my_funcs as mf

import matplotlib.pyplot as plt
# %matplotlib widget

gdb='/home/ggrl/geodatabase/'

# %%
grid_lista = mf.importar('malha_cartog_100k')

# %%
grid_lista
# Out:
#           id  left  top  right  bottom  \
# 0      734.0 -74.0 -6.5  -73.5    -7.0
# 1      735.0 -74.0 -7.0  -73.5    -7.5
# 2      736.0 -74.0 -7.5  -73.5    -8.0
# 3      737.0 -74.0 -8.0  -73.5    -8.5
# 4      820.0 -73.5 -5.5  -73.0    -6.0
# ...      ...   ...  ...    ...     ...
# 3051  7598.0 -35.0 -6.5  -34.5    -7.0
# 3052  7599.0 -35.0 -7.0  -34.5    -7.5
# 3053  7600.0 -35.0 -7.5  -34.5    -8.0
# 3054  7601.0 -35.0 -8.0  -34.5    -8.5
# 3055  7602.0 -35.0 -8.5  -34.5    -9.0
#
#                                                geometry
# 0     MULTIPOLYGON (((-74.00000 -6.50000, -73.50000 ...
# 1     MULTIPOLYGON (((-74.00000 -7.00000, -73.50000 ...
# 2     MULTIPOLYGON (((-74.00000 -7.50000, -73.50000 ...
# 3     MULTIPOLYGON (((-74.00000 -8.00000, -73.50000 ...
# 4     MULTIPOLYGON (((-73.50000 -5.50000, -73.00000 ...
# ...                                                 ...
# 3051  MULTIPOLYGON (((-35.00000 -6.50000, -34.50000 ...
# ...

# %%
malha_cartog_1089_50k = gpd.read_file('/home/ggrl/Desktop/1089_area_50k.shp')

# %%
malha_cartog_1089_50k
# Out:
#     field_1        id_folha                          region  \
# 0     23129  SC23_Y_B_III_4  (-45.25, -45.0, -10.5, -10.25)
# 1     23130   SC23_Y_B_VI_2  (-45.25, -45.0, -10.75, -10.5)
# 2     23131   SC23_Y_B_VI_4  (-45.25, -45.0, -11.0, -10.75)
# 3     23132  SC23_Y_D_III_2  (-45.25, -45.0, -11.25, -11.0)
# 4     23305    SC23_Z_A_I_3  (-45.0, -44.75, -10.5, -10.25)
# 5     23306   SC23_Z_A_IV_1  (-45.0, -44.75, -10.75, -10.5)
# 6     23307   SC23_Z_A_IV_3  (-45.0, -44.75, -11.0, -10.75)
# 7     23308    SC23_Z_C_I_1  (-45.0, -44.75, -11.25, -11.0)
# 8     23480    SC23_Z_A_I_2  (-44.75, -44.5, -10.25, -10.0)
# 9     23481    SC23_Z_A_I_4  (-44.75, -44.5, -10.5, -10.25)
# 10    23482   SC23_Z_A_IV_2  (-44.75, -44.5, -10.75, -10.5)
# 11    23483   SC23_Z_A_IV_4  (-44.75, -44.5, -11.0, -10.75)
# 12    23655    SC23_X_C_V_3   (-44.5, -44.25, -10.0, -9.75)
# 13    23656   SC23_Z_A_II_1  (-44.5, -44.25, -10.25, -10.0)
# 14    23657   SC23_Z_A_II_3  (-44.5, -44.25, -10.5, -10.25)
# ...

# %%
# malha_cartog_1089_50k.drop(['field_1','region'],axis=1,inplace=True)

# %%
bounds = malha_cartog_1089_50k.bounds

# %%
df_regions = pd.DataFrame(bounds)

# %%
df = pd.DataFrame(malha_cartog_1089_50k)

# %%
df_regions.head()
# Out:
#     minx   miny   maxx   maxy
# 0 -45.25 -10.50 -45.00 -10.25
# 1 -45.25 -10.75 -45.00 -10.50
# 2 -45.25 -11.00 -45.00 -10.75
# 3 -45.25 -11.25 -45.00 -11.00
# 4 -45.00 -10.50 -44.75 -10.25

# %%
df_regions.minx
# Out:
# 0    -45.25
# 1    -45.25
# 2    -45.25
# 3    -45.25
# 4    -45.00
# 5    -45.00
# 6    -45.00
# 7    -45.00
# 8    -44.75
# 9    -44.75
# 10   -44.75
# 11   -44.75
# 12   -44.50
# 13   -44.50
# 14   -44.50
# 15   -44.50
# 16   -44.50
# 17   -44.25
# 18   -44.25
# 19   -44.25
# 20   -44.25
# 21   -44.25
# 22   -44.00
# 23   -44.00
# 24   -44.00
# 25   -44.00
# 26   -44.00
# 27   -44.00
# 28   -43.75
# 29   -43.75
# 30   -43.75
# 31   -43.75
# 32   -43.75
# 33   -43.75
# Name: minx, dtype: float64

# %%
lista_region = [df_regions.minx,df_regions.maxx,
                df_regions.miny, df_regions.maxy]

# %%
for index,row in malha_cartog_1089_50k.iterrows():
    print(index)
    print(row)
    break
# Out:
# 0
# field_1                                                 23129
# id_folha                                       SC23_Y_B_III_4
# region                         (-45.25, -45.0, -10.5, -10.25)
# geometry    POLYGON ((-45.25 -10.25, -45 -10.25, -45 -10.5...
# Name: 0, dtype: object

# %%
region['left'] = bounds.maxx
region['right'] = bounds.minx
region['bottom'] = bounds.miny
region['top'] = bounds.maxy

# %%
region.drop(['maxx','miny','minx','maxy'],axis=1,inplace=True)

# %%
region
# Out:
#      left  right  bottom    top
# 0  -45.00 -45.25  -10.50 -10.25
# 1  -45.00 -45.25  -10.75 -10.50
# 2  -45.00 -45.25  -11.00 -10.75
# 3  -45.00 -45.25  -11.25 -11.00
# 4  -44.75 -45.00  -10.50 -10.25
# 5  -44.75 -45.00  -10.75 -10.50
# 6  -44.75 -45.00  -11.00 -10.75
# 7  -44.75 -45.00  -11.25 -11.00
# 8  -44.50 -44.75  -10.25 -10.00
# 9  -44.50 -44.75  -10.50 -10.25
# 10 -44.50 -44.75  -10.75 -10.50
# 11 -44.50 -44.75  -11.00 -10.75
# 12 -44.25 -44.50  -10.00  -9.75
# 13 -44.25 -44.50  -10.25 -10.00
# 14 -44.25 -44.50  -10.50 -10.25
# 15 -44.25 -44.50  -10.75 -10.50
# 16 -44.25 -44.50  -11.00 -10.75
# 17 -44.00 -44.25  -10.00  -9.75
# 18 -44.00 -44.25  -10.25 -10.00
# 19 -44.00 -44.25  -10.50 -10.25
# 20 -44.00 -44.25  -10.75 -10.50
# 21 -44.00 -44.25  -11.00 -10.75
# 22 -43.75 -44.00   -9.75  -9.50
# 23 -43.75 -44.00  -10.00  -9.75
# 24 -43.75 -44.00  -10.25 -10.00
# 25 -43.75 -44.00  -10.50 -10.25
# 26 -43.75 -44.00  -10.75 -10.50
# 27 -43.75 -44.00  -11.00 -10.75
# ...

# %%
dic =
# Out:
#   File "<ipython-input-225-d33eef3eb5bf>", line 1
#     dic = {['left':region.left]}
#                   ^
# SyntaxError: invalid syntax

# %%
region.drop([0],inplace=True)

# %%
region
# Out:
#      left  right  bottom    top
# 1  -45.00 -45.25  -10.75 -10.50
# 2  -45.00 -45.25  -11.00 -10.75
# 3  -45.00 -45.25  -11.25 -11.00
# 4  -44.75 -45.00  -10.50 -10.25
# 5  -44.75 -45.00  -10.75 -10.50
# 6  -44.75 -45.00  -11.00 -10.75
# 7  -44.75 -45.00  -11.25 -11.00
# 8  -44.50 -44.75  -10.25 -10.00
# 9  -44.50 -44.75  -10.50 -10.25
# 10 -44.50 -44.75  -10.75 -10.50
# 11 -44.50 -44.75  -11.00 -10.75
# 12 -44.25 -44.50  -10.00  -9.75
# 13 -44.25 -44.50  -10.25 -10.00
# 14 -44.25 -44.50  -10.50 -10.25
# 15 -44.25 -44.50  -10.75 -10.50
# 16 -44.25 -44.50  -11.00 -10.75
# 17 -44.00 -44.25  -10.00  -9.75
# 18 -44.00 -44.25  -10.25 -10.00
# 19 -44.00 -44.25  -10.50 -10.25
# 20 -44.00 -44.25  -10.75 -10.50
# 21 -44.00 -44.25  -11.00 -10.75
# 22 -43.75 -44.00   -9.75  -9.50
# 23 -43.75 -44.00  -10.00  -9.75
# 24 -43.75 -44.00  -10.25 -10.00
# 25 -43.75 -44.00  -10.50 -10.25
# 26 -43.75 -44.00  -10.75 -10.50
# 27 -43.75 -44.00  -11.00 -10.75
# 28 -43.50 -43.75   -9.75  -9.50
# ...

# %%
# Definindo nomes a partir da articulação sistematica de folhas de cartas. 
lista_grid = []

for index, row in grid_lista.iterrows():
    grid_lista['id_folha'] = (mf.nomeador_grid(row['left'], row['right'],
                                       row['top'], row['bottom']))

# %%
grid_lista
# Out:
#           id  left  top  right  bottom  \
# 0      734.0 -74.0 -6.5  -73.5    -7.0
# 1      735.0 -74.0 -7.0  -73.5    -7.5
# 2      736.0 -74.0 -7.5  -73.5    -8.0
# 3      737.0 -74.0 -8.0  -73.5    -8.5
# 4      820.0 -73.5 -5.5  -73.0    -6.0
# ...      ...   ...  ...    ...     ...
# 3051  7598.0 -35.0 -6.5  -34.5    -7.0
# 3052  7599.0 -35.0 -7.0  -34.5    -7.5
# 3053  7600.0 -35.0 -7.5  -34.5    -8.0
# 3054  7601.0 -35.0 -8.0  -34.5    -8.5
# 3055  7602.0 -35.0 -8.5  -34.5    -9.0
#
#                                                geometry     id_folha region
# 0     MULTIPOLYGON (((-74.00000 -6.50000, -73.50000 ...  SC25_V_A_VI   None
# 1     MULTIPOLYGON (((-74.00000 -7.00000, -73.50000 ...  SC25_V_A_VI   None
# 2     MULTIPOLYGON (((-74.00000 -7.50000, -73.50000 ...  SC25_V_A_VI   None
# 3     MULTIPOLYGON (((-74.00000 -8.00000, -73.50000 ...  SC25_V_A_VI   None
# 4     MULTIPOLYGON (((-73.50000 -5.50000, -73.00000 ...  SC25_V_A_VI   None
# ...

# %%
import math

# %%
grid_lista
# Out:
#           id  left  top  right  bottom  \
# 0      734.0 -74.0 -6.5  -73.5    -7.0
# 1      735.0 -74.0 -7.0  -73.5    -7.5
# 2      736.0 -74.0 -7.5  -73.5    -8.0
# 3      737.0 -74.0 -8.0  -73.5    -8.5
# 4      820.0 -73.5 -5.5  -73.0    -6.0
# ...      ...   ...  ...    ...     ...
# 3051  7598.0 -35.0 -6.5  -34.5    -7.0
# 3052  7599.0 -35.0 -7.0  -34.5    -7.5
# 3053  7600.0 -35.0 -7.5  -34.5    -8.0
# 3054  7601.0 -35.0 -8.0  -34.5    -8.5
# 3055  7602.0 -35.0 -8.5  -34.5    -9.0
#
#                                                geometry     id_folha  \
# 0     MULTIPOLYGON (((-74.00000 -6.50000, -73.50000 ...  SC25_V_A_VI
# 1     MULTIPOLYGON (((-74.00000 -7.00000, -73.50000 ...  SC25_V_A_VI
# 2     MULTIPOLYGON (((-74.00000 -7.50000, -73.50000 ...  SC25_V_A_VI
# 3     MULTIPOLYGON (((-74.00000 -8.00000, -73.50000 ...  SC25_V_A_VI
# 4     MULTIPOLYGON (((-73.50000 -5.50000, -73.00000 ...  SC25_V_A_VI
# ...                                                 ...          ...
# ...

# %%
grid_lista
# Out:
#           id  left  top  right  bottom  \
# 0      734.0 -74.0 -6.5  -73.5    -7.0
# 1      735.0 -74.0 -7.0  -73.5    -7.5
# 2      736.0 -74.0 -7.5  -73.5    -8.0
# 3      737.0 -74.0 -8.0  -73.5    -8.5
# 4      820.0 -73.5 -5.5  -73.0    -6.0
# ...      ...   ...  ...    ...     ...
# 3051  7598.0 -35.0 -6.5  -34.5    -7.0
# 3052  7599.0 -35.0 -7.0  -34.5    -7.5
# 3053  7600.0 -35.0 -7.5  -34.5    -8.0
# 3054  7601.0 -35.0 -8.0  -34.5    -8.5
# 3055  7602.0 -35.0 -8.5  -34.5    -9.0
#
#                                                geometry
# 0     MULTIPOLYGON (((-74.00000 -6.50000, -73.50000 ...
# 1     MULTIPOLYGON (((-74.00000 -7.00000, -73.50000 ...
# 2     MULTIPOLYGON (((-74.00000 -7.50000, -73.50000 ...
# 3     MULTIPOLYGON (((-74.00000 -8.00000, -73.50000 ...
# 4     MULTIPOLYGON (((-73.50000 -5.50000, -73.00000 ...
# ...                                                 ...
# 3051  MULTIPOLYGON (((-35.00000 -6.50000, -34.50000 ...
# ...

# %%
grid_lista.drop('region',axis=1,inplace=True)

# %%
grid_lista
# Out:
#           id  left  top  right  bottom  \
# 0      734.0 -74.0 -6.5  -73.5    -7.0
# 1      735.0 -74.0 -7.0  -73.5    -7.5
# 2      736.0 -74.0 -7.5  -73.5    -8.0
# 3      737.0 -74.0 -8.0  -73.5    -8.5
# 4      820.0 -73.5 -5.5  -73.0    -6.0
# ...      ...   ...  ...    ...     ...
# 3051  7598.0 -35.0 -6.5  -34.5    -7.0
# 3052  7599.0 -35.0 -7.0  -34.5    -7.5
# 3053  7600.0 -35.0 -7.5  -34.5    -8.0
# 3054  7601.0 -35.0 -8.0  -34.5    -8.5
# 3055  7602.0 -35.0 -8.5  -34.5    -9.0
#
#                                                geometry
# 0     MULTIPOLYGON (((-74.00000 -6.50000, -73.50000 ...
# 1     MULTIPOLYGON (((-74.00000 -7.00000, -73.50000 ...
# 2     MULTIPOLYGON (((-74.00000 -7.50000, -73.50000 ...
# 3     MULTIPOLYGON (((-74.00000 -8.00000, -73.50000 ...
# 4     MULTIPOLYGON (((-73.50000 -5.50000, -73.00000 ...
# ...                                                 ...
# 3051  MULTIPOLYGON (((-35.00000 -6.50000, -34.50000 ...
# ...

# %%
for index,row in grid_lista.iterrows():
    print(index)
    row['region'] = row.left,row.right,row.bottom,row.top
# Out:
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# SC25_V_A_VI
# ...

# %%
grid_lista.set_index('id_folha')

# %%
# Definindo region. 
for index, row in grid_lista.iterrows():
    index['region'] = row['left'], row['right'],row['bottom'], row['top']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-117-c7147fa18f79> in <module>
#       1 # Definindo region.
#       2 for index, row in grid_lista.iterrows():
# ----> 3     grid_lista['region'] = [row['left'], row['right'],row['bottom'], row['top']]
#
# ~/Softwares/anaconda3/envs/mappingBot/lib/python3.8/site-packages/geopandas/geodataframe.py in __setitem__(self, key, value)
#     851             except TypeError:
#     852                 warnings.warn("Geometry column does not contain geometry.")
# --> 853         super(GeoDataFrame, self).__setitem__(key, value)
#     854
#     855     #
#
# ~/Softwares/anaconda3/envs/mappingBot/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
# ...

# %%
grid_lista
# Out:
#           id  left  top  right  bottom  \
# 0      734.0 -74.0 -6.5  -73.5    -7.0
# 1      735.0 -74.0 -7.0  -73.5    -7.5
# 2      736.0 -74.0 -7.5  -73.5    -8.0
# 3      737.0 -74.0 -8.0  -73.5    -8.5
# 4      820.0 -73.5 -5.5  -73.0    -6.0
# ...      ...   ...  ...    ...     ...
# 3051  7598.0 -35.0 -6.5  -34.5    -7.0
# 3052  7599.0 -35.0 -7.0  -34.5    -7.5
# 3053  7600.0 -35.0 -7.5  -34.5    -8.0
# 3054  7601.0 -35.0 -8.0  -34.5    -8.5
# 3055  7602.0 -35.0 -8.5  -34.5    -9.0
#
#                                                geometry     id_folha  \
# 0     MULTIPOLYGON (((-74.00000 -6.50000, -73.50000 ...  SC25_V_A_VI
# 1     MULTIPOLYGON (((-74.00000 -7.00000, -73.50000 ...  SC25_V_A_VI
# 2     MULTIPOLYGON (((-74.00000 -7.50000, -73.50000 ...  SC25_V_A_VI
# 3     MULTIPOLYGON (((-74.00000 -8.00000, -73.50000 ...  SC25_V_A_VI
# 4     MULTIPOLYGON (((-73.50000 -5.50000, -73.00000 ...  SC25_V_A_VI
# ...                                                 ...          ...
# ...

# %%
malha_cartog_100k = grid_lista.drop('id',axis=1)

# %%
malha_cartog_100k = malha_cartog_100k.set_index('id_folha')

# %%
malha_cartog_100k.head(5)
# Out:
#              left  top  right  bottom  \
# id_folha
# SC25_V_A_VI -74.0 -6.5  -73.5    -7.0
# SC25_V_A_VI -74.0 -7.0  -73.5    -7.5
# SC25_V_A_VI -74.0 -7.5  -73.5    -8.0
# SC25_V_A_VI -74.0 -8.0  -73.5    -8.5
# SC25_V_A_VI -73.5 -5.5  -73.0    -6.0
#
#                                                       geometry
# id_folha
# SC25_V_A_VI  MULTIPOLYGON (((-74.00000 -6.50000, -73.50000 ...
# SC25_V_A_VI  MULTIPOLYGON (((-74.00000 -7.00000, -73.50000 ...
# SC25_V_A_VI  MULTIPOLYGON (((-74.00000 -7.50000, -73.50000 ...
# SC25_V_A_VI  MULTIPOLYGON (((-74.00000 -8.00000, -73.50000 ...
# SC25_V_A_VI  MULTIPOLYGON (((-73.50000 -5.50000, -73.00000 ...

# %%
region = malha_cartog_100k.region[:1].values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-95-7cceec1d966c> in <module>
# ----> 1 region = malha_cartog_100k.region[:1].values
#
# ~/Softwares/anaconda3/envs/mappingBot/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'GeoDataFrame' object has no attribute 'region'

# %%
region
# Out:
# array(['(-45.25, -45.0, -10.5, -10.25)'], dtype=object)

# %%
print(region)
# Out:
# ['(-45.25, -45.0, -10.5, -10.25)']

# %%
g_1089
# Out:
#                 X           Y     MDT  KPERC    eU    eth    CTCOR  LONGITUDE  \
# 0       528115.65  8756161.26  522.35   0.38  1.46  18.83  1371.89 -44.742414
# 1       528035.37  8756163.26  522.77   0.43  1.06  15.94  1170.76 -44.743149
# 2       527955.11  8756164.95  522.11   0.44  1.08  13.13  1016.51 -44.743884
# 3       527874.82  8756166.56  522.05   0.42  1.47  11.12   946.89 -44.744620
# 4       527794.50  8756168.02  522.57   0.43  1.78  10.41   948.79 -44.745356
# ...           ...         ...     ...    ...   ...    ...      ...        ...
# 667894  665126.58  8782417.52  422.06   0.29  0.59   7.02   562.15 -43.488568
# 667895  665130.89  8782340.24  422.94   0.33  0.61   7.26   588.93 -43.488525
# 667896  665135.62  8782262.93  423.37   0.36  0.66   7.69   630.33 -43.488478
# 667897  665140.29  8782185.57  422.44   0.40  0.48   7.39   599.77 -43.488431
# 667898  665143.98  8782108.02  423.89   0.45  0.30   7.40   594.58 -43.488394
#
#          LATITUDE
# ...

# %%
lista_region_1089_50k =  pd.to_numeric(area_1089_50k_index.region)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "(-45.25, -45.0, -10.5, -10.25)"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-1e6aac9c7185> in <module>
# ----> 1 lista_region_1089_50k =  pd.to_numeric(area_1089_50k_index.region)
#
# ~/Softwares/anaconda3/envs/mappingBot/lib/python3.8/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     152         coerce_numeric = errors not in ("ignore", "raise")
#     153         try:
# --> 154             values = lib.maybe_convert_numeric(
#     155                 values, set(), coerce_numeric=coerce_numeric
#     156             )
#
# ...

# %%
for index, row in area_1089_50k_index.iterrows():
    print(row.region)
    index = g_1089[vd.inside((g_1089.LONGITUDE, g_1089.LATITUDE), region = row.region)]
¹
    break
# Out:
# (-45.25, -45.0, -10.5, -10.25)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-3c4e590ee86f> in <module>
#       1 for index, row in area_1089_50k_index.iterrows():
#       2     print(row.region)
# ----> 3     index = g_1089[vd.inside((g_1089.LONGITUDE, g_1089.LATITUDE), region = row.region)]
#       4
#       5     break
#
# ~/Softwares/anaconda3/envs/mappingBot/lib/python3.8/site-packages/verde/coordinates.py in inside(coordinates, region)
#     693
#     694     """
# --> 695     check_region(region)
#     696     w, e, s, n = region
#     697     easting, northing = coordinates[:2]
#
# ~/Softwares/anaconda3/envs/mappingBot/lib/python3.8/site-packages/verde/coordinates.py in check_region(region)
#      37     """
#      38     if len(region) != 4:
# ---> 39         raise ValueError("Invalid region '{}'. Only 4 values allowed.".format(region))
# ...

# %%
grid_lista
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1a1d75003dba> in <module>
# ----> 1 grid_lista
#
# NameError: name 'grid_lista' is not defined

# %%
grid_lista
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1a1d75003dba> in <module>
# ----> 1 grid_lista
#
# NameError: name 'grid_lista' is not defined

# %%
 SF23_Y_A_III_4 = malha_cartog_50k[malha_cartog_50k['id_folha'] == 'SF23_Y_A_III_4']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fd2425e67967> in <module>
# ----> 1 SF23_Y_A_III_4 = malha_cartog_50k[malha_cartog_50k['id_folha'] == 'SF23_Y_A_III_4']
#
# NameError: name 'malha_cartog_50k' is not defined

# %%
g_1089 = pd.read_csv(gdb+'geof/g1089')

# %%
g_1039_SF23_Y_A_III_4 = g_1039[vd.inside((g_1039.LONG, g_1039.LAT), region = region)

# %%
g_1039_SF23_Y_A_III_4
# Out:
#             UTME       UTMN       LONG        LAT    MAGR     THC     UC  \
# 447457  320379.0  7515408.0 -46.745544 -22.457932  155.77   38.93   0.00
# 447458  320370.0  7515508.0 -46.745621 -22.457031  153.70   29.04   8.78
# 447459  320362.0  7515608.0 -46.745697 -22.456116  150.64   30.64  13.47
# 447460  320353.0  7515708.0 -46.745773 -22.455215  146.57   47.68  16.70
# 447461  320344.0  7515808.0 -46.745850 -22.454315  142.51   34.88   6.23
# ...          ...        ...        ...        ...     ...     ...    ...
# 535551  320184.0  7534042.0 -46.745346 -22.289642 -113.71   63.55  15.38
# 535552  320083.0  7534040.0 -46.746323 -22.289658 -107.67   60.69  23.54
# 535553  319983.0  7534037.0 -46.747299 -22.289673  -98.64   56.39   5.71
# 535554  319884.0  7534035.0 -46.748260 -22.289673  -90.60   50.85  21.02
# 535555  319784.0  7534033.0 -46.749222 -22.289688  -86.56  112.66   6.78
#
#             KC      CTC
# 447457   53.53   683.17
# 447458   61.97   716.11
# ...

# %%
g_1039
# Out:
#             UTME       UTMN       LONG        LAT    MAGR    THC     UC  \
# 0       684002.0  7335281.0 -49.190033 -24.083740 -144.49  45.56   5.05
# 1       684003.0  7335381.0 -49.190048 -24.082840 -147.53  53.58   0.00
# 2       684004.0  7335481.0 -49.190048 -24.081940 -144.57  52.58  14.07
# 3       684005.0  7335581.0 -49.190048 -24.081039 -146.61  51.68   0.00
# 4       684006.0  7335681.0 -49.190048 -24.080124 -156.65  62.20  21.64
# ...          ...        ...        ...        ...     ...    ...    ...
# 539044  329329.0  7563776.0 -46.653473 -22.022064   92.53  70.13  20.86
# 539045  329426.0  7563774.0 -46.652527 -22.022095  100.51  54.54  19.79
# 539046  329523.0  7563771.0 -46.651596 -22.022125  100.50  74.22  19.75
# 539047  329620.0  7563769.0 -46.650650 -22.022156   96.48  68.61   5.81
# 539048  329717.0  7563767.0 -46.649719 -22.022186   93.46  64.39  15.35
#
#             KC      CTC
# 0        14.96   714.25
# 1        27.56   708.61
# 2        15.95   837.01
# ...

# %%
chain_list = ['CTC', 'KC', 'UC', 'THC', 'MAGR']

grids = {'CTC':(),'KC':(), 'UC':(), 'THC':(), 'MAGR':()}

scores = {'CTC':(),'KC':(), 'UC':(), 'THC':(), 'MAGR':()}


coordinates = (g_1039_SF23_Y_A_III_4.UTME.values, g_1039_SF23_Y_A_III_4.UTMN.values)

# %%
for i in chain_list:
    print(i)
    
    chain = vd.Chain([
        ('trend', vd.Trend(degree=1)),
        ('reduce', vd.BlockReduce(np.median, spacing=1000)),
        ('spline', vd.Spline())
    ])
    
    chain.fit(coordinates, g_1039_SF23_Y_A_III_4[i])
  
    cv     = vd.BlockKFold(spacing=1000,
                  n_splits=100,
                  shuffle=True)

    scores[i] = vd.cross_val_score(chain,
                             coordinates,
                             g_1039_SF23_Y_A_III_4[i],
                             cv=cv)

    grid = chain.grid(spacing=200, data_names=[i],pixel_register=True)
    grids[i] = vd.distance_mask(coordinates, maxdist=1000, grid= grid)
# Out:
# CTC
# KC
# UC
# THC
# MAGR
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-199-42a6fb5a88e8> in <module>
#      14                   shuffle=True)
#      15
# ---> 16     scores[i] = vd.cross_val_score(chain,
#      17                              coordinates,
#      18                              g_1039_SF23_Y_A_III_4[i],
#
# ~/Softwares/anaconda3/envs/mappingBot/lib/python3.8/site-packages/verde/model_selection.py in cross_val_score(estimator, coordinates, data, weights, cv, client, delayed, scoring)
#     774         # Clone the estimator to avoid fitting the same object simultaneously
#     775         # when delayed=True.
# --> 776         score = dispatch(fit_score, client=client, delayed=delayed)(
#     777             clone(estimator),
#     778             tuple(select(i, train_index) for i in fit_args),
#
# ...

# %%
plt.figure()
plt.hist(scores['CTC'],bins='auto')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (array([2., 0., 1.]),
#  array([0.58121921, 0.58812793, 0.59503664, 0.60194535]),
#  <BarContainer object of 3 artists>)

# %%
plt.figure()
grids['CTC'].CTC.plot()
plt.axis('scaled')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (319784.0, 345064.0, 7510797.0, 7538532.0)
