# %% [markdown]
# # Filtering and Describing Geospatial Data

# %% [markdown]
# Neste notebook vamos definir as funçoes de descriçao e filtragem dos dados a partir das classes definidas na bilbioteca GeoPandas e Matplotlib
#
# [Mapping and Plotting Tools](https://geopandas.org/docs/user_guide/mapping.html)
#
# [Matplotlib](https://matplotlib.org/stable/tutorials/introductory/usage.html#sphx-glr-tutorials-introductory-usage-py)
#
#
#  *IMPORTANTE*
# - Com as funçoes definidas e testadas neste notebook, criaremos um arquivo .py no diretorio .scr/ para armazená-las, possibilitando assim, sua utilizaçao com a funçao import.

# %%
import pandas as pd

import geopandas as gpd 
import fiona

# %%
# Origem do banco de dados
from src.geopandas_custom import gdb

gdb()
# Out:
# '/home/ggrl/geodatabase/'

# %%
path = gdb('geodatabase.gpkg')

# %%
# Parametro para plot interativo
# %matplotlib widget

# %% [markdown]
# ## Importando os vetores do banco de dados criado no notebook passado.
# - Escolha de camada e mapa
#     - Caso nao tenha o mapa selecionado retorne lista de mapas disponiveis para aquela escala.
#     - Caso nao escolha um mapa retorne todos os vetores daquela camada.

# %%
# IMPORTADOR DE LITOLOGIAS POR ESCALA --------------------------------------------------------------------------#
def importar_geometrias(camada, mapa=False):
    '''
    Recebe:
        camada      : camada vetorial a ser lida do geopackage.
        mapa        : nome do mapa presente na camada vetorial;

    Retorna:
        Objeto GeoDataFrame.
        
    Se houver seleçao de mapa retornara apenas as geometrias que possuem o nome escolhido na coluna ['MAPA']
    Se Retornar camada vazia recebera a lista das camadas veotoriais diposniveis
    Se mapa == False: retorna todos os objetos presente nesta camada vetorial
    '''
    lito =  gpd.read_file(path,
                        driver= 'GPKG',
                        layer= camada)

    if mapa:
        folha = lito[lito.MAPA == 'Carta geológica da folha ' + mapa]             # df[df.series]
        
        if folha.empty:

            print("O mapa escolhido nao est'a presente na coluna MAPA da camada veotiral. Os mapas disponiveis serao listados a seguir.")
            print('# Selecionando apenas os caracteres apos ''folha'' (SEM ESPAÇO)')
            print(f"# -- Lista de mapas: {list(lito.MAPA.unique())}")

            lista_mapas = list(lito.MAPA.unique())
            return lista_mapas

        else:    
            return(folha)

    else:
        return(lito)

# %% [markdown]
# ###  Utilizando as funçoes definidas acima para importar os dados

# %%
# Abrindo os vetores descritivos dos projetos aerogeofisicos
proj_geof = importar_geometrias('proj_aerogeof')

# %%
df = proj_geof

# %%
df.ESPACAMENT
# Out:
# 0       2.5
# 1       500
# 2      1500
# 3      1000
# 4       500
#        ...
# 291     2,5
# 292     250
# 293    1000
# 294    1000
# 295     500
# Name: ESPACAMENT, Length: 296, dtype: object

# %%
#df[df.ESPACAMENT]

# %%
list(fiona.listlayers(gdb('geodatabase.gpkg')))
# Out:
# ['litologia_1kk',
#  'litologia_250k',
#  'litologia_100k',
#  'litologia_50k',
#  'ocorr_min_cprm',
#  'aflora',
#  'am_petro',
#  'proj_cprm',
#  'proj_aerogeof',
#  'socorro_250k']

# %%
proj_geof.columns
# Out:
# Index(['ID_PROJETO', 'TITULO', 'METODOS', 'ALTURA_VOO', 'AREA_LEVAN',
#        'QUILOMETRA', 'DIRECAO_LV', 'DIRECAO_LC', 'ESPACAMENT', 'ESPACAME_1',
#        'ID_SERIE', 'SERIE', 'DISPONIBIL', 'IMAGENS', 'SHAPE_AREA', 'SHAPE_LEN',
#        'geometry'],
#       dtype='object')

# %%
print(f'Lista de espaçamentos disponíveis: {list(proj_geof.ESPACAMENT.unique())}')
# Out:
# Lista de espaçamentos disponíveis: ['2.5', '500', '1500', '1000', '3000', '2000', '3', '0', '250', '150', '200', '2500', '100', '4000', '2', '125', '400', '300', '1', '5', '4', '2,5', '6000', '8000', '6', '1,5', '7']

# %%
litologia_1kk = importar_geometrias('litologia_1kk')
# litologia_100k = importar_geometrias('litologia_100k')
# litologia_50k = importar_geometrias('litologia_50k')

# %% [markdown]
# ## Descrevendo as caracteristicas dos dados

# %%
litologia_1kk.head(5)
# Out:
#    ID_UNIDADE SIGLA HIERARQUIA                       NOME  \
# 0        1506   Q1t    Unidade  Unidade Terraços fluviais
# 1        2054  K2ra   Formação          Formação Rio Azul
# 2         214  N12s   Formação          Formação Solimões
# 3        1506   Q1t    Unidade  Unidade Terraços fluviais
# 4         214  N12s   Formação          Formação Solimões
#
#               AMBIENTE_T                        SUB_AMBIEN SIGLA_PAI NOME_PAI  \
# 0  Cobertura superficial  Cobertura transportada(Clástica)      None     None
# 1                   None                              None      None     None
# 2                   None                              None      None     None
# 3  Cobertura superficial  Cobertura transportada(Clástica)      None     None
# 4                   None                              None      None     None
#
#                                              LEGENDA       ESCALA  ...  \
# 0  Correspondem a amplos depósitos sedimentares c...  1:1.000.000  ...
# 1  Folhelho cinza a castanho e arenito fino com n...  1:1.000.000  ...
# 2  Sedimento pelítico, flúvio lacustre, contendo ...  1:1.000.000  ...
# 3  Correspondem a amplos depósitos sedimentares c...  1:1.000.000  ...
# 4  Sedimento pelítico, flúvio lacustre, contendo ...  1:1.000.000  ...
#
#      ERA_MIN    ERA_MAX SISTEMA_MI  SISTEMA_MA  EPOCA_MIN EPOCA_MAX  \
# 0  Cenozóico  Cenozóico    Neogeno     Neogeno   Superior  Superior
# 1  Mesozóico  Mesozóico   Cretáceo    Cretáceo   Inferior  Inferior
# 2  Cenozóico  Cenozóico    Neogeno     Neogeno   Superior  Superior
# 3  Cenozóico  Cenozóico    Neogeno     Neogeno   Superior  Superior
# 4  Cenozóico  Cenozóico    Neogeno     Neogeno   Superior  Superior
#
#   SIGLAS_HIS SHAPE_AREA  SHAPE_LEN  \
# 0       None   0.002355   0.326835
# 1       None   0.005557   0.499255
# 2      E2N2s   0.276915   3.847330
# 3       None   0.033780   1.492084
# 4      E2N2s   2.239930  16.631079
#
#                                             geometry
# 0  POLYGON ((-72.72785 -8.38730, -72.73120 -8.384...
# 1  POLYGON ((-73.73806 -7.33994, -73.73616 -7.343...
# 2  MULTIPOLYGON (((-72.00000 -8.00000, -72.03095 ...
# 3  POLYGON ((-72.00000 -7.25284, -72.00048 -7.253...
# 4  POLYGON ((-68.99004 -8.79511, -68.98310 -8.798...
#
# [5 rows x 27 columns]

# %%
print(litologia_1kk.columns)
# Out:
# Index(['ID_UNIDADE', 'SIGLA', 'HIERARQUIA', 'NOME', 'AMBIENTE_T', 'SUB_AMBIEN',
#        'SIGLA_PAI', 'NOME_PAI', 'LEGENDA', 'ESCALA', 'MAPA', 'LITOTIPOS',
#        'RANGE', 'IDADE_MIN', 'IDADE_MAX', 'EON_MIN', 'EON_MAX', 'ERA_MIN',
#        'ERA_MAX', 'SISTEMA_MI', 'SISTEMA_MA', 'EPOCA_MIN', 'EPOCA_MAX',
#        'SIGLAS_HIS', 'SHAPE_AREA', 'SHAPE_LEN', 'geometry'],
#       dtype='object')

# %%
meta_lito_1kk = pd.DataFrame(litologia_1kk.dtypes)
meta_lito_1kk['Valores null'] = litologia_1kk.isnull().sum()
meta_lito_1kk['Valores unicos'] = litologia_1kk.nunique()
meta_lito_1kk                                                                   # NEED TO CREATE A SYSTEM TO GENERATE A DATAFRAME FOR EACH LITOSTRATIGRAPHIC LAYER
                                                                                # TO DO SO, WE COULD CREATE AN UPPER INDEX FOR EACH LAYER CONTAINING ALL THIS INDECES.
# Out:
#                    0  Valores null  Valores unicos
# ID_UNIDADE     int64             0            2334
# SIGLA         object             0            2334
# HIERARQUIA    object             0              30
# NOME          object             0            2299
# AMBIENTE_T    object         30843               9
# SUB_AMBIEN    object         37895              28
# SIGLA_PAI     object         31035             380
# NOME_PAI      object         31035             380
# LEGENDA       object            13            2095
# ESCALA        object             0               1
# MAPA          object             0              45
# LITOTIPOS     object             0            1637
# RANGE         object             0             112
# IDADE_MIN      int64             0              43
# IDADE_MAX      int64             0              44
# EON_MIN       object             0               3
# EON_MAX       object             0               3
# ERA_MIN       object             0               9
# ERA_MAX       object             0              10
# SISTEMA_MI    object          1943              21
# SISTEMA_MA    object          2534              21
# EPOCA_MIN     object          1943              15
# EPOCA_MAX     object          2534              15
# SIGLAS_HIS    object         18820            1103
# SHAPE_AREA   float64             0           46705
# SHAPE_LEN    float64             0           46705
# geometry    geometry             0           46705

# %% [markdown]
# ### Here we can define a function to execute this operation for any layer

# %%
def metadataframe(GeoDataFrame):
    '''
    Recebe : 
        GeoDataFrame Object : Camadas vetoriais de unidades litoestratigráficas;
        
        Retorna :
            DataFrame Object: Planílha com metanálise das camadas vetoriais;
    '''
    print(f'# -- Gerando MetaDataFrame Litoestratigráfico')
    type_dataframe = pd.DataFrame(GeoDataFrame.dtypes)               # Describe the dtype of each column from the DataFrame or, better saying, GeoDataFrame;

    type_dataframe['Valores null']   = GeoDataFrame.isnull().sum()   # Describe the sum of each null value from our object
    type_dataframe['Valores unicos'] = GeoDataFrame.nunique()        # Describe the number of unique values from our object, that is a GeoDataFrame

    meta_dataframe_litologico = type_dataframe.rename(columns = {0 : 'dType'})       # Rename the first column to 'dtype', the name of the function we used.

    print('')
    
    return meta_dataframe_litologico

# %%
# The above function was inserted inside the /sources/descricao.py file;
# So we can import the funcion with this command wennerver we need it

# %%
litologia_250k = importar_geometrias('litologia_250k')
metadataframe(litologia_250k)
#metadataframe(litologia_100k)
#metadataframe(litologia_50k)
# Out:
# # -- Gerando MetaDataFrame Litoestratigráfico
#                dType  Valores null  Valores unicos
# ID_UNIDADE     int64             0             916
# SIGLA         object             0             916
# HIERARQUIA    object             0              19
# NOME          object             0             912
# AMBIENTE_T    object         12105               8
# SUB_AMBIEN    object         13724              35
# SIGLA_PAI     object         10240             211
# NOME_PAI      object         10240             211
# LEGENDA       object            10             902
# ESCALA        object             0               1
# MAPA          object             0              47
# LITOTIPOS     object          1003             678
# RANGE         object             0              84
# IDADE_MIN      int64             0              36
# IDADE_MAX      int64             0              35
# EON_MIN       object             0               3
# EON_MAX       object             0               3
# ERA_MIN       object             0               9
# ERA_MAX       object             0              10
# SISTEMA_MI    object           669              20
# SISTEMA_MA    object          1363              19
# EPOCA_MIN     object           669              14
# EPOCA_MAX     object          1363              13
# SIGLAS_HIS    object         10218             353
# SHAPE_AREA   float64             0           18642
# SHAPE_LEN    float64             0           18642
# geometry    geometry             0           18642

# %% [markdown]
# ### We can observe and analyse by the same means our aerogeophysical metadata.

# %%
metadataframe(proj_geof)       # WE CONCLUDE BY OBSERVING THIS DATAFRAME THAT THE 'TITULO' COLUMN EATHER HAS AN DUPLICATED VALUE
                               # BECAUSE WE HAVE 296 GEOMETRIES AND 295 DIFERENT TITLES
# Out:
# # -- Gerando MetaDataFrame Litoestratigráfico
#                dType  Valores null  Valores unicos
# ID_PROJETO     int64             0             296
# TITULO        object             0             295
# METODOS       object             0              15
# ALTURA_VOO    object            31              21
# AREA_LEVAN    object             0             264
# QUILOMETRA    object            94             199
# DIRECAO_LV    object             0              32
# DIRECAO_LC    object             0              34
# ESPACAMENT    object             0              27
# ESPACAME_1    object             4              31
# ID_SERIE       int64             0               4
# SERIE         object             0               4
# DISPONIBIL    object           181               1
# IMAGENS       object           181             115
# SHAPE_AREA   float64             0             290
# SHAPE_LEN    float64             0             281
# geometry    geometry             0             296

# %% [markdown]
# ## Com os dados disponiveis na RAM podemos utilizar funçoes do built-in do Python ou funçoes disponibilizadas atravez das bibliotecas podemos produzir informaçoes importantes sobre o nosso dado.

# %% [markdown]
# #### Como por exemplo, calcular area de cobertura do dado.

# %%
area_lito_1kk = litologia_1kk[:].area.sum()
print(area_lito_1kk)

# We can observe that the calculation of the area should be done with a cartesian coordinate reference system instead of geographic for more accurate results
# Although, our coverage area is not inside only one UTM Zone, so we need to create a system to convert each geometry to it's correspodent Zone.
# Out:
# 699.2119915387831
# /tmp/ipykernel_7850/3710234299.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   area_lito_1kk = litologia_1kk[:].area.sum()

# %%
litologia_1kk['SHAPE_AREA'].sum() # We can observe that the area of the polygons have already been calculated and is stored at 'SHAPE_AREA' column
# Out:
# 699.2119915384314

# %%
print(litologia_1kk['SHAPE_AREA'].sum() - area_lito_1kk) # The result is the difference between the Area calculated by the CRPM and the area calculated by the GeoPandas Function
# Out:
# -3.516333890729584e-10

# %%
# SELECTING AEROGEOPHYSICAL PROJECTS BY ITS FLIGHT LINE SPACEMENT [RESOLUTION]
proj_geof_500m = proj_geof[proj_geof['ESPACAMENT'] == '500']
proj_geof_1000m = proj_geof[proj_geof['ESPACAMENT'] == '1000']

# %%
print(f" The total coverage area of projects with 500 m resolution: {proj_geof_500m['SHAPE_AREA'].sum()}")
print(f" The total coverage area of projects with 1000 m resolution: {proj_geof_1000m['SHAPE_AREA'].sum()}")
# Out:
#  The total coverage area of projects with 500 m resolution: 325.81878046663854
#  The total coverage area of projects with 1000 m resolution: 100.8120406558254

# %%
print(f" The total coverage area of projects with 500 m resolution: {proj_geof_500m[:].area.sum()}")

print(f" The total coverage area of projects with 1000 m resolution: {proj_geof_1000m[:].area.sum()}")
# Out:
#  The total coverage area of projects with 500 m resolution: 325.81878041879565
#  The total coverage area of projects with 1000 m resolution: 100.81204065019355
# /tmp/ipykernel_7850/1195854347.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   print(f" The total coverage area of projects with 500 m resolution: {proj_geof_500m[:].area.sum()}")
# /tmp/ipykernel_7850/1195854347.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   print(f" The total coverage area of projects with 1000 m resolution: {proj_geof_1000m[:].area.sum()}")

# %%
print(f"Percentage of aerogeophysical data coverage of the continental area with 500m resolution: {(proj_geof_500m['SHAPE_AREA'].sum()  / litologia_1kk['SHAPE_AREA'].sum()) * 100} %")
print(f"Percentage of aerogeophysical data coverage of the continental area with 1000m resolution: {(proj_geof_1000m['SHAPE_AREA'].sum() / litologia_1kk['SHAPE_AREA'].sum()) * 100} %")
# Out:
# Percentage of aerogeophysical data coverage of the continental area with 500m resolution: 46.597996660463494 %
# Percentage of aerogeophysical data coverage of the continental area with 1000m resolution: 14.417950761115398 %

# %% [markdown]
# ### Listando atributos geologicos das geometrias importadas.

# %%
# Abrindo os vetores litológicos de um unico mapa utilizando a função definida acima
#varginha_100k = importar_geometrias('litologia_100k','Varginha - UFRJ')
#varginha_100k.head(5)

# %%
# com estas funçoes utilizadas asssimas, podemos definir uma funçao que descreve o nosso dado vetorial
def describe_geologico(gdf):
    lista_colunas = list(gdf.columns)
    lista_litotipos = list(gdf.LITOTIPOS.unique())
    lista_legenda = list(gdf.LEGENDA.unique())

    dic_litologico = {'lista_colunas': lista_colunas,
                      'lista_litotipos': lista_litotipos,
                      'lista_legenda': lista_legenda}
    return dic_litologico

# %%
dic_litoligico = describe_geologico(litologia_1kk)

# %% [markdown]
# ### Reconhecendo as litologia mapeadas em suas escalas
# - Faremos um filtro na coluna LEGENDA e LITOTIOPOS para selecionar as classes de interesse e, com estas geometrias, selecionaremos os mapas que as contém.
# - Assim podemos identificar quais cartas geológicas e suas escalas podemos trabalhar.

# %%
def filtro(gdf,mineral):
    filtrado = gdf[gdf['LITOTIPOS'].str.contains(mineral)]
    if filtrado.empty:
        print(f"{list(gdf['LITOTIPOS'].unique())}")
    else:
        return filtrado

# %%
litologia_grafitosa_1kk = filtro(litologia_1kk,'graf')

# %%
litotipos_vazio = litologia_1kk[litologia_1kk.LITOTIPOS.isna()]
litotipos_vazio.LITOTIPOS
# Out:
# Series([], Name: LITOTIPOS, dtype: object)

# %%
#Foi necessário inserir a str 'Vazio' em celas que não continham valores para que a função de filtro funcionasse corretamente na coluna LEGENDA.

litologia_1kk.fillna('Vazio',inplace=True)
litologia_250k.fillna('Vazio',inplace=True)

litologia_100k = importar_geometrias('litologia_100k')
litologia_100k.fillna('Vazio',inplace=True)

litologia_50k = importar_geometrias('litologia_50k')
litologia_50k.fillna('Vazio',inplace=True)

# %%
litologia_1kk.to_file(gdb('geodatabase.gpkg'),
              driver='GPKG',
              layer='litologia_1kk')

litologia_250k.to_file(gdb('geodatabase.gpkg'),
              driver='GPKG',
              layer='litologia_250k')

litologia_100k.to_file(gdb('geodatabase.gpkg'),
              driver='GPKG',
              layer='litologia_100k')

litologia_50k.to_file(gdb('geodatabase.gpkg'),
              driver='GPKG',
              layer='litologia_50k')

# %%
Grafita_xistos_1kk = filtro(litologia_1kk,'Graf')

# %%
dicionario_grafitoso = describe_geologico(Grafita_xistos_1kk)

# %%
len(dicionario_grafitoso['lista_litotipos'])
# Out:
# 29

# %%
lista_grafita = dicionario_grafitoso['lista_litotipos']

# %%
associacao_grafitosa=[]

for i in lista_grafita:
    split = i.split(",")
    associacao_grafitosa.append(split)

# %%
associacao_grafitosa[:10]
# Out:
# [['Anfibolito', ' Grafita xisto', ' Metapelito', ' Quartzito'],
#  ['Formação ferrífera bandada',
#   ' Grafita xisto',
#   ' Metachert',
#   ' Rocha metassedimentar',
#   ' Rocha metavulcânica ultramáfica',
#   ' Serpentinito'],
#  ['Biotita-anfibólio xisto',
#   ' Biotita-quartzo xisto',
#   ' Filito',
#   ' Grafita xisto',
#   ' Mármore calcítico',
#   ' Mármore dolomítico',
#   ' Metatufo',
#   ' Quartzo-mica xisto',
#   ' Rocha calcissilicática',
#   ' Xisto carbonático'],
#  ['Clorita xisto',
#   ' Grafita xisto',
#   ' Hornblenda gnaisse',
#   ' Metacalcário',
#   ' Muscovita quartzito',
#   ' Muscovita-biotita xisto',
#   ' Quartzito ferruginoso',
#   ' Talco xisto'],
#  ['Clorita xisto',
#   ' Grafita xisto',
#   ' Metachert',
#   ' Metadacito',
#   ' Metatufo',
#   ' Xisto'],
#  ['Biotita gnaisse',
#   ' Gnaisse',
#   ' Gondito',
#   ' Grafita xisto',
#   ' Granada gnaisse',
#   ' Kinzigito',
#   ' Mármore',
#   ' Muscovita quartzito',
#   ' Quartzito',
#   ' Rocha calcissilicática',
#   ' Sericita xisto',
#   ' Xisto'],
#  ['Grafita xisto',
#   ' Metachert',
#   ' Muscovita quartzito',
#   ' Quartzito ferruginoso',
#   ' Xisto',
#   ' Xisto aluminoso'],
#  ['Clorita xisto',
#   ' Cloritito',
#   ' Formação ferrífera bandada',
#   ' Grafita xisto',
#   ' Muscovita-biotita xisto',
#   ' Piroxenito',
#   ' Serpentinito',
#   ' Talco xisto',
#   ' Xisto magnesiano'],
#  ['Biotita xisto',
#   ' Biotita-muscovita-quartzo xisto',
#   ' Grafita xisto',
#   ' Granada-biotita-muscovita-quartzo xisto',
#   ' Granada-clorita xisto',
#   ' Mármore',
#   ' Metaconglomerado suportado por clastos',
#   ' Metapsamito',
#   ' Metarcóseo',
#   ' Quartzito ferruginoso'],
#  ['Filito', ' Grafita xisto', ' Quartzo-mica xisto']]

# %% [markdown]
# #### Desafio desnecessário para provar meus conhecimentos com for loops:

# %%
mapas_lito_gr_100k = litologia_100k

# %%
indice=0
for i in mapas_lito_gr_100k:
    print(i)
    list_gr_100k[indice] = litologia_100k[litologia_100k['MAPA'].str.contains("i")]
    indice+=1
# Out:
# ID_UNIDADE
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/geologist_environment/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/envs/geologist_environment/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/envs/geologist_environment/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/geologist_environment/lib/python3.8/site-packages/pandas/core/frame.py in _set_item_mgr(self, key, value)
#    3750         try:
# -> 3751             loc = self._info_axis.get_loc(key)
#    3752         except KeyError:
#
# ~/anaconda3/envs/geologist_environment/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_7850/3791372804.py in <module>
#       2 for i in mapas_lito_gr_100k:
#       3     print(i)
# ----> 4     list_gr_100k[indice] = litologia_100k[litologia_100k['MAPA'].str.contains("i")]
#       5     indice+=1
#
# ~/anaconda3/envs/geologist_environment/lib/python3.8/site-packages/geopandas/geodataframe.py in __setitem__(self, key, value)
#    1320             except TypeError:
#    1321                 warnings.warn("Geometry column does not contain geometry.")
# -> 1322         super(GeoDataFrame, self).__setitem__(key, value)
#    1323
#    1324     #
#
# ~/anaconda3/envs/geologist_environment/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3600             self._setitem_array(key, value)
#    3601         elif isinstance(value, DataFrame):
# -> 3602             self._set_item_frame_value(key, value)
#    3603         elif (
#    3604             is_list_like(value)
#
# ~/anaconda3/envs/geologist_environment/lib/python3.8/site-packages/pandas/core/frame.py in _set_item_frame_value(self, key, value)
#    3740         # now align rows
#    3741         arraylike = _reindex_for_setitem(value, self.index)
# -> 3742         self._set_item_mgr(key, arraylike)
#    3743
#    3744     def _iset_item_mgr(self, loc: int | slice | np.ndarray, value) -> None:
#
# ~/anaconda3/envs/geologist_environment/lib/python3.8/site-packages/pandas/core/frame.py in _set_item_mgr(self, key, value)
#    3752         except KeyError:
#    3753             # This item wasn't present, just insert at end
# -> 3754             self._mgr.insert(len(self._info_axis), key, value)
#    3755         else:
#    3756             self._iset_item_mgr(loc, value)
#
# ~/anaconda3/envs/geologist_environment/lib/python3.8/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value)
#    1160             value = ensure_block_shape(value, ndim=self.ndim)
#    1161
# -> 1162         block = new_block(values=value, ndim=self.ndim, placement=slice(loc, loc + 1))
#    1163
#    1164         for blkno, count in _fast_count_smallints(self.blknos[loc:]):
#
# ~/anaconda3/envs/geologist_environment/lib/python3.8/site-packages/pandas/core/internals/blocks.py in new_block(values, placement, ndim, klass)
#    1930
#    1931     values, _ = extract_pandas_array(values, None, ndim)
# -> 1932     check_ndim(values, placement, ndim)
#    1933
#    1934     if klass is None:
#
# ~/anaconda3/envs/geologist_environment/lib/python3.8/site-packages/pandas/core/internals/blocks.py in check_ndim(values, placement, ndim)
#    1972             )
#    1973         if len(placement) != len(values):
# -> 1974             raise ValueError(
#    1975                 f"Wrong number of items passed {len(values)}, "
#    1976                 f"placement implies {len(placement)}"
#
# ValueError: Wrong number of items passed 27, placement implies 1

# %%
len(list_gr_100k)
# Out:
# 59268

# %%
lista_mapa = list(litologia_1kk.MAPA.unique())
print(len(lista_mapa))
lista_nome=[]

for mapa in lista_mapa:
    trash=0
    Mapa=[]
    
    for letra in mapa:
        if trash<25:
            trash+=1
            
        else:
            Mapa+=letra
            
    lista_nome += [''.join(Mapa)]
# Out:
# 45

# %%
lista_nome
# Out:
# [                                                                                  geometry  \
#  MAPA
#  Carta geológica da folha Paulo Saldanha  POLYGON ((-62.00000 -11.97996, -62.00000 -12.0...
#
#                                           ID_UNIDADE   SIGLA HIERARQUIA  \
#  MAPA
#  Carta geológica da folha Paulo Saldanha        3844  MP3rbm    Unidade
#
#                                                                     NOME  \
#  MAPA
#  Carta geológica da folha Paulo Saldanha  Unidade Rio Branco, metamáfica
#
#                                          AMBIENTE_T SUB_AMBIEN SIGLA_PAI  \
#  MAPA
#  Carta geológica da folha Paulo Saldanha      Vazio      Vazio     MP3rb
#
#                                                              NOME_PAI  \
#  MAPA
#  Carta geológica da folha Paulo Saldanha  MP3rb - Formação Rio Branco
#
#                                                                                     LEGENDA  \
#  MAPA
#  Carta geológica da folha Paulo Saldanha  Metagabro, metagabro-norito, metadiabásio, anf...
#
#                                           ...       EON_MAX           ERA_MIN  \
#  MAPA                                     ...
#  Carta geológica da folha Paulo Saldanha  ...  Proterozóico  Mesoproterozóico
#
#                                                    ERA_MAX  SISTEMA_MI  \
#  MAPA
#  Carta geológica da folha Paulo Saldanha  Mesoproterozóico   Esteniano
#
#                                           SISTEMA_MA     EPOCA_MIN  \
#  MAPA
#  Carta geológica da folha Paulo Saldanha   Esteniano  Landoveriano
#
#                                              EPOCA_MAX SIGLAS_HIS SHAPE_AREA  \
#  MAPA
#  Carta geológica da folha Paulo Saldanha  Landoveriano      Vazio   0.001552
#
#                                          SHAPE_LEN
#  MAPA
#  Carta geológica da folha Paulo Saldanha  0.275637
#
#  [1 rows x 26 columns],
#                                                                                               geometry  \
#  MAPA
#  Carta geológica da folha Rio Tanaru - SD.20-X-B-IV  POLYGON ((-61.12233 -13.00000, -61.13843 -13.0...
#
#                                                      ID_UNIDADE SIGLA  \
#  MAPA
#  Carta geológica da folha Rio Tanaru - SD.20-X-B-IV        4510  Q1ci
#
#                                                     HIERARQUIA  \
#  MAPA
#  Carta geológica da folha Rio Tanaru - SD.20-X-B-IV    Unidade
#
#                                                                                             NOME  \
#  MAPA
#  Carta geológica da folha Rio Tanaru - SD.20-X-B-IV  Unidade Cobertura sedimentar indiferenciada
#
#                                                                 AMBIENTE_T  \
#  MAPA
#  Carta geológica da folha Rio Tanaru - SD.20-X-B-IV  Cobertura superficial
#
#                                                                       SUB_AMBIEN  \
#  MAPA
#  Carta geológica da folha Rio Tanaru - SD.20-X-B-IV  Cobertura clasto-lateritica
#
#                                                     SIGLA_PAI NOME_PAI  \
#  MAPA
#  Carta geológica da folha Rio Tanaru - SD.20-X-B-IV     Vazio    Vazio
#
#                                                                                                LEGENDA  \
#  MAPA
#  Carta geológica da folha Rio Tanaru - SD.20-X-B-IV  Extensos depósitos de areia fina a média (com ...
#
#                                                      ...      EON_MAX  \
#  MAPA                                                ...
#  Carta geológica da folha Rio Tanaru - SD.20-X-B-IV  ...  Fanerozóico
#
#                                                        ERA_MIN    ERA_MAX  \
#  MAPA
#  Carta geológica da folha Rio Tanaru - SD.20-X-B-IV  Cenozóico  Cenozóico
#
#                                                      SISTEMA_MI  SISTEMA_MA  \
#  MAPA
#  Carta geológica da folha Rio Tanaru - SD.20-X-B-IV     Neogeno     Neogeno
#
#                                                     EPOCA_MIN EPOCA_MAX  \
#  MAPA
#  Carta geológica da folha Rio Tanaru - SD.20-X-B-IV  Superior  Superior
#
#                                                     SIGLAS_HIS SHAPE_AREA  \
#  MAPA
#  Carta geológica da folha Rio Tanaru - SD.20-X-B-IV      Vazio   0.000704
#
#                                                     SHAPE_LEN
#  MAPA
#  Carta geológica da folha Rio Tanaru - SD.20-X-B-IV  0.174514
#
#  [1 rows x 26 columns],
#                                                                              geometry  \
#  MAPA
#  Carta geológica da folha Roncador  POLYGON ((-61.43799 -12.50000, -61.44593 -12.5...
#
#                                     ID_UNIDADE      SIGLA HIERARQUIA  \
#  MAPA
#  Carta geológica da folha Roncador         264  JK_beta_a   Formação
#
#                                               NOME AMBIENTE_T SUB_AMBIEN  \
#  MAPA
#  Carta geológica da folha Roncador  Formação Anarí      Vazio      Vazio
#
#                                    SIGLA_PAI NOME_PAI  \
#  MAPA
#  Carta geológica da folha Roncador     Vazio    Vazio
#
#                                                                               LEGENDA  \
#  MAPA
#  Carta geológica da folha Roncador  Basalto amigdaloidal e maciço, diabásio e gabr...
#
#                                     ...      EON_MAX    ERA_MIN    ERA_MAX  \
#  MAPA                               ...
#  Carta geológica da folha Roncador  ...  Fanerozóico  Mesozóico  Mesozóico
#
#                                     SISTEMA_MI  SISTEMA_MA EPOCA_MIN  \
#  MAPA
#  Carta geológica da folha Roncador    Cretáceo   Jurássico  Inferior
#
#                                       EPOCA_MAX SIGLAS_HIS SHAPE_AREA SHAPE_LEN
#  MAPA
#  Carta geológica da folha Roncador  Lonpingiano  J1_beta_a   0.000065  0.047578
#
#  [1 rows x 26 columns],
#                                                                               geometry  \
#  MAPA
#  Carta geológica da folha Rio Pardo  POLYGON ((-61.50000 -11.90871, -61.50000 -11.9...
#
#                                      ID_UNIDADE    SIGLA HIERARQUIA  \
#  MAPA
#  Carta geológica da folha Rio Pardo        6255  NP3fcbr     Membro
#
#                                               NOME AMBIENTE_T SUB_AMBIEN  \
#  MAPA
#  Carta geológica da folha Rio Pardo  Membro Rondon      Vazio      Vazio
#
#                                     SIGLA_PAI  \
#  MAPA
#  Carta geológica da folha Rio Pardo    NP3fcb
#
#                                                                      NOME_PAI  \
#  MAPA
#  Carta geológica da folha Rio Pardo  NP3fcb - Formação Fazenda da Casa Branca
#
#                                                                                LEGENDA  \
#  MAPA
#  Carta geológica da folha Rio Pardo  Siltito vermelho-tijolo micáceo, com lâminas d...
#
#                                      ...       EON_MAX          ERA_MIN  \
#  MAPA                                ...
#  Carta geológica da folha Rio Pardo  ...  Proterozóico  Neoproterozóico
#
#                                              ERA_MAX  SISTEMA_MI  SISTEMA_MA  \
#  MAPA
#  Carta geológica da folha Rio Pardo  Neoproterozóico  Ediacarano  Ediacarano
#
#                                       EPOCA_MIN   EPOCA_MAX SIGLAS_HIS  \
#  MAPA
#  Carta geológica da folha Rio Pardo  Pridoliano  Pridoliano      Vazio
#
#                                     SHAPE_AREA SHAPE_LEN
#  MAPA
#  Carta geológica da folha Rio Pardo   0.010234  1.134993
#
#  [1 rows x 26 columns],
#                                                                                   geometry  \
#  MAPA
#  Carta geológica da folha Pimenta Bueno  POLYGON ((-61.38853 -12.00000, -61.42610 -12.0...
#
#                                          ID_UNIDADE         SIGLA  \
#  MAPA
#  Carta geológica da folha Pimenta Bueno         577  MP3_gamma_rp
#
#                                               HIERARQUIA  \
#  MAPA
#  Carta geológica da folha Pimenta Bueno  Suíte intrusiva
#
#                                                               NOME  \
#  MAPA
#  Carta geológica da folha Pimenta Bueno  Suíte intrusiva Rio Pardo
#
#                                                     AMBIENTE_T  \
#  MAPA
#  Carta geológica da folha Pimenta Bueno  Magmatismo intraplaca
#
#                                                         SUB_AMBIEN SIGLA_PAI  \
#  MAPA
#  Carta geológica da folha Pimenta Bueno  Intrusivas pós-orogênicas     Vazio
#
#                                         NOME_PAI  \
#  MAPA
#  Carta geológica da folha Pimenta Bueno    Vazio
#
#                                                                                    LEGENDA  \
#  MAPA
#  Carta geológica da folha Pimenta Bueno  Monzo a sienogranitos cinza a róseo, equigranu...
#
#                                          ...       EON_MAX           ERA_MIN  \
#  MAPA                                    ...
#  Carta geológica da folha Pimenta Bueno  ...  Proterozóico  Mesoproterozóico
#
#                                                   ERA_MAX  SISTEMA_MI  \
#  MAPA
#  Carta geológica da folha Pimenta Bueno  Mesoproterozóico   Esteniano
#
#                                          SISTEMA_MA     EPOCA_MIN  \
#  MAPA
#  Carta geológica da folha Pimenta Bueno   Esteniano  Landoveriano
#
#                                             EPOCA_MAX SIGLAS_HIS SHAPE_AREA  \
#  MAPA
#  Carta geológica da folha Pimenta Bueno  Landoveriano      Vazio   0.001771
#
#                                         SHAPE_LEN
#  MAPA
#  Carta geológica da folha Pimenta Bueno  0.275088
#
#  [1 rows x 26 columns],
#                                                                                          geometry  \
#  MAPA
#  Carta geológica da folha Serra da Providência  MULTIPOLYGON (((-61.96789 -10.50000, -62.00000...
#
#                                                 ID_UNIDADE           SIGLA  \
#  MAPA
#  Carta geológica da folha Serra da Providência        5641  MP1_gamma_pssp
#
#                                                HIERARQUIA  \
#  MAPA
#  Carta geológica da folha Serra da Providência     Fácies
#
#                                                                                              NOME  \
#  MAPA
#  Carta geológica da folha Serra da Providência  Fácies Maciço Serra da Providência, sienograni...
#
#                                                AMBIENTE_T SUB_AMBIEN  \
#  MAPA
#  Carta geológica da folha Serra da Providência      Vazio      Vazio
#
#                                                    SIGLA_PAI  \
#  MAPA
#  Carta geológica da folha Serra da Providência  MP1_gamma_ps
#
#                                                                                         NOME_PAI  \
#  MAPA
#  Carta geológica da folha Serra da Providência  MP1_gamma_ps - Corpo Maciço Serra da Providência
#
#                                                                                           LEGENDA  \
#  MAPA
#  Carta geológica da folha Serra da Providência  Hornblenda biotita sienogranito a biotita sien...
#
#                                                 ...       EON_MAX  \
#  MAPA                                           ...
#  Carta geológica da folha Serra da Providência  ...  Proterozóico
#
#                                                          ERA_MIN  \
#  MAPA
#  Carta geológica da folha Serra da Providência  Mesoproterozóico
#
#                                                          ERA_MAX  SISTEMA_MI  \
#  MAPA
#  Carta geológica da folha Serra da Providência  Mesoproterozóico   Calimiano
#
#                                                 SISTEMA_MA EPOCA_MIN EPOCA_MAX  \
#  MAPA
#  Carta geológica da folha Serra da Providência   Calimiano     Médio     Médio
#
#                                                    SIGLAS_HIS SHAPE_AREA  \
#  MAPA
#  Carta geológica da folha Serra da Providência  MP1_gamma_psp   0.001223
#
#                                                SHAPE_LEN
#  MAPA
#  Carta geológica da folha Serra da Providência  0.168095
#
#  [1 rows x 26 columns],
#                                                                               geometry  \
#  MAPA
#  Carta geológica da folha Ji Paraná  MULTIPOLYGON (((-61.50000 -10.96914, -61.50000...
#
#                                      ID_UNIDADE SIGLA    HIERARQUIA  \
#  MAPA
#  Carta geológica da folha Ji Paraná        1507   Q2a  Não definida
#
#                                                       NOME  \
#  MAPA
#  Carta geológica da folha Ji Paraná  Depósitos aluvionares
#
#                                                 AMBIENTE_T SUB_AMBIEN  \
#  MAPA
#  Carta geológica da folha Ji Paraná  Cobertura superficial      Vazio
#
#                                     SIGLA_PAI NOME_PAI  \
#  MAPA
#  Carta geológica da folha Ji Paraná     Vazio    Vazio
#
#                                                                                LEGENDA  \
#  MAPA
#  Carta geológica da folha Ji Paraná  Sedimentos sreno-argilosos aluvionares inconso...
#
#                                      ...      EON_MAX    ERA_MIN    ERA_MAX  \
#  MAPA                                ...
#  Carta geológica da folha Ji Paraná  ...  Fanerozóico  Cenozóico  Cenozóico
#
#                                      SISTEMA_MI  SISTEMA_MA EPOCA_MIN  \
#  MAPA
#  Carta geológica da folha Ji Paraná     Neogeno     Neogeno  Superior
#
#                                     EPOCA_MAX SIGLAS_HIS SHAPE_AREA SHAPE_LEN
#  MAPA
#  Carta geológica da folha Ji Paraná  Superior        N4a    0.00001  0.016609
#
#  [1 rows x 26 columns],
#                                                                               geometry  \
#  MAPA
#  Carta geológica da folha Vila Nova  POLYGON ((-61.35394 2.00000, -61.35846 2.00000...
#
#                                      ID_UNIDADE         SIGLA HIERARQUIA  \
#  MAPA
#  Carta geológica da folha Vila Nova        7211  MP1_delta_ra     Fácies
#
#                                                                            NOME  \
#  MAPA
#  Carta geológica da folha Vila Nova  Fácies Anortosito, Anortosito Repartimento
#
#                                     AMBIENTE_T SUB_AMBIEN    SIGLA_PAI  \
#  MAPA
#  Carta geológica da folha Vila Nova      Vazio      Vazio  MP1_delta_r
#
#                                                                         NOME_PAI  \
#  MAPA
#  Carta geológica da folha Vila Nova  MP1_delta_r - Corpo Anortosito Repartimento
#
#                                                                                LEGENDA  \
#  MAPA
#  Carta geológica da folha Vila Nova  Anortosito pertencente a uma associação magmát...
#
#                                      ...       EON_MAX           ERA_MIN  \
#  MAPA                                ...
#  Carta geológica da folha Vila Nova  ...  Proterozóico  Mesoproterozóico
#
#                                               ERA_MAX  SISTEMA_MI  SISTEMA_MA  \
#  MAPA
#  Carta geológica da folha Vila Nova  Mesoproterozóico   Calimiano   Calimiano
#
#                                     EPOCA_MIN EPOCA_MAX SIGLAS_HIS SHAPE_AREA  \
#  MAPA
#  Carta geológica da folha Vila Nova     Médio     Médio      Vazio   0.000154
#
#                                     SHAPE_LEN
#  MAPA
#  Carta geológica da folha Vila Nova  0.063218
#
#  [1 rows x 26 columns],
#                                                                                      geometry  \
#  MAPA
#  Carta geológica da folha Vila de Tepequém  MULTIPOLYGON (((-61.58190 3.50955, -61.58244 3...
#
#                                             ID_UNIDADE        SIGLA HIERARQUIA  \
#  MAPA
#  Carta geológica da folha Vila de Tepequém        4329  PP3_alfa_ci   Formação
#
#                                                                   NOME  \
#  MAPA
#  Carta geológica da folha Vila de Tepequém  Formação Cachoeira da Ilha
#
#                                            AMBIENTE_T  \
#  MAPA
#  Carta geológica da folha Vila de Tepequém    Orógeno
#
#                                                            SUB_AMBIEN  \
#  MAPA
#  Carta geológica da folha Vila de Tepequém  Magmatismo pós-colisional
#
#                                            SIGLA_PAI NOME_PAI  \
#  MAPA
#  Carta geológica da folha Vila de Tepequém     Vazio    Vazio
#
#                                                                                       LEGENDA  \
#  MAPA
#  Carta geológica da folha Vila de Tepequém  Ignimbrito riolítico de cor cinza escura, pouc...
#
#                                             ...       EON_MAX  \
#  MAPA                                       ...
#  Carta geológica da folha Vila de Tepequém  ...  Proterozóico
#
#                                                       ERA_MIN  \
#  MAPA
#  Carta geológica da folha Vila de Tepequém  Paleoproterozóico
#
#                                                       ERA_MAX  SISTEMA_MI  \
#  MAPA
#  Carta geológica da folha Vila de Tepequém  Paleoproterozóico  Orosiriano
#
#                                             SISTEMA_MA   EPOCA_MIN   EPOCA_MAX  \
#  MAPA
#  Carta geológica da folha Vila de Tepequém  Orosiriano  Furongiano  Furongiano
#
#                                            SIGLAS_HIS SHAPE_AREA SHAPE_LEN
#  MAPA
#  Carta geológica da folha Vila de Tepequém      Vazio   0.000015  0.020506
#
#  [1 rows x 26 columns],
#                                                                                    geometry  \
#  MAPA
#  Carta geológica da folha Betânia - UFMT  MULTIPOLYGON (((-60.31955 -14.50000, -60.31955...
#
#                                           ID_UNIDADE SIGLA    HIERARQUIA  \
#  MAPA
#  Carta geológica da folha Betânia - UFMT        5210  NP3h  Não definida
#
#                                               NOME AMBIENTE_T SUB_AMBIEN  \
#  MAPA
#  Carta geológica da folha Betânia - UFMT  Hornfels      Vazio      Vazio
#
#                                          SIGLA_PAI NOME_PAI  \
#  MAPA
#  Carta geológica da folha Betânia - UFMT     Vazio    Vazio
#
#                                                        LEGENDA  ...  \
#  MAPA                                                           ...
#  Carta geológica da folha Betânia - UFMT  Sillimanita hornfels  ...
#
#                                                EON_MAX          ERA_MIN  \
#  MAPA
#  Carta geológica da folha Betânia - UFMT  Proterozóico  Neoproterozóico
#
#                                                   ERA_MAX  SISTEMA_MI  \
#  MAPA
#  Carta geológica da folha Betânia - UFMT  Neoproterozóico  Ediacarano
#
#                                           SISTEMA_MA   EPOCA_MIN   EPOCA_MAX  \
#  MAPA
#  Carta geológica da folha Betânia - UFMT  Ediacarano  Pridoliano  Pridoliano
#
#                                          SIGLAS_HIS SHAPE_AREA SHAPE_LEN
#  MAPA
#  Carta geológica da folha Betânia - UFMT      Vazio   0.000079  0.063662
#
#  [1 rows x 26 columns],
#                                                                                   geometry  \
#  MAPA
#  Carta geológica da folha Rio Escondido  POLYGON ((-60.50000 -13.49681, -60.50000 -13.5...
#
#                                          ID_UNIDADE SIGLA HIERARQUIA  \
#  MAPA
#  Carta geológica da folha Rio Escondido        3826  PZco   Formação
#
#                                                         NOME  \
#  MAPA
#  Carta geológica da folha Rio Escondido  Formação Corumbiara
#
#                                                                            AMBIENTE_T  \
#  MAPA
#  Carta geológica da folha Rio Escondido  Bacia de ambiente divergente e/ou intraplaca
#
#                                                    SUB_AMBIEN SIGLA_PAI  \
#  MAPA
#  Carta geológica da folha Rio Escondido  Bacia intracratônica     Vazio
#
#                                         NOME_PAI  \
#  MAPA
#  Carta geológica da folha Rio Escondido    Vazio
#
#                                                                                    LEGENDA  \
#  MAPA
#  Carta geológica da folha Rio Escondido  Conglomerado polimítico estratificado, compost...
#
#                                          ...      EON_MAX     ERA_MIN  \
#  MAPA                                    ...
#  Carta geológica da folha Rio Escondido  ...  Fanerozóico  Paleozóico
#
#                                             ERA_MAX  SISTEMA_MI  SISTEMA_MA  \
#  MAPA
#  Carta geológica da folha Rio Escondido  Paleozóico    Permiano   Cambriano
#
#                                            EPOCA_MIN EPOCA_MAX SIGLAS_HIS  \
#  MAPA
#  Carta geológica da folha Rio Escondido  Cisuraliano  Inferior        Jco
#
#                                         SHAPE_AREA SHAPE_LEN
#  MAPA
#  Carta geológica da folha Rio Escondido   0.000003  0.008001
#
#  [1 rows x 26 columns],
#                                                                                   geometry  \
#  MAPA
#  Carta geológica da folha Ilha do Porto  POLYGON ((-60.15346 -13.50000, -60.16734 -13.5...
#
#                                          ID_UNIDADE    SIGLA HIERARQUIA  \
#  MAPA
#  Carta geológica da folha Ilha do Porto        3833  MP1comt    Unidade
#
#                                                                    NOME  \
#  MAPA
#  Carta geológica da folha Ilha do Porto  Unidade Colorado, metapelítica
#
#                                         AMBIENTE_T  \
#  MAPA
#  Carta geológica da folha Ilha do Porto    Orógeno
#
#                                                                                 SUB_AMBIEN  \
#  MAPA
#  Carta geológica da folha Ilha do Porto  Faixa ogênica relacionada a bacia de ambiente ...
#
#                                         SIGLA_PAI                   NOME_PAI  \
#  MAPA
#  Carta geológica da folha Ilha do Porto     MP1co  MP1co - Complexo Colorado
#
#                                                                                    LEGENDA  \
#  MAPA
#  Carta geológica da folha Ilha do Porto  Xistos pelíticos dominados por sillimanita-gra...
#
#                                          ...       EON_MAX           ERA_MIN  \
#  MAPA                                    ...
#  Carta geológica da folha Ilha do Porto  ...  Proterozóico  Mesoproterozóico
#
#                                                   ERA_MAX  SISTEMA_MI  \
#  MAPA
#  Carta geológica da folha Ilha do Porto  Mesoproterozóico   Calimiano
#
#                                          SISTEMA_MA EPOCA_MIN EPOCA_MAX  \
#  MAPA
#  Carta geológica da folha Ilha do Porto   Calimiano     Médio     Médio
#
#                                         SIGLAS_HIS SHAPE_AREA SHAPE_LEN
#  MAPA
#  Carta geológica da folha Ilha do Porto    MP2comt   0.000026   0.02999
#
#  [1 rows x 26 columns],
#                                                                                               geometry  \
#  MAPA
#  Carta geológica da folha Porto Triunfo SD.20-X-B-V  POLYGON ((-60.50000 -12.96579, -60.50000 -13.0...
#
#                                                      ID_UNIDADE  SIGLA  \
#  MAPA
#  Carta geológica da folha Porto Triunfo SD.20-X-B-V        3825  NP3pr
#
#                                                     HIERARQUIA  \
#  MAPA
#  Carta geológica da folha Porto Triunfo SD.20-X-B-V   Formação
#
#                                                                        NOME  \
#  MAPA
#  Carta geológica da folha Porto Triunfo SD.20-X-B-V  Formação Pedra Redonda
#
#                                                     AMBIENTE_T SUB_AMBIEN  \
#  MAPA
#  Carta geológica da folha Porto Triunfo SD.20-X-B-V      Vazio      Vazio
#
#                                                     SIGLA_PAI  \
#  MAPA
#  Carta geológica da folha Porto Triunfo SD.20-X-B-V     NP3pb
#
#                                                                         NOME_PAI  \
#  MAPA
#  Carta geológica da folha Porto Triunfo SD.20-X-B-V  NP3pb - Grupo Pimenta Bueno
#
#                                                                                                LEGENDA  \
#  MAPA
#  Carta geológica da folha Porto Triunfo SD.20-X-B-V  Paraconglomerado e arenito de granulometria gr...
#
#                                                      ...       EON_MAX  \
#  MAPA                                                ...
#  Carta geológica da folha Porto Triunfo SD.20-X-B-V  ...  Proterozóico
#
#                                                              ERA_MIN  \
#  MAPA
#  Carta geológica da folha Porto Triunfo SD.20-X-B-V  Neoproterozóico
#
#                                                              ERA_MAX  \
#  MAPA
#  Carta geológica da folha Porto Triunfo SD.20-X-B-V  Neoproterozóico
#
#                                                      SISTEMA_MI  SISTEMA_MA  \
#  MAPA
#  Carta geológica da folha Porto Triunfo SD.20-X-B-V  Ediacarano  Ediacarano
#
#                                                       EPOCA_MIN   EPOCA_MAX  \
#  MAPA
#  Carta geológica da folha Porto Triunfo SD.20-X-B-V  Pridoliano  Pridoliano
#
#                                                     SIGLAS_HIS SHAPE_AREA  \
#  MAPA
#  Carta geológica da folha Porto Triunfo SD.20-X-B-V       C1pr   0.000259
#
#                                                     SHAPE_LEN
#  MAPA
#  Carta geológica da folha Porto Triunfo SD.20-X-B-V  0.176919
#
#  [1 rows x 26 columns],
#                                                                                   geometry  \
#  MAPA
#  Carta geológica da folha NA-20-Z-D-III  POLYGON ((-60.37144 0.50000, -60.46969 0.50000...
#
#                                          ID_UNIDADE           SIGLA HIERARQUIA  \
#  MAPA
#  Carta geológica da folha NA-20-Z-D-III        7228  PP3_gamma_abic     Fácies
#
#                                                           NOME AMBIENTE_T  \
#  MAPA
#  Carta geológica da folha NA-20-Z-D-III  Fácies Cinco Estrelas      Vazio
#
#                                         SUB_AMBIEN      SIGLA_PAI  \
#  MAPA
#  Carta geológica da folha NA-20-Z-D-III      Vazio  PP3_gamma_abi
#
#                                                                    NOME_PAI  \
#  MAPA
#  Carta geológica da folha NA-20-Z-D-III  PP3_gamma_abi - Corpo Igarapé Azul
#
#                                                                                    LEGENDA  \
#  MAPA
#  Carta geológica da folha NA-20-Z-D-III  Monzogranitos, com subordinados sienogranitos,...
#
#                                          ...       EON_MAX            ERA_MIN  \
#  MAPA                                    ...
#  Carta geológica da folha NA-20-Z-D-III  ...  Proterozóico  Paleoproterozóico
#
#                                                    ERA_MAX  SISTEMA_MI  \
#  MAPA
#  Carta geológica da folha NA-20-Z-D-III  Paleoproterozóico  Orosiriano
#
#                                          SISTEMA_MA   EPOCA_MIN   EPOCA_MAX  \
#  MAPA
#  Carta geológica da folha NA-20-Z-D-III  Orosiriano  Furongiano  Furongiano
#
#                                         SIGLAS_HIS SHAPE_AREA SHAPE_LEN
#  MAPA
#  Carta geológica da folha NA-20-Z-D-III      Vazio    0.01012   0.45852
#
#  [1 rows x 26 columns],
#                                                                                  geometry  \
#  MAPA
#  Carta geológica da folha Novo Paraíso  POLYGON ((-60.01787 1.00000, -60.04230 1.00000...
#
#                                         ID_UNIDADE           SIGLA HIERARQUIA  \
#  MAPA
#  Carta geológica da folha Novo Paraíso        7224  PP3_gamma_abcj     Fácies
#
#                                                       NOME AMBIENTE_T  \
#  MAPA
#  Carta geológica da folha Novo Paraíso  Fácies Jaburuzinho      Vazio
#
#                                        SUB_AMBIEN      SIGLA_PAI  \
#  MAPA
#  Carta geológica da folha Novo Paraíso      Vazio  PP3_gamma_abc
#
#                                                              NOME_PAI  \
#  MAPA
#  Carta geológica da folha Novo Paraíso  PP3_gamma_abc - Corpo Caroebe
#
#                                                                                   LEGENDA  \
#  MAPA
#  Carta geológica da folha Novo Paraíso  Hornblenda-biotita quartzo dioritos, quartzo m...
#
#                                         ...       EON_MAX            ERA_MIN  \
#  MAPA                                   ...
#  Carta geológica da folha Novo Paraíso  ...  Proterozóico  Paleoproterozóico
#
#                                                   ERA_MAX  SISTEMA_MI  \
#  MAPA
#  Carta geológica da folha Novo Paraíso  Paleoproterozóico  Orosiriano
#
#                                         SISTEMA_MA   EPOCA_MIN   EPOCA_MAX  \
#  MAPA
#  Carta geológica da folha Novo Paraíso  Orosiriano  Furongiano  Furongiano
#
#                                        SIGLAS_HIS SHAPE_AREA SHAPE_LEN
#  MAPA
#  Carta geológica da folha Novo Paraíso      Vazio   0.003175  0.254074
#
#  [1 rows x 26 columns],
#                                                                                       geometry  \
#  MAPA
#  Carta geológica da folha Santa Rita - UFMT  POLYGON ((-59.42658 -16.28096, -59.47305 -16.2...
#
#                                              ID_UNIDADE SIGLA HIERARQUIA  \
#  MAPA
#  Carta geológica da folha Santa Rita - UFMT        1505  Q1pc     Fácies
#
#                                                                                 NOME  \
#  MAPA
#  Carta geológica da folha Santa Rita - UFMT  Fácies Pantanal, depósitos coluvionares
#
#                                             AMBIENTE_T SUB_AMBIEN SIGLA_PAI  \
#  MAPA
#  Carta geológica da folha Santa Rita - UFMT      Vazio      Vazio      Q12p
#
#                                                              NOME_PAI  \
#  MAPA
#  Carta geológica da folha Santa Rita - UFMT  Q12p - Formação Pantanal
#
#                                                                                        LEGENDA  \
#  MAPA
#  Carta geológica da folha Santa Rita - UFMT  Depósitos de talus, cones aluvionais e coluvia...
#
#                                              ...      EON_MAX    ERA_MIN  \
#  MAPA                                        ...
#  Carta geológica da folha Santa Rita - UFMT  ...  Fanerozóico  Cenozóico
#
#                                                ERA_MAX  SISTEMA_MI  SISTEMA_MA  \
#  MAPA
#  Carta geológica da folha Santa Rita - UFMT  Cenozóico     Neogeno     Neogeno
#
#                                             EPOCA_MIN EPOCA_MAX SIGLAS_HIS  \
#  MAPA
#  Carta geológica da folha Santa Rita - UFMT  Superior  Superior      Vazio
#
#                                             SHAPE_AREA SHAPE_LEN
#  MAPA
#  Carta geológica da folha Santa Rita - UFMT   0.000012   0.02076
#
#  [1 rows x 26 columns],
#                                                                                          geometry  \
#  MAPA
#  Carta geológica da folha Santa Barbara - UFMT  POLYGON ((-59.00795 -16.00000, -59.05809 -16.0...
#
#                                                 ID_UNIDADE  SIGLA HIERARQUIA  \
#  MAPA
#  Carta geológica da folha Santa Barbara - UFMT        3205  MP3mc   Formação
#
#                                                                      NOME  \
#  MAPA
#  Carta geológica da folha Santa Barbara - UFMT  Formação Morro Cristalino
#
#                                                AMBIENTE_T SUB_AMBIEN SIGLA_PAI  \
#  MAPA
#  Carta geológica da folha Santa Barbara - UFMT      Vazio      Vazio      MP3a
#
#                                                             NOME_PAI  \
#  MAPA
#  Carta geológica da folha Santa Barbara - UFMT  MP3a - Grupo Aguapeí
#
#                                                                                           LEGENDA  \
#  MAPA
#  Carta geológica da folha Santa Barbara - UFMT  Quartzo arenito seixosos com arenito fino subo...
#
#                                                 ...       EON_MAX  \
#  MAPA                                           ...
#  Carta geológica da folha Santa Barbara - UFMT  ...  Proterozóico
#
#                                                          ERA_MIN  \
#  MAPA
#  Carta geológica da folha Santa Barbara - UFMT  Mesoproterozóico
#
#                                                          ERA_MAX  SISTEMA_MI  \
#  MAPA
#  Carta geológica da folha Santa Barbara - UFMT  Mesoproterozóico   Esteniano
#
#                                                 SISTEMA_MA     EPOCA_MIN  \
#  MAPA
#  Carta geológica da folha Santa Barbara - UFMT   Esteniano  Landoveriano
#
#                                                    EPOCA_MAX SIGLAS_HIS  \
#  MAPA
#  Carta geológica da folha Santa Barbara - UFMT  Landoveriano      Vazio
#
#                                                SHAPE_AREA SHAPE_LEN
#  MAPA
#  Carta geológica da folha Santa Barbara - UFMT   0.044557  1.440886
#
#  [1 rows x 26 columns],
#                                                                                    geometry  \
#  MAPA
#  Carta geológica da folha Serra da Borda  POLYGON ((-59.51040 -15.00000, -59.51253 -15.0...
#
#                                           ID_UNIDADE SIGLA HIERARQUIA  \
#  MAPA
#  Carta geológica da folha Serra da Borda        2139   NQi    Unidade
#
#                                                                                      NOME  \
#  MAPA
#  Carta geológica da folha Serra da Borda  Unidade Coberturas sedimentares indiferenciadas
#
#                                          AMBIENTE_T SUB_AMBIEN SIGLA_PAI  \
#  MAPA
#  Carta geológica da folha Serra da Borda      Vazio      Vazio     Vazio
#
#                                          NOME_PAI  \
#  MAPA
#  Carta geológica da folha Serra da Borda    Vazio
#
#                                                                                     LEGENDA  \
#  MAPA
#  Carta geológica da folha Serra da Borda  Sedimentos com granulometria variando de casca...
#
#                                           ...      EON_MAX    ERA_MIN  \
#  MAPA                                     ...
#  Carta geológica da folha Serra da Borda  ...  Fanerozóico  Cenozóico
#
#                                             ERA_MAX  SISTEMA_MI  SISTEMA_MA  \
#  MAPA
#  Carta geológica da folha Serra da Borda  Cenozóico     Neogeno     Neogeno
#
#                                          EPOCA_MIN EPOCA_MAX SIGLAS_HIS  \
#  MAPA
#  Carta geológica da folha Serra da Borda  Superior  Superior      Vazio
#
#                                          SHAPE_AREA SHAPE_LEN
#  MAPA
#  Carta geológica da folha Serra da Borda   0.001476  0.230665
#
#  [1 rows x 26 columns],
#                                                                              geometry  \
#  MAPA
#  Carta geológica da folha Rio Novo  POLYGON ((-59.50000 -14.44004, -59.50000 -14.5...
#
#                                     ID_UNIDADE SIGLA HIERARQUIA  \
#  MAPA
#  Carta geológica da folha Rio Novo        2139   NQi    Unidade
#
#                                                                                NOME  \
#  MAPA
#  Carta geológica da folha Rio Novo  Unidade Coberturas sedimentares indiferenciadas
#
#                                    AMBIENTE_T SUB_AMBIEN SIGLA_PAI NOME_PAI  \
# ...
#
#                                     ...       EON_MAX          ERA_MIN  \
#  MAPA                               ...
#  Carta geológica da folha Macaúbas  ...  Proterozóico  Neoproterozóico
#
#                                             ERA_MAX   SISTEMA_MI  SISTEMA_MA  \
#  MAPA
#  Carta geológica da folha Macaúbas  Neoproterozóico  Criogeniano     Toniano
#
#                                      EPOCA_MIN    EPOCA_MAX  \
#  MAPA
#  Carta geológica da folha Macaúbas  Ludlowiano  Wenloquiano
#
#                                                      SIGLAS_HIS SHAPE_AREA  \
#  MAPA
#  Carta geológica da folha Macaúbas  MP1og, MP3sp, NP12og, MP3og   0.000031
#
#                                    SHAPE_LEN
#  MAPA
#  Carta geológica da folha Macaúbas  0.052671
#
#  [1 rows x 26 columns],
#                                                                                       geometry  \
#  MAPA
#  Carta geológica da folha Riacho de Santana  POLYGON ((-42.84460 -14.00000, -42.84717 -14.0...
#
#                                              ID_UNIDADE  SIGLA HIERARQUIA  \
#  MAPA
#  Carta geológica da folha Riacho de Santana        5573  A2gfo    Unidade
#
#                                                                                     NOME  \
#  MAPA
#  Carta geológica da folha Riacho de Santana  Unidade Favelândia, ortognaisse migmatítico
#
#                                             AMBIENTE_T SUB_AMBIEN SIGLA_PAI  \
#  MAPA
#  Carta geológica da folha Riacho de Santana      Vazio      Vazio      A2gf
#
#                                                                                      NOME_PAI  \
#  MAPA
#  Carta geológica da folha Riacho de Santana  A2gf - Complexo gnáissico-migmatítico Favelândia
#
#                                                                                        LEGENDA  \
#  MAPA
#  Carta geológica da folha Riacho de Santana  (Hornblenda)-biotita ortognaisse migmatítico, ...
#
#                                              ...   EON_MAX        ERA_MIN  \
#  MAPA                                        ...
#  Carta geológica da folha Riacho de Santana  ...  Arqueano  Paleoarqueano
#
#                                                    ERA_MAX  SISTEMA_MI  \
#  MAPA
#  Carta geológica da folha Riacho de Santana  Paleoarqueano       Vazio
#
#                                              SISTEMA_MA EPOCA_MIN EPOCA_MAX  \
#  MAPA
#  Carta geológica da folha Riacho de Santana       Vazio     Vazio     Vazio
#
#                                             SIGLAS_HIS SHAPE_AREA SHAPE_LEN
#  MAPA
#  Carta geológica da folha Riacho de Santana      Vazio   0.000071  0.045037
#
#  [1 rows x 26 columns],
#                                                                             geometry  \
#  MAPA
#  Carta geológica da folha Boquira  POLYGON ((-42.53116 -13.00000, -42.54377 -13.0...
#
#                                    ID_UNIDADE      SIGLA  HIERARQUIA  \
#  MAPA
#  Carta geológica da folha Boquira        5544  MP12nfacg  Litofácies
#
#                                                                       NOME  \
#  MAPA
#  Carta geológica da folha Boquira  Litofácies Fazendinha, metaconglomerado
#
#                                   AMBIENTE_T SUB_AMBIEN SIGLA_PAI  \
#  MAPA
#  Carta geológica da folha Boquira      Vazio      Vazio    MP12nf
#
#                                                        NOME_PAI  \
#  MAPA
#  Carta geológica da folha Boquira  MP12nf - Formação Fazendinha
#
#                                                                              LEGENDA  \
#  MAPA
#  Carta geológica da folha Boquira  Metaquartzarenito sericítico e biotítico silic...
#
#                                    ...       EON_MAX           ERA_MIN  \
#  MAPA                              ...
#  Carta geológica da folha Boquira  ...  Proterozóico  Mesoproterozóico
#
#                                             ERA_MAX  SISTEMA_MI  SISTEMA_MA  \
#  MAPA
#  Carta geológica da folha Boquira  Mesoproterozóico   Ectasiano   Calimiano
#
#                                   EPOCA_MIN EPOCA_MAX SIGLAS_HIS SHAPE_AREA  \
#  MAPA
#  Carta geológica da folha Boquira  Superior     Médio      Vazio    0.00015
#
#                                   SHAPE_LEN
#  MAPA
#  Carta geológica da folha Boquira  0.174448
#
#  [1 rows x 26 columns],
#                                                                                            geometry  \
#  MAPA
#  Carta geológica da folha Oliveira dos Brejinhos  POLYGON ((-42.95923 -12.50000, -42.96246 -12.5...
#
#                                                   ID_UNIDADE  SIGLA HIERARQUIA  \
#  MAPA
#  Carta geológica da folha Oliveira dos Brejinhos        1067  MP1mr   Formação
#
#                                                                  NOME  \
#  MAPA
#  Carta geológica da folha Oliveira dos Brejinhos  Formação Bom Retiro
#
#                                                  AMBIENTE_T SUB_AMBIEN  \
#  MAPA
#  Carta geológica da folha Oliveira dos Brejinhos      Vazio      Vazio
#
#                                                  SIGLA_PAI  \
#  MAPA
#  Carta geológica da folha Oliveira dos Brejinhos      MP1m
#
#                                                                  NOME_PAI  \
#  MAPA
#  Carta geológica da folha Oliveira dos Brejinhos  MP1m - Grupo São Marcos
#
#                                                                                             LEGENDA  \
#  MAPA
#  Carta geológica da folha Oliveira dos Brejinhos  Metaquartzarenito bem selecionado, às vezes bi...
#
#                                                   ...       EON_MAX  \
#  MAPA                                             ...
#  Carta geológica da folha Oliveira dos Brejinhos  ...  Proterozóico
#
#                                                            ERA_MIN  \
#  MAPA
#  Carta geológica da folha Oliveira dos Brejinhos  Mesoproterozóico
#
#                                                            ERA_MAX  SISTEMA_MI  \
#  MAPA
#  Carta geológica da folha Oliveira dos Brejinhos  Mesoproterozóico   Calimiano
#
#                                                   SISTEMA_MA EPOCA_MIN  \
#  MAPA
#  Carta geológica da folha Oliveira dos Brejinhos   Calimiano     Médio
#
#                                                  EPOCA_MAX     SIGLAS_HIS  \
#  MAPA
#  Carta geológica da folha Oliveira dos Brejinhos     Médio  PP4mr, P4M1bb
#
#                                                  SHAPE_AREA SHAPE_LEN
#  MAPA
#  Carta geológica da folha Oliveira dos Brejinhos   0.000027  0.020602
#
#  [1 rows x 26 columns],
#                                                                                      geometry  \
#  MAPA
#  Carta geológica da folha Ouricuri do Ouro  POLYGON ((-42.25706 -12.50000, -42.29193 -12.5...
#
#                                             ID_UNIDADE   SIGLA    HIERARQUIA  \
#  MAPA
#  Carta geológica da folha Ouricuri do Ouro        4099  N12dl2  Não definida
#
#                                                                        NOME  \
#  MAPA
#  Carta geológica da folha Ouricuri do Ouro  Depósitos detrito-lateríticos 2
#
#                                            AMBIENTE_T SUB_AMBIEN SIGLA_PAI  \
#  MAPA
#  Carta geológica da folha Ouricuri do Ouro      Vazio      Vazio     Vazio
#
#                                            NOME_PAI  \
#  MAPA
#  Carta geológica da folha Ouricuri do Ouro    Vazio
#
#                                                                                       LEGENDA  \
#  MAPA
#  Carta geológica da folha Ouricuri do Ouro  Sedimentos areno-argilosos, finos a médios, em...
#
#                                             ...      EON_MAX    ERA_MIN  \
#  MAPA                                       ...
#  Carta geológica da folha Ouricuri do Ouro  ...  Fanerozóico  Cenozóico
#
#                                               ERA_MAX  SISTEMA_MI  SISTEMA_MA  \
#  MAPA
#  Carta geológica da folha Ouricuri do Ouro  Cenozóico     Neogeno     Neogeno
#
#                                            EPOCA_MIN EPOCA_MAX   SIGLAS_HIS  \
#  MAPA
#  Carta geológica da folha Ouricuri do Ouro  Superior  Superior  NQdl2, Ndl2
#
#                                            SHAPE_AREA SHAPE_LEN
#  MAPA
#  Carta geológica da folha Ouricuri do Ouro   0.000003  0.009855
#
#  [1 rows x 26 columns],
#                                                                              geometry  \
#  MAPA
#  Carta geológica da folha Ipupiara  POLYGON ((-42.91970 -12.00000, -42.93250 -12.0...
#
#                                     ID_UNIDADE         SIGLA HIERARQUIA  \
#  MAPA
#  Carta geológica da folha Ipupiara        4127  PP2_gamma_ib      Corpo
#
#                                                             NOME AMBIENTE_T  \
#  MAPA
#  Carta geológica da folha Ipupiara  Corpo Granitóide de Ibitiara    Orógeno
#
#                                         SUB_AMBIEN SIGLA_PAI NOME_PAI  \
#  MAPA
#  Carta geológica da folha Ipupiara  Arco magmático     Vazio    Vazio
#
#                                                                               LEGENDA  \
#  MAPA
#  Carta geológica da folha Ipupiara  Granodiorito e tonalito isotrópicos com fenocr...
#
#                                     ...       EON_MAX            ERA_MIN  \
#  MAPA                               ...
#  Carta geológica da folha Ipupiara  ...  Proterozóico  Paleoproterozóico
#
#                                               ERA_MAX  SISTEMA_MI  SISTEMA_MA  \
#  MAPA
#  Carta geológica da folha Ipupiara  Paleoproterozóico    Riaciano    Riaciano
#
#                                    EPOCA_MIN EPOCA_MAX SIGLAS_HIS SHAPE_AREA  \
#  MAPA
#  Carta geológica da folha Ipupiara   Série 3   Série 3      Vazio    0.00002
#
#                                    SHAPE_LEN
#  MAPA
#  Carta geológica da folha Ipupiara  0.019427
#
#  [1 rows x 26 columns],
#  'Gentio do Ouro',
#  'Barra do Mendes',
#  'Central',
#  'São Raimundo Nonato',
#  'Remanso',
#  'Bom Jardim',
#  'Barragem',
#  'Rio das Ostras - UERJ',
#  'Macaé - UERJ',
#  'Itaperuna - UERJ',
#  'São Fidelis - UERJ',
#  'Espera Feliz - UFMG',
#  'Manhumirim - UFMG',
#  'Itaobim',
#  'Comercinho',
#  'Jequitinhonha',
#  'Joaima',
#  'Condeúba',
#  'Brumado',
#  'Tanhaçu',
#  'Rio de Contas',
#  'Tombador',
#  'Lagoa do Alegre',
#  'Casa Nova',
#  'Serra dos Brejinhos',
#  'Riacho Queimadas',
#  'Parambu',
#  'Guarapari - UFES',
#  'Vitória - UFES',
#  'São Gabriel da Palha',
#  'Aracruz - UFES',
#  'Linhares',
#  'Mantena - UFMG',
#  'Ecoporanga - UFMG',
#  'Nova Venécia - UFMG',
#  'Montanha - UFMG',
#  'Almenara',
#  'Rio do Prado',
#  'Manoel Vitorino',
#  'Maracás',
#  'Jequié',
#  'Ruy Barbosa',
#  'Itaberaba',
#  'Piritiba',
#  'Jacobina',
#  'Mirangaba',
#  'Caldeirão Grande',
#  'Mundo Novo',
#  'Brejão da Caatinga',
#  'Campo Formoso',
#  'Senhor do Bonfim',
#  'Campo dos Cavalos',
#  'Petrolina',
#  'Itamontinga',
#  'Juremal',
#  'Cristália',
#  'Cruz de Malta',
#  'Fronteiras',
#  'Ouricuri',
#  'Pio IX - UFC',
#  'Novo Oriente',
#  'Crateus',
#  'Independência',
#  'Várzea do Boi',
#  'Ipu - UFPA',
#  'Ipueiras',
#  'Granja -UFC',
#  'Sobral - UFPA',
#  'Irauçuba',
#  'Regência - UFES',
#  'Ipiau - UFBA',
#  'Amargosa - UFBA',
#  'Jaguaquara - UFBA',
#  'Andorinha',
#  'Monte Santo',
#  'Barro Vermelho',
#  'Pinhões',
#  'Uauá',
#  'Macururé',
#  'Santa Maria da Boa Vista',
#  'Parnamirim',
#  'Chorrochó',
#  'Salgueiro',
#  'Bodocó',
#  'Jardim',
#  'Cedro',
#  'Mombaça',
#  'Boa Viagem - UFC',
#  'Senador Pompeu',
#  'Quixeramobim - UFC',
#  'Taperuaba - UFC',
#  'Itatira - UFC',
#  'Quixadá 100.000',
#  'Itapipoca',
#  'Caimbé',
#  'Ribeira do Pombal',
#  'Jeremoabo',
#  'Cícero Dantas',
#  'Mirandiba',
#  'Serra Talhada - UFPE',
#  'Cajazeiras',
#  'Pau dos Ferros - UFRN',
#  'Banabuiú',
#  'Jaguaretama - UFC',
#  'Baturité',
#  'Itapiúna',
#  'Poço da Cruz - UFPE',
#  'Sertânia',
#  'Buíque',
#  'Apodi - UFRN',
#  'Mossoró - UFRN',
#  'Pesqueira',
#  'Venturosa - UFPE',
#  'Belo Jardim - UFPE',
#  'Garanhuns - UFPE',
#  'Juazeirinho',
#  'Santa Cruz do Capibaribe',
#  'Boqueirão',
#  'Currais Novos',
#  'Jardim do Seridó - UFRN',
#  'rsos minerais da folha Santa Cruz',
#  'Macau - UFRN',
#  'Jandaira - UFRN',
#  'rsos minerais da folha Lajes',
#  'Surubim - UFPE',
#  'Campina Grande',
#  'Sapé - UFPE',
#  'São José do Campestre-UnB',
#  'Solânea - UFPE',
#  'São José do Mipibu',
#  'Guarabira - UFPE',
#  'Cabedelo - UFPE',
#  'João Camara - UnB',
#  'Natal - UFRN',
#  'Touros - UFRN',
#  'Itamaracá - UFPE',
#  'Caiana']

# %%
folha=lista_nome
indice=0

for i in lista_nome:
    print(i)
    folha[indice] = litologia_1kk[litologia_1kk['MAPA'].str.contains(i)].dissolve('MAPA')
    indice+=1
# Out:
# Contamana
# Javari
# Rio Branco
# Juruá
# Içá
# Pico da Neblina
# Guaporé
# Porto Velho
# Purus
# Manaus
# Boa Vista
# Corumbá
# Cuiabá
# Juruena
# Tapajós
# Santarém
# Tumucumaque
# Uruguaiana
# Campo Grande
# Asunción
# Lagoa Mirim
# Porto Alegre
# Curitiba
# Paranapanema
# Goiânia
# Goiás
# Tocantins
# Araguaia
# Belém
# Macapá
# Iguape
# Rio de Janeiro
# Belo Horizonte
# Brasília
# Rio São Francisco
# Teresina
# São Luis
# Vitória
# Rio Doce
# Salvador
# Aracaju
# Jaguaribe
# Fortaleza
# Recife
# Natal

# %%
folha[31].plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <AxesSubplot:>

# %%
lista_mapa = list(litologia_100k.MAPA.unique())
lista_mapa
# Out:
# ['Carta geológica da folha Paulo Saldanha',
#  'Carta geológica da folha Rio Tanaru - SD.20-X-B-IV',
#  'Carta geológica da folha Roncador',
#  'Carta geológica da folha Rio Pardo',
#  'Carta geológica da folha Pimenta Bueno',
#  'Carta geológica da folha Serra da Providência',
#  'Carta geológica da folha Ji Paraná',
#  'Carta geológica da folha Vila Nova',
#  'Carta geológica da folha Vila de Tepequém',
#  'Carta geológica da folha Betânia - UFMT',
#  'Carta geológica da folha Rio Escondido',
#  'Carta geológica da folha Ilha do Porto',
#  'Carta geológica da folha Porto Triunfo SD.20-X-B-V',
#  'Carta geológica da folha NA-20-Z-D-III',
#  'Carta geológica da folha Novo Paraíso',
#  'Carta geológica da folha Santa Rita - UFMT',
#  'Carta geológica da folha Santa Barbara - UFMT',
#  'Carta geológica da folha Serra da Borda',
#  'Carta geológica da folha Rio Novo',
#  'Carta geológica da folha Rio Pindaituba - UFMT',
#  'Carta geológica da folha Vila Oeste',
#  'Carta geológica da folha Jauru - UFMT',
#  'Carta geológica da folha Rio Branco - UFMT',
#  'Carta geológica da folha Ilha Porto Escondido',
#  'Carta geológica da folha Colônia São Lourenço',
#  'Carta geológica da folha Fazenda Santa Otília',
#  'Carta geológica da folha Aldeia Tomázia',
#  'Carta geológica da folha Rio Perdido',
#  'Carta geológica da folha Fazenda Margarida',
#  'Carta geológica da folha Vila Campão',
#  'Carta geológica da folha São Domingos',
#  'Carta geológica da folha Rio Ratão',
#  'Carta geológica da folha Cuiú-Cuiú',
#  'Carta geológica da folha Cachoeira Seca',
#  'Carta geológica da folha Vila Planalto',
#  'Carta geológica da folha Ilha Mambuai',
#  'Carta geológica da folha Uruá',
#  'Carta geológica da folha Barão de Melgaço - UFMT',
#  'Carta geológica da folha Rio Nhandu',
#  'Carta geológica da folha Jardim do Ouro',
#  'Carta geológica da folha Igrejinha - UNISINOS',
#  'Carta geológica da folha Bagé',
#  'Carta geológica da folha Aceguá',
#  'Carta geológica da folha Lagoa da Meia Lua',
#  'Carta geológica da folha Brasilândia',
#  'Carta geológica da folha Cacimba',
#  'Carta geológica da folha Paranatinga',
#  'Carta geológica da folha Rio Braço Sul',
#  'Carta geológica da folha Serra do Cachimbo',
#  'Carta geológica da folha Curral de Pedras',
#  'Carta geológica da folha Arroio Grande',
#  'Carta geológica da folha Jaguarão',
#  'Carta geológica da folha Passo São Diogo',
#  'Carta geológica da folha Hulha Negra',
#  'Carta geológica da folha Pinheiro Machado',
#  'Carta geológica da folha Lavras do Sul',
#  'Carta geológica da folha Santa Maria - RS',
#  'Carta geológica da folha Sobradinho',
#  'Carta geológica da folha Agudo',
#  'Carta geológica da folha Três Passos',
#  'Carta geológica da folha Frederico Westphalen',
#  'Carta geológica da folha Matarazzo',
#  'Carta geológica da folha Pelotas',
#  'Carta geológica da folha Pedro Osório',
#  'Carta geológica da folha Placa Nativa',
#  'Carta geológica da folha Nova Xavantina',
#  'Carta geológica da folha Rio Bacajá - UFPR',
#  'Carta geológica da folha Gravataí - UFRGS',
#  'Carta geológica da folha Sanclerlândia',
#  'Carta geológica da folha Rio Inajá',
#  'Carta geológica da folha São João Batista',
#  'Carta geológica da folha Marajoara',
#  'Carta geológica da folha Caldeirão',
#  'Carta geológica da folha Itararé',
#  'Carta geológica da folha Cerro Azul',
#  'Carta geológica da folha Itaberaí',
#  'Carta geológica da folha Nazário',
#  'Carta geológica da folha Santa Teresinha de Goiás - UNB',
#  'Carta geológica da folha Campinorte - UNB',
#  'Carta geológica da folha Novo Planalto',
#  'Carta geológica da folha Porangatu - UNB',
#  'Carta geológica da folha Serra Pelada',
#  'Carta geológica da folha Apiaí',
#  'Carta geológica da folha Eldorado Paulista',
#  'Carta geológica da folha Mata Azul',
#  'Carta geológica da folha Belém 100.000',
#  'Carta geológica da folha Iguape',
#  'Carta geológica da folha Registro',
#  'Carta geológica da folha Monte Carmelo',
#  'Carta geológica da folha Coromandel',
#  'Carta geológica da folha Serra da Tiririca',
#  'Carta geológica da folha Guarda Mor',
#  'Carta geológica da folha Paracatu',
#  'Carta geológica da folha Cabeceira Grande',
#  'Carta geológica da folha Ribeirão Arrojado',
#  'Carta geológica da folha Cavalcante - UNB',
#  'Carta geológica da folha Imperatriz',
#  'Carta geológica da folha Alpinópolis - UERJ',
#  'Carta geológica da folha Lagamar',
#  'Carta geológica da folha Patos de Minas',
#  'Carta geológica da folha Arrenegado',
#  'Carta geológica da folha Unaí',
#  'Carta geológica da folha Serra da Aldeia',
#  'Carta geológica da folha Monte Alegre de Goiás - UNB',
#  'Carta geológica da folha Nova Roma - UNB',
#  'Carta geológica da folha Centro Novo do Maranhão',
#  'Carta geológica da folha Santa Luzia do Pará',
#  'Carta geológica da folha Cândido Mendes',
#  'Carta geológica da folha Campos do Jordão - UFRJ/FUJB',
#  'Carta geológica da folha Pouso Alegre - UFRJ/FUJB',
#  'Carta geológica da folha Itajubá - UFRJ',
#  'Carta geológica da folha Pindamonhangaba - UFRJ/FUJB',
#  'Carta geológica da folha Campo Belo - UFOP',
#  'Carta geológica da folha Machado - UFRJ/FUJB',
#  'Carta geológica da folha Alfenas - UFRJ/FUJB',
#  'Carta geológica da folha Varginha - UFRJ',
#  'Carta geológica da folha Nepomuceno - UFRJ',
#  'Carta geológica da folha Guapé - UERJ',
#  'Carta geológica da folha Piumhi - UFRJ',
#  'Carta geológica da folha Divinópolis',
#  'Carta geológica da folha Bom Despacho',
#  'Carta geológica da folha Abaeté',
#  'Carta geológica da folha Cristalândia do Piauí',
#  'Carta geológica da folha Angra dos Reis - UERJ',
#  'Carta geológica da folha Santa Rita de Jacutinga - UERJ',
#  'Carta geológica da folha Volta Redonda - UERJ',
#  'Carta geológica da folha Oliveira - UFOP',
#  'Carta geológica da folha Entre Rios de Minas',
#  'Carta geológica da folha Igarapé',
#  'Carta geológica da folha Pompéu',
#  'Carta geológica da folha Pará de Minas - UFMG',
#  'Carta geológica da folha Sete Lagoas',
#  'Carta geológica da folha Contagem',
#  'Carta geológica da folha Andrequice - UFMG',
#  'Carta geológica da folha Morro da Garça - UFMG',
#  'Carta geológica da folha Corinto - UFMG',
#  'Carta geológica da folha Curvelo - UFMG',
#  'Carta geológica da folha Serra do Cabral - UFMG',
#  'Carta geológica da folha Jequitaí - UFMG',
#  'Carta geológica da folha Santa Maria da Vitória',
#  'Carta geológica da folha Rio Paraim',
#  'Carta geológica da folha Parnaguá',
#  'Carta geológica da folha Curimatá',
#  'Carta geológica da folha Mansidão',
#  'Carta geológica da folha Baia de Guanabara - UERJ',
#  'Carta geológica da folha Barra do Piraí - UERJ',
#  'Carta geológica da folha Três Rios - UERJ',
#  'Carta geológica da folha Conselheiro Lafaiete',
#  'Carta geológica da folha Baldim',
#  'Carta geológica da folha Belo Horizonte',
#  'Carta geológica da folha Bocaiuva - UFMG',
#  'Carta geológica da folha Montes Claros - UFMG',
#  'Carta geológica da folha Ibotirama',
#  'Carta geológica da folha Barra',
#  'Carta geológica da folha Morpará',
#  'Carta geológica da folha Avelino Lopes',
#  'Carta geológica da folha Cabeças no Tempo',
#  'Carta geológica da folha Peixe',
#  'Carta geológica da folha Nova Friburgo - UERJ',
#  'Carta geológica da folha Cabo Frio - UERJ',
#  'Carta geológica da folha Casimiro de Abreu - UERJ',
#  'Carta geológica da folha Santo Antônio de Pádua - UERJ',
#  'Carta geológica da folha Viçosa - UFMG',
#  'Carta geológica da folha Carangola - UFMG',
#  'Carta geológica da folha Manhuaçú - UFMG',
#  'Carta geológica da folha Monte Azul - UFMG',
#  'Carta geológica da folha Taiobeiras - UFMG',
#  'Carta geológica da folha Caetité - UFBA',
#  'Carta geológica da folha Macaúbas',
#  'Carta geológica da folha Riacho de Santana',
#  'Carta geológica da folha Boquira',
#  'Carta geológica da folha Oliveira dos Brejinhos',
#  'Carta geológica da folha Ouricuri do Ouro',
#  'Carta geológica da folha Ipupiara',
#  'Carta geológica da folha Gentio do Ouro',
#  'Carta geológica da folha Barra do Mendes',
#  'Carta geológica da folha Central',
#  'Carta geológica da folha São Raimundo Nonato',
#  'Carta geológica da folha Remanso',
#  'Carta geológica da folha Bom Jardim',
#  'Carta geológica da folha Barragem',
#  'Carta geológica da folha Rio das Ostras - UERJ',
#  'Carta geológica da folha Macaé - UERJ',
#  'Carta geológica da folha Itaperuna - UERJ',
#  'Carta geológica da folha São Fidelis - UERJ',
#  'Carta geológica da folha Espera Feliz - UFMG',
#  'Carta geológica da folha Manhumirim - UFMG',
#  'Carta geológica da folha Itaobim',
#  'Carta geológica da folha Comercinho',
#  'Carta geológica da folha Jequitinhonha',
#  'Carta geológica da folha Joaima',
#  'Carta geológica da folha Condeúba',
#  'Carta geológica da folha Brumado',
#  'Carta geológica da folha Tanhaçu',
#  'Carta geológica da folha Rio de Contas',
#  'Carta geológica da folha Tombador',
#  'Carta geológica da folha Lagoa do Alegre',
#  'Carta geológica da folha Casa Nova',
#  'Carta geológica da folha Serra dos Brejinhos',
#  'Carta geológica da folha Riacho Queimadas',
#  'Carta geológica da folha Parambu',
#  'Carta geológica da folha Guarapari - UFES',
#  'Carta geológica da folha Vitória - UFES',
#  'Carta geológica da folha São Gabriel da Palha',
#  'Carta geológica da folha Aracruz - UFES',
#  'Carta geológica da folha Linhares',
#  'Carta geológica da folha Mantena - UFMG',
#  'Carta geológica da folha Ecoporanga - UFMG',
#  'Carta geológica da folha Nova Venécia - UFMG',
#  'Carta geológica da folha Montanha - UFMG',
#  'Carta geológica da folha Almenara',
#  'Carta geológica da folha Rio do Prado',
#  'Carta geológica da folha Manoel Vitorino',
#  'Carta geológica da folha Maracás',
#  'Carta geológica da folha Jequié',
#  'Carta geológica da folha Ruy Barbosa',
#  'Carta geológica da folha Itaberaba',
#  'Carta geológica da folha Piritiba',
#  'Carta geológica da folha Jacobina',
#  'Carta geológica da folha Mirangaba',
#  'Carta geológica da folha Caldeirão Grande',
#  'Carta geológica da folha Mundo Novo',
#  'Carta geológica da folha Brejão da Caatinga',
#  'Carta geológica da folha Campo Formoso',
#  'Carta geológica da folha Senhor do Bonfim',
#  'Carta geológica da folha Campo dos Cavalos',
#  'Carta geológica da folha Petrolina',
#  'Carta geológica da folha Itamontinga',
#  'Carta geológica da folha Juremal',
#  'Carta geológica da folha Cristália',
#  'Carta geológica da folha Cruz de Malta',
#  'Carta geológica da folha Fronteiras',
#  'Carta geológica da folha Ouricuri',
#  'Carta geológica da folha Pio IX - UFC',
#  'Carta geológica da folha Novo Oriente',
#  'Carta geológica da folha Crateus',
#  'Carta geológica da folha Independência',
#  'Carta geológica da folha Várzea do Boi',
#  'Carta geológica da folha Ipu - UFPA',
#  'Carta geológica da folha Ipueiras',
#  'Carta geológica da folha Granja -UFC',
#  'Carta geológica da folha Sobral - UFPA',
#  'Carta geológica da folha Irauçuba',
#  'Carta geológica da folha Regência - UFES',
#  'Carta geológica da folha Ipiau - UFBA',
#  'Carta geológica da folha Amargosa - UFBA',
#  'Carta geológica da folha Jaguaquara - UFBA',
#  'Carta geológica da folha Andorinha',
#  'Carta geológica da folha Monte Santo',
#  'Carta geológica da folha Barro Vermelho',
#  'Carta geológica da folha Pinhões',
#  'Carta geológica da folha Uauá',
#  'Carta geológica da folha Macururé',
#  'Carta geológica da folha Santa Maria da Boa Vista',
#  'Carta geológica da folha Parnamirim',
#  'Carta geológica da folha Chorrochó',
#  'Carta geológica da folha Salgueiro',
#  'Carta geológica da folha Bodocó',
#  'Carta geológica da folha Jardim',
#  'Carta geológica da folha Cedro',
#  'Carta geológica da folha Mombaça',
#  'Carta geológica da folha Boa Viagem - UFC',
#  'Carta geológica da folha Senador Pompeu',
#  'Carta geológica da folha Quixeramobim - UFC',
#  'Carta geológica da folha Taperuaba - UFC',
#  'Carta geológica da folha Itatira - UFC',
#  'Carta geológica da folha Quixadá 100.000',
#  'Carta geológica da folha Itapipoca',
#  'Carta geológica da folha Caimbé',
#  'Carta geológica da folha Ribeira do Pombal',
#  'Carta geológica da folha Jeremoabo',
#  'Carta geológica da folha Cícero Dantas',
#  'Carta geológica da folha Mirandiba',
#  'Carta geológica da folha Serra Talhada - UFPE',
#  'Carta geológica da folha Cajazeiras',
#  'Carta geológica da folha Pau dos Ferros - UFRN',
#  'Carta geológica da folha Banabuiú',
#  'Carta geológica da folha Jaguaretama - UFC',
#  'Carta geológica da folha Baturité',
#  'Carta geológica da folha Itapiúna',
#  'Carta geológica da folha Poço da Cruz - UFPE',
#  'Carta geológica da folha Sertânia',
#  'Carta geológica da folha Buíque',
#  'Carta geológica da folha Apodi - UFRN',
#  'Carta geológica da folha Mossoró - UFRN',
#  'Carta geológica da folha Pesqueira',
#  'Carta geológica da folha Venturosa - UFPE',
#  'Carta geológica da folha Belo Jardim - UFPE',
#  'Carta geológica da folha Garanhuns - UFPE',
#  'Carta geológica da folha Juazeirinho',
#  'Carta geológica da folha Santa Cruz do Capibaribe',
#  'Carta geológica da folha Boqueirão',
#  'Carta geológica da folha Currais Novos',
#  'Carta geológica da folha Jardim do Seridó - UFRN',
#  'Carta geológica e de recursos minerais da folha Santa Cruz',
#  'Carta geológica da folha Macau - UFRN',
#  'Carta geológica da folha Jandaira - UFRN',
#  'Carta geológica e de recursos minerais da folha Lajes',
#  'Carta geológica da folha Surubim - UFPE',
#  'Carta geológica da folha Campina Grande',
#  'Carta geológica da folha Sapé - UFPE',
#  'Carta geológica da folha São José do Campestre-UnB',
#  'Carta geológica da folha Solânea - UFPE',
#  'Carta geológica da folha São José do Mipibu',
#  'Carta geológica da folha Guarabira - UFPE',
#  'Carta geológica da folha Cabedelo - UFPE',
#  'Carta geológica da folha João Camara - UnB',
#  'Carta geológica da folha Natal - UFRN',
#  'Carta geológica da folha Touros - UFRN',
#  'Carta geológica da folha Itamaracá - UFPE',
#  'Carta geológica da folha Caiana']

# %%
lista_nome=[]

for mapa in lista_mapa:
    trash=0
    Mapa=[]
    
    for letra in mapa:
        if trash<25:
            trash+=1
            
        else:
            Mapa+=letra
            
    lista_nome += [''.join(Mapa)]

# %%
len(lista_nome)
# Out:
# 311

# %%
folha=lista_nome
indice=0

for i in lista_nome:
    print(i)
    folha[indice] = litologia_100k[litologia_100k['MAPA'].str.contains(i)].dissolve('MAPA')
    indice+=1
# Out:
# Paulo Saldanha
# Rio Tanaru - SD.20-X-B-IV
# Roncador
# Rio Pardo
# Pimenta Bueno
# Serra da Providência
# Ji Paraná
# Vila Nova
# Vila de Tepequém
# Betânia - UFMT
# Rio Escondido
# Ilha do Porto
# Porto Triunfo SD.20-X-B-V
# NA-20-Z-D-III
# Novo Paraíso
# Santa Rita - UFMT
# Santa Barbara - UFMT
# Serra da Borda
# Rio Novo
# Rio Pindaituba - UFMT
# Vila Oeste
# Jauru - UFMT
# Rio Branco - UFMT
# Ilha Porto Escondido
# Colônia São Lourenço
# Fazenda Santa Otília
# Aldeia Tomázia
# Rio Perdido
# Fazenda Margarida
# Vila Campão
# São Domingos
# Rio Ratão
# Cuiú-Cuiú
# Cachoeira Seca
# Vila Planalto
# Ilha Mambuai
# Uruá
# Barão de Melgaço - UFMT
# Rio Nhandu
# Jardim do Ouro
# Igrejinha - UNISINOS
# Bagé
# Aceguá
# Lagoa da Meia Lua
# Brasilândia
# Cacimba
# Paranatinga
# Rio Braço Sul
# Serra do Cachimbo
# Curral de Pedras
# Arroio Grande
# Jaguarão
# Passo São Diogo
# Hulha Negra
# Pinheiro Machado
# Lavras do Sul
# Santa Maria - RS
# Sobradinho
# Agudo
# Três Passos
# Frederico Westphalen
# Matarazzo
# Pelotas
# Pedro Osório
# Placa Nativa
# Nova Xavantina
# Rio Bacajá - UFPR
# Gravataí - UFRGS
# Sanclerlândia
# Rio Inajá
# São João Batista
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7850/3282373429.py in <module>
#       4 for i in lista_nome:
#       5     print(i)
# ----> 6     folha[indice] = litologia_100k[litologia_100k['MAPA'].str.contains(i)].dissolve('MAPA')
#       7     indice+=1
#
# ~/anaconda3/envs/geologist_environment/lib/python3.8/site-packages/geopandas/geodataframe.py in dissolve(self, by, aggfunc, as_index, level, sort, observed, dropna)
#    1498             return merged_geom
#    1499
# -> 1500         g = self.groupby(group_keys=False, **groupby_kwargs)[self.geometry.name].agg(
#    1501             merge_geometries
#    1502         )
#
# ~/anaconda3/envs/geologist_environment/lib/python3.8/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     263
#     264             try:
# --> 265                 return self._python_agg_general(func, *args, **kwargs)
#     266             except KeyError:
#     267                 # TODO: KeyError is raised in _python_agg_general,
#
# ~/anaconda3/envs/geologist_environment/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in _python_agg_general(self, func, *args, **kwargs)
#    1327             try:
#    1328                 # if this function is invalid for this dtype, we will ignore it.
# -> 1329                 result = self.grouper.agg_series(obj, f)
#    1330             except TypeError:
#    1331                 warnings.warn(
#
# ~/anaconda3/envs/geologist_environment/lib/python3.8/site-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#    1013             # In the datetime64tz case it would incorrectly cast to tz-naive
#    1014             # TODO: can we get a performant workaround for EAs backed by ndarray?
# -> 1015             result = self._aggregate_series_pure_python(obj, func)
#    1016
#    1017             # we can preserve a little bit more aggressively with EA dtype
#
# ~/anaconda3/envs/geologist_environment/lib/python3.8/site-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#    1070             # Each step of this loop corresponds to
#    1071             #  libreduction._BaseGrouper._apply_to_group
# -> 1072             res = func(group)
#    1073             res = libreduction.extract_result(res)
#    1074
#
# ~/anaconda3/envs/geologist_environment/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    1313     def _python_agg_general(self, func, *args, **kwargs):
#    1314         func = com.is_builtin_func(func)
# -> 1315         f = lambda x: func(x, *args, **kwargs)
#    1316
#    1317         # iterate through "columns" ex exclusions to populate output dict
#
# ~/anaconda3/envs/geologist_environment/lib/python3.8/site-packages/geopandas/geodataframe.py in merge_geometries(block)
#    1495         # Process spatial component
#    1496         def merge_geometries(block):
# -> 1497             merged_geom = block.unary_union
#    1498             return merged_geom
#    1499
#
# ~/anaconda3/envs/geologist_environment/lib/python3.8/site-packages/geopandas/base.py in unary_union(self)
#     722         POLYGON ((0 0, 0 1, 0 2, 2 2, 2 0, 1 0, 0 0))
#     723         """
# --> 724         return self.geometry.values.unary_union()
#     725
#     726     #
#
# ~/anaconda3/envs/geologist_environment/lib/python3.8/site-packages/geopandas/array.py in unary_union(self)
#     667
#     668     def unary_union(self):
# --> 669         return vectorized.unary_union(self.data)
#     670
#     671     #
#
# ~/anaconda3/envs/geologist_environment/lib/python3.8/site-packages/geopandas/_vectorized.py in unary_union(data)
#     875         return _pygeos_to_shapely(pygeos.union_all(data))
#     876     else:
# --> 877         return shapely.ops.unary_union(data)
#     878
#     879
#
# ~/anaconda3/envs/geologist_environment/lib/python3.8/site-packages/shapely/ops.py in unary_union(self, geoms)
#     152             subs[i] = g._geom
#     153         collection = lgeos.GEOSGeom_createCollection(6, subs, L)
# --> 154         return geom_factory(lgeos.methods['unary_union'](collection))
#     155
#     156 operator = CollectionOperator()
#
# KeyboardInterrupt:

# %%
len(folha)
# Out:
# 311
