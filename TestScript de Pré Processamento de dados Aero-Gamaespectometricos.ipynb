# %%
from sources.filtros import filtro

# %%
filtro()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_21048/3475621101.py in <module>
# ----> 1 filtro()
#
# TypeError: filtro() missing 2 required positional arguments: 'gdf' and 'mineral'

# %%
from sources import source_code as f    

import matplotlib.pyplot as plt 


# %matplotlib widget              

plt.rcParams['figure.dpi'] = 120

import seaborn as sns

# %%
#Levantamento 1089 
dic_cartas,dic_raw_meta = \
f.interpolar('100k','SF23_Y_B_I',
             'gama_line_1105',camada='litologia_1kk',
             describe=True,
             crs__='proj',
             tdm='cubico',gama=True,selecionar=True)
# Out:
# importando dados geofisicos
# /home/ggrl/anaconda3/envs/geologist_bot/lib/python3.8/site-packages/geopandas/geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# # --- Iniciando seleção de área de estudo
# 4 folhas cartográfica selecionadas
#
# Lista de chaves do dicionario de cartas: ['region', 'region_proj', 'raw_data', 'splines', 'scores', 'lito_splines', 'mean_score', 'litologia', 'cubic', 'lito_cubic']
# Listando atributos dos dados geofisicos
# 100%|██████████| 12/12 [00:00<00:00, 281182.39it/s]
# # --- # Listagem de dados do aerolevantamento:
# Lista de atributos geofísicos = ['KPERC', 'eU', 'eTH', 'UTHRAZAO', 'UKRAZAO', 'MDT', 'THKRAZAO', 'CTCOR']
# lista de atributos geograficos = ['LATITUDE', 'LONGITUDE']
# lista de atributos projetados = ['X', 'Y']
# Lista de chaves do dicionario de metadata bruto: ['Metadata', 'Lista_id', 'Lista_at_geof', 'Lista_at_geog', 'Lista_at_proj', 'Percentiles', 'Malha_cartografica']
#
# # --- Início da iteração entre as folhas cartográficas #
# 0it [00:00, ?it/s]
# SF23_Y_B_I geometry       POLYGON ((345155.9214983206 7566413.631237755,...
# region                              (-46.5, -46.0, -22.5, -22.0)
# region_proj    (345155.92149832065, 397141.19065775815, 75110...
# Name: SF23_Y_B_I, dtype: object
# # Folha de código: SF23_Y_B_I
#  Atualizando dados brutos em dic_cartas['raw_data']
#  com 72603 pontos de amostragem
# epsg:32723
# 1it [00:16, 16.27s/it]
#  Atualizando dados geologicos em dic_cartas['litologia']
#  com 60 poligonos descritos por                         27 atributos geologicos
# SF23_Y_B_IV geometry       POLYGON ((345704.8138797733 7511055.321610698,...
# region                              (-46.5, -46.0, -23.0, -22.5)
# region_proj    (345704.81387977325, 397514.8336313751, 745569...
# Name: SF23_Y_B_IV, dtype: object
# # Folha de código: SF23_Y_B_IV
#  Atualizando dados brutos em dic_cartas['raw_data']
#  com 71369 pontos de amostragem
# epsg:32723
# 2it [00:32, 16.18s/it]
#  Atualizando dados geologicos em dic_cartas['litologia']
#  com 40 poligonos descritos por                         27 atributos geologicos
# SF23_Y_B_II geometry       POLYGON ((396775.3595709229 7566835.571346411,...
# region                              (-46.0, -45.5, -22.5, -22.0)
# region_proj    (396775.3595709229, 448571.989664894, 7511484....
# Name: SF23_Y_B_II, dtype: object
# # Folha de código: SF23_Y_B_II
#  Atualizando dados brutos em dic_cartas['raw_data']
#  com 76002 pontos de amostragem
# epsg:32723
# 3it [00:48, 16.16s/it]
#  Atualizando dados geologicos em dic_cartas['litologia']
#  com 56 poligonos descritos por                         27 atributos geologicos
# SF23_Y_B_III geometry       POLYGON ((448389.1032635307 7567088.681391716,...
# region                              (-45.5, -45.0, -22.5, -22.0)
# region_proj    (448389.1032635307, 500000.0, 7511742.48124539...
# Name: SF23_Y_B_III, dtype: object
# # Folha de código: SF23_Y_B_III
#  Atualizando dados brutos em dic_cartas['raw_data']
#  com 72154 pontos de amostragem
# epsg:32723
# 4it [01:04, 16.13s/it]
#  Atualizando dados geologicos em dic_cartas['litologia']
#  com 58 poligonos descritos por                         27 atributos geologicos
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_33133/757546151.py in <module>
#       1 #Levantamento 1089
#       2 dic_cartas,dic_raw_meta = \
# ----> 3 f.interpolar('100k','SF23_Y_B_I',
#       4              'gama_line_1105',camada='litologia_1kk',
#       5              describe=True,
#
# ~/ic_2020/sources/source_code.py in interpolar(escala, id, geof, psize, spacing, degree, n_splits, camada, mapa, crs__, describe, save, tdm, mag, gama, selecionar)
#     333                 data.loc[data.KPERC < 0, 'KPERC'] = 0
#     334                 data.loc[data.eU < 0, 'eU'] = 0
# --> 335                 data.loc[data.eth < 0, 'eth'] = 0
#     336                 data.loc[data.CTCOR < 0, 'CTCOR'] = 0
#     337
#
# ~/anaconda3/envs/geologist_bot/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'eth'

# %% [markdown]
# ## Descriçao estatistica dos dados brutos

# %%
dic_raw_meta['Percentiles'].T
# Out:
#              count        mean         std       min        0.1%       10%  \
# MDT       635173.0  508.893234   85.329898  290.6400  312.140000  400.9600
# KPERC     635173.0    0.520116    0.545391   -0.4100   -0.120000    0.0500
# eU        635173.0    1.107293    0.683094   -1.6400   -0.290000    0.3800
# eth       635173.0    9.470464    5.405466   -0.5600    0.600000    3.6200
# CTCOR     635173.0  836.493968  450.466561  -86.6500   72.351280  331.9800
# THKRAZAO  635173.0   52.609745   92.576155    0.4532    1.701555    7.4646
# UKRAZAO   635173.0    6.368725   10.713721    0.0118    0.045417    0.7330
# UTHRAZAO  635173.0    0.129238    0.070951    0.0023    0.005800    0.0583
#
#                25%       50%        75%        99.5%        max
# MDT       450.5400  501.3000   564.3900   722.290000   795.5500
# KPERC       0.1400    0.3500     0.7200     2.990000     6.5200
# eU          0.6500    1.0000     1.4400     3.880000    25.5000
# eth         5.7900    8.4000    11.9900    29.290000    70.1300
# CTCOR     513.8200  754.0300  1085.9200  2424.664200  5958.8200
# THKRAZAO   12.3368   24.0520    51.7335   658.665466  1892.6940
# UKRAZAO     1.3617    2.7836     6.1791    69.429660   217.3391
# UTHRAZAO    0.0848    0.1182     0.1596     0.427100     1.8439

# %%
dic_cartas['mean_score']
# Out:
# {'SC23_Z_A': {'MDT': '',
#   'KPERC': '',
#   'eU': '',
#   'eth': '',
#   'CTCOR': '',
#   'THKRAZAO': '',
#   'UKRAZAO': '',
#   'UTHRAZAO': ''}}

# %% [markdown]
# {'SC23_Z_A_IV': {'MDT': 0.8334158339524731,
#   'KPERC': 0.18091328322392417,
#   'eU': 0.19612079468324217,
#   'eth': 0.41133174470341644,
#   'CTCOR': 0.41790058475767133,
#   'THKRAZAO': 0.008707459671240092,
#   'UKRAZAO': 0.04778105652944411,
#   'UTHRAZAO': 0.11266206587505746}}

# %% [markdown]
# ## DESCRIÇÃO DOS DADOS DA FOLHA SC23_Z_A_IV_1

# %% [markdown]
# ### DICIONARIO DE DADOS DISPONIVEIS
#     - Regioes geograficas (W,E, S, N)
#     - Regioes projetadas (W,E, S, N)
#     - Dados Brutos
#     - Dados Interpolados
#     - Scores da Validacao Crusada para os dados interpolados
#     - Dataframe com classes alvos (Unidades Litologicas)

# %%
for i in dic_cartas:
    print(i)
# Out:
# region
# region_proj
# raw_data
# splines
# scores
# lito_splines
# mean_score
# litologia
# cubic
# lito_cubic

# %%
print(f"#  folhas cartograficas: {len(dic_cartas['region'])}")
print(f"ID folhas cartograficas: {list(dic_cartas['region'].keys())}")
# Out:
# #  folhas cartograficas: 1
# ID folhas cartograficas: ['SC23_Z_A']

# %%
print(f"Dados interpolados pleo modelo de splines: {list(dic_cartas['splines']['SC23_Z_A'].keys())}")
# Out:
# Dados interpolados pleo modelo de splines: ['MDT', 'KPERC', 'eU', 'eth', 'CTCOR', 'THKRAZAO', 'UKRAZAO', 'UTHRAZAO']

# %%
print(f"Dataframe de classes litologicas disponiveis: {list(dic_cartas['lito_splines']['SC23_Z_A'].keys())}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_20408/1004889537.py in <module>
# ----> 1 print(f"Dataframe de classes litologicas disponiveis: {list(dic_cartas['lito_splines']['SC23_Z_A'].keys())}")
#
# AttributeError: 'str' object has no attribute 'keys'

# %%
print(f"Dataframe de classes litologicas disponiveis: {list(dic_cartas['lito_cubic']['SC23_Z_A'].keys())}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_20408/1351588621.py in <module>
# ----> 1 print(f"Dataframe de classes litologicas disponiveis: {list(dic_cartas['lito_cubic']['SC23_Z_A'].keys())}")
#
# AttributeError: 'str' object has no attribute 'keys'

# %% [markdown]
# ### CRIANDO DICIONARIO DE TITULOS PARA OS PLOTS

# %%
list_canal = dic_raw_meta['Lista_at_geof']
print(f"Lista de atributos: {list_canal}")

# LISTA DE TITULOS 
titles =   [
            'MDT (m)',
            'K (%)',
            'U (ppm)',
            'Th (ppm)',
            'Contagem Total (μR/h)',
            'Th (ppm) / K (%)',
            'U (ppm) / K (%)',
            'U (ppm) / Th (ppm)'
            ]


# DICIONARIO DE TITULOS
dic_titles = {}
for f, t in zip(list_canal, titles):
    dic_titles[f] = t

dic_titles
# Out:
# Lista de atributos: ['MDT', 'KPERC', 'eU', 'eth', 'CTCOR', 'THKRAZAO', 'UKRAZAO', 'UTHRAZAO']
# {'MDT': 'MDT (m)',
#  'KPERC': 'K (%)',
#  'eU': 'U (ppm)',
#  'eth': 'Th (ppm)',
#  'CTCOR': 'Contagem Total (μR/h)',
#  'THKRAZAO': 'Th (ppm) / K (%)',
#  'UKRAZAO': 'U (ppm) / K (%)',
#  'UTHRAZAO': 'U (ppm) / Th (ppm)'}

# %% [markdown]
# #### DISTRIBUICAO GEOSTATISTICA DOS DADOS BRUTOS

# %%
dic_cartas['raw_data']['SC23_Z_A']
# Out:
#                 X           Y     MDT  KPERC    eU    eth   CTCOR  THKRAZAO  \
# 82136   500148.30  8868403.03  507.73   0.10  0.56   9.21  625.03   94.5592
# 82137   500148.32  8868321.68  511.97   0.09  0.66   9.23  636.30  103.9236
# 82138   500147.95  8868240.28  513.21   0.06  0.71   9.11  626.87  151.4477
# 82139   500146.94  8868158.84  514.44   0.03  0.80   9.85  672.23  342.6986
# 82140   500144.84  8868077.25  513.20   0.03  0.91  10.95  748.45  376.3382
# ...           ...         ...     ...    ...   ...    ...     ...       ...
# 630683  664127.38  8894231.25  472.41   0.00  0.56   1.54  148.80   58.2370
# 630684  664127.72  8894311.82  471.73   0.00  0.68   1.36  166.32   55.4658
# 630685  664128.00  8894392.48  470.07   0.04  0.78   2.15  235.53   47.9224
# 630686  664128.08  8894473.24  467.22   0.07  0.70   2.67  262.62   41.4539
# 630687  664127.87  8894554.13  470.36   0.06  0.69   2.88  271.21   46.1024
#
#         UKRAZAO  UTHRAZAO  LONGITUDE   LATITUDE  \
# 82136    5.7975    0.0613 -44.998646 -10.236826
# 82137    7.4098    0.0713 -44.998646 -10.237562
# 82138   11.8846    0.0785 -44.998649 -10.238298
# 82139   27.8959    0.0814 -44.998658 -10.239034
# 82140   31.0579    0.0825 -44.998677 -10.239772
# ...         ...       ...        ...        ...
# 630683  21.5182    0.3695 -43.502588  -9.999853
# 630684  26.6706    0.4808 -43.502588  -9.999125
# 630685  17.5676    0.3666 -43.502589  -9.998395
# 630686  10.8116    0.2608 -43.502592  -9.997665
# 630687  11.1466    0.2418 -43.502597  -9.996934
#
#                               geometry
# 82136   POINT (500148.300 8868403.030)
# 82137   POINT (500148.320 8868321.680)
# 82138   POINT (500147.950 8868240.280)
# 82139   POINT (500146.940 8868158.840)
# 82140   POINT (500144.840 8868077.250)
# ...                                ...
# 630683  POINT (664127.380 8894231.250)
# 630684  POINT (664127.720 8894311.820)
# 630685  POINT (664128.000 8894392.480)
# 630686  POINT (664128.080 8894473.240)
# 630687  POINT (664127.870 8894554.130)
#
# [441857 rows x 13 columns]

# %%
SC23_raw_data = dic_cartas['raw_data']['SC23']
SC23_raw_data_describe = SC23_raw_data.describe(percentiles=(0.01,0.1,0.25,0.5,0.75,0.995))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_20408/1511829108.py in <module>
# ----> 1 SC23_raw_data = dic_cartas['raw_data']['SC23']
#       2 SC23_raw_data_describe = SC23_raw_data.describe(percentiles=(0.01,0.1,0.25,0.5,0.75,0.995))
#
# KeyError: 'SC23'

# %%
SC23_cubic = dic_cartas['cubic']['SC23']
SC23_cubic_describe = SC23_cubic.describe(percentiles=(0.01,0.1,0.25,0.5,0.75,0.995))

# %%
SC23_Z_A_IV_splines = dic_cartas['splines']['SC23']
SC23_Z_A_IV_splines_describe = SC23_Z_A_IV_splines.describe(percentiles=(0.01,0.1,0.25,0.5,0.75,0.995))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_17665/2380379862.py in <module>
#       1 SC23_Z_A_IV_splines = dic_cartas['splines']['SC23']
# ----> 2 SC23_Z_A_IV_splines_describe = SC23_Z_A_IV_splines.describe(percentiles=(0.01,0.1,0.25,0.5,0.75,0.995))
#
# AttributeError: 'dict' object has no attribute 'describe'

# %%
SC23_raw_data_describe.drop(columns=['LATITUDE','LONGITUDE','X','Y'],inplace=True)

# %%
SC23_raw_data_describe.T
# Out:
#              count        mean         std       min        1%       10%  \
# MDT       635173.0  508.893234   85.329898  290.6400  335.9900  400.9600
# KPERC     635173.0    0.521395    0.544087    0.0000    0.0000    0.0500
# eU        635173.0    1.108532    0.680827    0.0000    0.0100    0.3800
# eth       635173.0    9.470497    5.405406    0.0000    1.6100    3.6200
# CTCOR     635173.0  836.496906  450.460998    0.0000  148.7200  331.9800
# THKRAZAO  635173.0   52.609745   92.576155    0.4532    3.2460    7.4646
# UKRAZAO   635173.0    6.368725   10.713721    0.0118    0.1816    0.7330
# UTHRAZAO  635173.0    0.129238    0.070951    0.0023    0.0146    0.0583
#
#                25%       50%        75%        99.5%        max
# MDT       450.5400  501.3000   564.3900   722.290000   795.5500
# KPERC       0.1400    0.3500     0.7200     2.990000     6.5200
# eU          0.6500    1.0000     1.4400     3.880000    25.5000
# eth         5.7900    8.4000    11.9900    29.290000    70.1300
# CTCOR     513.8200  754.0300  1085.9200  2424.664200  5958.8200
# THKRAZAO   12.3368   24.0520    51.7335   658.665466  1892.6940
# UKRAZAO     1.3617    2.7836     6.1791    69.429660   217.3391
# UTHRAZAO    0.0848    0.1182     0.1596     0.427100     1.8439

# %%
SC23_Z_A_IV_lito_splines_describe.drop(columns=['easting','northing'],inplace=True)
SC23_Z_A_IV_lito_splines_describe.T
# Out:
#             count         mean         std         min          1%  \
# MDT       12099.0   520.051037   79.313535  353.712055  375.028288
# KPERC     12099.0     0.613108    0.480117   -0.105268    0.045090
# eU        12099.0     1.544612    0.641737    0.024692    0.451419
# eth       12099.0    14.065652    6.316804    1.927982    4.825268
# CTCOR     12099.0  1181.754773  434.228152  181.118059  471.366247
# THKRAZAO  12099.0    69.873876  114.794826  -37.201091    3.111614
# UKRAZAO   12099.0     7.167995   10.056855   -4.088171    0.175704
# UTHRAZAO  12099.0     0.120033    0.045600    0.009401    0.051214
#
#                  10%         25%          50%          75%        99.5%  \
# MDT       427.117421  463.893597   504.315605   570.208614   696.920125
# KPERC       0.129048    0.225416     0.485239     0.882290     2.228371
# eU          0.834722    1.094399     1.456220     1.897454     4.071260
# eth         7.278378    9.387742    12.481567    17.359265    32.290732
# CTCOR     666.340301  827.853552  1134.711231  1488.392862  2594.145990
# THKRAZAO    8.370339   13.693988    29.744209    65.203926   692.309813
# UKRAZAO     0.947111    1.641812     3.497150     7.653959    59.168538
# UTHRAZAO    0.072521    0.087151     0.111788     0.143336     0.284249
#
#                   max
# MDT        705.203399
# KPERC        3.178376
# eU           6.412020
# eth         47.318088
# CTCOR     3651.751195
# THKRAZAO   950.940079
# UKRAZAO     80.023690
# UTHRAZAO     0.665047

# %%
SC23_cubic_describe.drop(columns=['X','Y'],inplace=True)

SC23_cubic_describe.T
# Out:
#           count        mean          std          min           1%  \
# MDT       100.0  499.764741   133.821771   329.038698   329.038698
# CTCOR     100.0   50.051047  1162.154890 -2088.762611 -2088.762611
# KPERC     100.0   -0.725540     2.054537    -4.794021    -4.794021
# eU        100.0    0.101886     1.256831    -2.308281    -2.308281
# eth       100.0    4.525344     8.655499    -6.167689    -6.167689
# UTHRAZAO  100.0    0.064277     0.338580    -0.545822    -0.545822
# UKRAZAO   100.0   -7.796168    26.982419   -59.004951   -59.004951
# THKRAZAO  100.0   73.696906   207.400074     5.038777     5.038777
#
#                   10%         25%         50%         75%        99.5%  \
# MDT        329.038698  329.038698  465.063952  642.871812   651.154584
# CTCOR    -2088.762611   64.821663  397.343378  729.865092  1837.564080
# KPERC       -4.794021    0.076526    0.104799    0.398511     1.063074
# eU          -2.308281    0.271729    0.529468    0.787208     1.398419
# eth         -6.167689    0.082369    4.517328    8.952288    29.127780
# UTHRAZAO    -0.545822    0.042525    0.087332    0.421461     0.421461
# UKRAZAO    -59.004951    1.823344    2.304046    2.966523    36.645965
# THKRAZAO     5.038777    5.038777   20.214434   49.968919   888.089134
#
#                   max
# MDT        651.154584
# CTCOR     1837.564080
# KPERC        1.063074
# eU           1.398419
# eth         29.127780
# UTHRAZAO     0.421461
# UKRAZAO     36.645965
# THKRAZAO   888.089134

# %%
litologia = dic_cartas['litologia']['SC23_Z_A']
litologia.to_crs(32723,inplace=True)
litologia.plot('SIGLA',
                legend=True,
                legend_kwds={'loc': 'center left', 'bbox_to_anchor':(1,0.5)})
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <AxesSubplot:>

# %%
dic_titles
# Out:
# {'MDT': 'MDT (m)',
#  'KPERC': 'K (%)',
#  'eU': 'U (ppm)',
#  'eth': 'Th (ppm)',
#  'CTCOR': 'Contagem Total (μR/h)',
#  'THKRAZAO': 'Th (ppm) / K (%)',
#  'UKRAZAO': 'U (ppm) / K (%)',
#  'UTHRAZAO': 'U (ppm) / Th (ppm)'}

# %%
def plot_raw_data(raw_data):
    fig, axs = plt.subplots(nrows = 8, ncols = 1, figsize = (9, 9),sharex='all',sharey='all')
    
    raw_data_describe = raw_data.describe(percentiles=(0.01,0.1,0.25,0.5,0.75,0.995))

    X, Y = raw_data.X, raw_data.Y

    for ax, f in zip(axs.flat, dic_titles):
        vmin = raw_data_describe[f]['1%']
        vmax = raw_data_describe[f]['99.5%']

        g = ax.scatter(c=raw_data[f], x = X,
                                      y = Y,
                                      cmap = 'rainbow',
                                      s    = 0.5,
                                      vmax =vmax, vmin=vmin)

        fig.colorbar(g, ax = ax)
        ax.set_title(str(dic_titles[f]), size = 11)
        ax.axis('scaled')

    #plt.tight_layout()

# %%
plot_raw_data(dic_cartas['raw_data']['SC23_Z_A'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
data = dic_cartas['cubic']['SC23_Z_A']

# %%
plot_raw_data(data)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lista_splines = list(dic_cartas['splines']['SC23_Z_A_IV'].keys())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_20408/2360021730.py in <module>
# ----> 1 lista_splines = list(dic_cartas['splines']['SC23_Z_A_IV'].keys())
#
# KeyError: 'SC23_Z_A_IV'

# %%
import pandas as pd

# %%
def plot_splines_grid(splines_grid):
    fig, axs = plt.subplots(nrows = 4, ncols = 2, figsize = (16, 16),sharex='all',sharey='all')

    for ax, f in zip(axs.flat, dic_titles):

        df_splines = pd.DataFrame(splines_grid[f][f])

        p = df_splines.describe(percentiles=(0.01,0.1,0.25,0.5,0.75,0.995))
        print(p)
        vmin = p['1%']
        vmax = p['99.5%']

        g = grids[f][f].plot(ax=ax,
                             cmap = 'rainbow',
                             vmax =vmax, vmin=vmin)

        #fig.colorbar(g, ax = ax)
        ax.set_title(str(dic_titles[f]), size = 11)
        ax.axis('scaled')

    #plt.tight_layout()

# %%
splines_grid[f][f]

# %%
grids = dic_cartas['splines']['SC23_Z_A']

plot_splines_grid(grids)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(dic_cartas['splines']['SC23_Z_A_IV'].keys())
# Out:
# dict_keys(['MDT', 'KPERC', 'eU', 'eth', 'CTCOR', 'THKRAZAO', 'UKRAZAO', 'UTHRAZAO'])

# %%
dic_cartas['splines']['SC23_Z_A_IV']['MDT']
# Out:
# <xarray.Dataset>
# Dimensions:   (northing: 111, easting: 109)
# Coordinates:
#   * easting   (easting) float64 5.003e+05 5.008e+05 ... 5.539e+05 5.544e+05
#   * northing  (northing) float64 8.784e+06 8.785e+06 ... 8.839e+06 8.839e+06
# Data variables:
#     MDT       (northing, easting) float64 507.7 496.3 475.4 ... 477.1 465.5
# Attributes:
#     metadata:  Generated by Chain(steps=[('trend', Trend(degree=1)),\n       ...

# %%
dic_cartas['splines']['SC23_Z_A_IV']['MDT'].MDT
# Out:
# <xarray.DataArray 'MDT' (northing: 111, easting: 109)>
# array([[507.72841526, 496.31877256, 475.37628754, ..., 442.692659  ,
#         442.42075025, 441.2416789 ],
#        [503.35398745, 481.78973809, 484.38749263, ..., 448.18273566,
#         446.06405591, 445.86374598],
#        [484.02824611, 474.63855493, 507.34104155, ..., 453.60696193,
#         446.79647658, 446.36630683],
#        ...,
#        [403.72985597, 418.22104113, 422.06590069, ..., 502.92034455,
#         500.9368981 , 498.90484094],
#        [414.47089031, 435.38269424, 433.45931606, ..., 496.9677803 ,
#         489.24909389, 484.30312644],
#        [435.31028101, 437.53553086, 442.41248074, ..., 489.22170783,
#         477.10614737, 465.47434941]])
# Coordinates:
#   * easting   (easting) float64 5.003e+05 5.008e+05 ... 5.539e+05 5.544e+05
#   * northing  (northing) float64 8.784e+06 8.785e+06 ... 8.839e+06 8.839e+06
# Attributes:
#     metadata:  Generated by Chain(steps=[('trend', Trend(degree=1)),\n       ...

# %% [markdown]
# ### DESCRICAO GEOSTATISTICA DOS DADOS INTERPOLADOS

# %%
geodataframe = dic_cartas['lito_splines']['SC23_Z_A_IV'].set_geometry('geometry')
print(geodataframe.crs)
geodataframe.plot('closest_unid',s= 5,
                                 legend=True,
                                 legend_kwds={'loc': 'center left', 'bbox_to_anchor':(1,0.5)})
                                 
plt.title(label=f"'closest_unid': SC23_Z_A_IV")
plt.axis('scaled')
# Out:
# epsg:32723
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (497546.76096330275, 557153.7890366972, 8781483.652612612, 8841797.007387388)

# %%
from shapely import geometry

dic_cartas['lito_cubic']['SC23_Z_A_IV']['geometry'] = [geometry.Point(x,y) for x, y in zip(dic_cartas['lito_cubic']['SC23_Z_A_IV']['X'], dic_cartas['lito_cubic']['SC23_Z_A_IV']['Y'])]

geodataframe = dic_cartas['lito_cubic']['SC23_Z_A_IV'].set_geometry('geometry')
geodataframe.set_crs(32723,inplace=True)
geodataframe.to_crs(32723,inplace=True)

print(geodataframe.crs)

# %%
geodataframe
# Out:
#                     X             Y         MDT        CTCOR     KPERC  \
# 0       500000.000000  8.783975e+06  510.971924  1728.869274  1.532959
# 1       500109.644412  8.783975e+06  510.971924  1728.869274  1.532959
# 2       500219.288824  8.783975e+06  510.971924  1728.869274  1.532959
# 3       500328.933235  8.783975e+06  512.638234  1683.430977  1.503587
# 4       500438.577647  8.783975e+06  513.651634  1640.614269  1.471212
# ...               ...           ...         ...          ...       ...
# 249995  554273.983852  8.839305e+06  477.906303   895.879587  0.651783
# 249996  554383.628264  8.839305e+06  469.745255   862.128866  0.630352
# 249997  554493.272676  8.839305e+06  460.988773   824.988883  0.605418
# 249998  554602.917088  8.839305e+06  451.475640   783.606527  0.571166
# 249999  554712.561500  8.839305e+06  451.475640   783.606527  0.571166
#
#               eU        eth  UTHRAZAO   UKRAZAO   THKRAZAO closest_unid  \
# 0       2.267979  17.205152  0.133299  1.477464  11.103245       NP1rp3
# 1       2.267979  17.205152  0.133299  1.477464  11.103245       NP1rp3
# 2       2.267979  17.205152  0.133299  1.477464  11.103245       NP1rp3
# 3       2.326873  16.427387  0.143720  1.549360  10.770013       NP1rp3
# 4       2.356847  15.776541  0.151033  1.603550  10.571928         N1dl
# ...          ...        ...       ...       ...        ...          ...
# 249995  0.874006  10.362863  0.089454  1.363215  15.916905          NaN
# 249996  0.961251   9.680775  0.106218  1.551167  15.306415          NaN
# 249997  1.064014   8.921947  0.125131  1.770339  14.625392          NaN
# 249998  1.182887   8.099838  0.145881  2.034030  13.970594          NaN
# 249999  1.182887   8.099838  0.145881  2.034030  13.970594          NaN
#
#                               geometry
# 0       POINT (500000.000 8783975.089)
# 1       POINT (500109.644 8783975.089)
# 2       POINT (500219.289 8783975.089)
# 3       POINT (500328.933 8783975.089)
# 4       POINT (500438.578 8783975.089)
# ...                                ...
# 249995  POINT (554273.984 8839304.906)
# 249996  POINT (554383.628 8839304.906)
# 249997  POINT (554493.273 8839304.906)
# 249998  POINT (554602.917 8839304.906)
# 249999  POINT (554712.561 8839304.906)
#
# [250000 rows x 12 columns]

# %%
geodataframe.plot('closest_unid',s= 5,
                        legend=True,
                        legend_kwds={'loc': 'center left', 'bbox_to_anchor':(1,0.5)}
                )
                                 
plt.title(label=f"'closest_unid': SC23_Z_A_IV")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Text(0.5, 1.0, "'closest_unid': SC23_Z_A_IV")

# %%
def plotBoxplots(df, cols = None):
    n = len(cols)
    fig, axs = plt.subplots(n, 1, figsize = (9, n * 2))
    
    for ax, f in zip(axs, cols):
        sns.boxplot(y = f, x = 'closest_unid', data = df, ax = ax)

# %%
plotBoxplots(dic_cartas['lito_splines']['SC23_Z_A_IV'], cols = dic_titles)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plotBoxplots(dic_cartas['lito_cubic']['SC23_Z_A_IV'], cols = dic_titles)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, axs = plt.subplots(nrows = 4, ncols = 2, figsize = (7, 6))

for ax, gf in zip(axs.flat, dic_titles):
    g = ax.hist(dic_cartas['lito_splines']['SC23_Z_A_IV'][gf], color = 'lightblue', edgecolor = 'black')
    ax.set_title(str(dic_titles[gf]), size = 9)

plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, axs = plt.subplots(nrows = 4, ncols = 2, figsize = (7, 6))

for ax, gf in zip(axs.flat, dic_titles):
    g = ax.hist(dic_cartas['lito_cubic']['SC23_Z_A_IV'][gf], color = 'lightblue', edgecolor = 'black')
    ax.set_title(str(dic_titles[gf]), size = 9)

plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, axs = plt.subplots(nrows = 4, ncols = 2, figsize = (7, 6))

for ax, gf in zip(axs.flat, dic_titles):
    g = ax.hist(dic_cartas['raw_data']['SC23_Z_A_IV'][gf], color = 'lightblue', edgecolor = 'black')
    ax.set_title(str(dic_titles[gf]), size = 9)

plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
for i in dic_cartas['splines']:
    print(i)
    dic_cartas['lito_splines'][i].to_csv(f.gdb+'dataframe_input_model/lito_splines_'+i+'.csv',index=False)
    dic_cartas['lito_cubic'][i].to_csv(f.gdb+'dataframe_input_model/lito_cubic_'+i+'.csv',index=False)
# Out:
# SC23_Z_A_IV

# %%
dic_cartas['lito_cubic']['SC23_Z_A_IV']
# Out:
#                     X             Y         MDT        CTCOR     KPERC  \
# 0       500000.000000  8.783975e+06  510.971924  1728.869274  1.532959
# 1       500109.644412  8.783975e+06  510.971924  1728.869274  1.532959
# 2       500219.288824  8.783975e+06  510.971924  1728.869274  1.532959
# 3       500328.933235  8.783975e+06  512.638234  1683.430977  1.503587
# 4       500438.577647  8.783975e+06  513.651634  1640.614269  1.471212
# ...               ...           ...         ...          ...       ...
# 249995  554273.983852  8.839305e+06  477.906303   895.879587  0.651783
# 249996  554383.628264  8.839305e+06  469.745255   862.128866  0.630352
# 249997  554493.272676  8.839305e+06  460.988773   824.988883  0.605418
# 249998  554602.917088  8.839305e+06  451.475640   783.606527  0.571166
# 249999  554712.561500  8.839305e+06  451.475640   783.606527  0.571166
#
#               eU        eth  UTHRAZAO   UKRAZAO   THKRAZAO closest_unid
# 0       2.267979  17.205152  0.133299  1.477464  11.103245       NP1rp3
# 1       2.267979  17.205152  0.133299  1.477464  11.103245       NP1rp3
# 2       2.267979  17.205152  0.133299  1.477464  11.103245       NP1rp3
# 3       2.326873  16.427387  0.143720  1.549360  10.770013       NP1rp3
# 4       2.356847  15.776541  0.151033  1.603550  10.571928         N1dl
# ...          ...        ...       ...       ...        ...          ...
# 249995  0.874006  10.362863  0.089454  1.363215  15.916905          NaN
# 249996  0.961251   9.680775  0.106218  1.551167  15.306415          NaN
# 249997  1.064014   8.921947  0.125131  1.770339  14.625392          NaN
# 249998  1.182887   8.099838  0.145881  2.034030  13.970594          NaN
# 249999  1.182887   8.099838  0.145881  2.034030  13.970594          NaN
#
# [250000 rows x 11 columns]

# %%
dic_cartas['lito_cubic']['SC23_Z_A_IV'].closest_unid.isnull().sum()
# Out:
# 237901

# %%
dic_cartas['lito_splines']['SC23_Z_A_IV']
# Out:
#            northing        easting         MDT     KPERC        eU        eth  \
# 0      8.784225e+06  500256.171330  507.728415  1.462137  2.150546  17.387574
# 1      8.784225e+06  500757.913991  496.318773  1.298393  2.232456  15.215179
# 2      8.784225e+06  501259.656651  475.376288  1.001659  1.837471  13.578551
# 3      8.784225e+06  501761.399312  487.177736  0.957392  1.555910  11.502266
# 4      8.784225e+06  502263.141972  511.442025  0.503313  1.708078  13.554818
# ...             ...            ...         ...       ...       ...        ...
# 12094  8.839055e+06  552437.408028  488.829873  0.522074  1.541224  13.245871
# 12095  8.839055e+06  552939.150688  492.888244  0.684923  0.775737  14.785880
# 12096  8.839055e+06  553440.893349  489.221708  0.761254  0.972271  13.866382
# 12097  8.839055e+06  553942.636009  477.106147  0.795367  0.756874  11.282279
# 12098  8.839055e+06  554444.378670  465.474349  0.768831  1.087537  11.056722
#
#              CTCOR   THKRAZAO   UKRAZAO  UTHRAZAO  \
# 0      1702.643589  12.640614  1.518653  0.125674
# 1      1540.385563  12.132598  1.754884  0.146725
# 2      1307.373078  13.559304  1.868111  0.135771
# 3      1139.923248  12.429871  1.652679  0.135169
# 4      1140.690957  25.230987  3.261274  0.124446
# ...            ...        ...       ...       ...
# 12094  1108.515769  26.210036  3.451054  0.127485
# 12095  1144.793866  21.806335  1.060464  0.051550
# 12096  1140.769955  18.702497  1.272996  0.070707
# 12097   976.101971  14.367540  0.950492  0.065522
# 12098   997.728476  14.253250  1.429655  0.101116
#
#                              geometry closest_unid
# 0      POINT (500256.171 8784225.169)       NP1rp3
# 1      POINT (500757.914 8784225.169)       NP1rp3
# 2      POINT (501259.657 8784225.169)       NP1rp3
# 3      POINT (501761.399 8784225.169)       NP1rp3
# 4      POINT (502263.142 8784225.169)         N1dl
# ...                               ...          ...
# 12094  POINT (552437.408 8839055.491)         N1dl
# 12095  POINT (552939.151 8839055.491)         N1dl
# 12096  POINT (553440.893 8839055.491)         N1dl
# 12097  POINT (553942.636 8839055.491)       NP1rp3
# 12098  POINT (554444.379 8839055.491)       NP1rp3
#
# [12099 rows x 12 columns]

# %%
dic_cartas['lito_splines']['SC23_Z_A_IV'].closest_unid.isnull().sum()
# Out:
# 0
