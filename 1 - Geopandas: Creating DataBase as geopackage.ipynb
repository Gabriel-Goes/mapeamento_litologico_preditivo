# %% [markdown]
# # Interagindo com a base de dados geologica da CPRM atraves do portal [GeoSGB](https://geoportal.cprm.gov.br/geosgb/)

# %% [markdown]
# ## Com a ferramento Geoprocessing conseguimos selecionar a area e a camda vetorial desejada, alem do formato do arquivo. No caso foi feito o download dos arquivos shapefiles da area do territorio continental brasileiro.

# %%
from IPython.display import Image
Image('imagens/geoprocessing_icon.png')

# %%
Image('imagens/sgb_online_database.png')

# %% [markdown]
# ### Criando Banco de Dados Geológicos com [GeoPandas](https://geopandas.org/getting_started.html)
#
# - Com a biblioteca GeoPandas, vamos abrir os vetores no formato shapefile e salvalos em um banco de dados formatado como um geopackage.

# %% [markdown]
# ## Para este trabalho foi utilizada a area continental brasileira.
#  - O Download destes arquivos foi feito no dia 18/06/2021 e a base de dados online do SGB pode ter sofrido alteraçoes desde entao.

# %%
import geopandas as gpd

# %% [markdown]
# ####  Definindo um apelido de atalho para nossa base de dados local.

# %%
gdb = '/home/ggrl/geodatabase/'

# %% [markdown]
# ####  Lendo as geometrias litoestratigráficas dos arquivos shapefiles fornecidos pelo banco de dados gratuitos da CPRM e definindo a camada com um nome para cada escala.

# %%
# abrindo unidades litoestratigráficas em escala de 1 : 1.000.000 
litologia_1kk = gpd.read_file(gdb+'shapefiles/Unidades_litoestratigráficas___1_1_000_000__2004_.shp')

# %%
litologia_1kk.to_file(gdb+'geodatabase.gpkg',
              driver='GPKG',
              layer='litologia_1kk')

# %%
# Unidades Litoestratigráficas na escala de 1 : 250.000
litologia_250k = gpd.read_file(gdb+'shapefiles/Unidades_litoestratigráficas___1_250_000.shp')

litologia_250k.to_file(gdb+'geodatabase.gpkg',
              driver='GPKG',
              layer='litologia_250k')

# %%
# Unidades Litoestratigráficas na escalada de 1 : 150.000
litologia_150k = gpd.read_file(gdb+'shapefiles/Unidades_litoestratigráficas___1_150_000.shp')

litologia_150k.to_file(gdb+'geodatadatabase.gpkg',
              driver='GPKG',
              layer='litologia_150k')

# Este shapefile está vazio, podendo ser um erro no download da base de dados do SGB ou
# apenas que não há mapas disponibilizado para esta escala.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5870/863113924.py in <module>
#       2 litologia_150k = gpd.read_file(gdb+'shapefiles/Unidades_litoestratigráficas___1_150_000.shp')
#       3
# ----> 4 litologia_150k.to_file(gdb+'geodatadatabase.gpkg',
#       5               driver='GPKG',
#       6               layer='litologia_150k')
#
# ~/anaconda3/envs/geologist_bot/lib/python3.8/site-packages/geopandas/geodataframe.py in to_file(self, filename, driver, schema, index, **kwargs)
#    1084         from geopandas.io.file import _to_file
#    1085
# -> 1086         _to_file(self, filename, driver, schema, index, **kwargs)
#    1087
#    1088     def set_crs(self, crs=None, epsg=None, inplace=False, allow_override=False):
#
# ~/anaconda3/envs/geologist_bot/lib/python3.8/site-packages/geopandas/io/file.py in _to_file(df, filename, driver, schema, index, mode, crs, **kwargs)
#     302         df = df.reset_index(drop=False)
#     303     if schema is None:
# --> 304         schema = infer_schema(df)
#     305     if crs:
#     306         crs = pyproj.CRS.from_user_input(crs)
#
# ~/anaconda3/envs/geologist_bot/lib/python3.8/site-packages/geopandas/io/file.py in infer_schema(df)
#     360
#     361     if df.empty:
# --> 362         raise ValueError("Cannot write empty DataFrame to file.")
#     363
#     364     # Since https://github.com/Toblerity/Fiona/issues/446 resolution,
#
# ValueError: Cannot write empty DataFrame to file.

# %%
# Unidades Litoestratigráficas na escalada de 1 : 100.000
litologia_100k = gpd.read_file(gdb+'shapefiles/Unidades_litoestratigráficas___1_100_000.shp')

litologia_100k.to_file(gdb+'geodatabase.gpkg',
              driver='GPKG',
              layer='litologia_100k')

# %%
# Unidades Litoestratigráficas na escalada de 1 : 50.000
litologia_50k = gpd.read_file(gdb+'shapefiles/Unidades_litoestratigráficas___1_50_000.shp')

litologia_50k.to_file(gdb+'geodatabase.gpkg',
              driver='GPKG',
              layer='litologia_50k')

# %% [markdown]
# #### Podemos, também, adicionar ao nosso GeoPackage geometrias outros tipos de geometria, como pontos de ocorrência mineral.

# %%
ocorr_min = gpd.read_file(gdb+'shapefiles/Ocorrências_minerais.shp')

ocorr_min.to_file(gdb+'gepdatabase.gpkg',
                  driver='GPKG',
                  layer='ocorr_min_cprm')

# %% [markdown]
# #### Afloramentos, Amostras Petrograficas e Projetos de mapeamentos geolgocios e geofisicos

# %%
aflora = gpd.read_file(gdb+'shapefiles/Afloramentos_geológicos.shp')

aflora.to_file(gdb+'geodatabase.gpkg',
                  driver='GPKG',
                  layer='aflora')

# %%
am_petro = gpd.read_file(gdb+'shapefiles/Amostras_petrográficas.shp')

am_petro.to_file(gdb+'geodatabase.gpkg',
                  driver='GPKG',
                  layer='am_petro')

# %%
proj_cprm = gpd.read_file(gdb+'shapefiles/Projetos_da_CPRM.shp')


proj_cprm.to_file(gdb+'geodatabase.gpkg',
                  driver='GPKG',
                  layer='proj_cprm')

# %%
proj_aerogeof = gpd.read_file(gdb+'shapefiles/Projetos_de_aerogeofísica.shp')

proj_aerogeof.to_file(gdb+'geodatabase.gpkg',
                  driver='GPKG',
                  layer='proj_aerogeof')

# %% [markdown]
# #### Vetores do mapa geologico da Folha Campinas SF23_Y_A 1:250.000

# %%
socorro_250k = gpd.read_file(gdb+'shapefiles/socorro.shp')

# %%
socorro_250k.to_file(gdb+'geodatabase.gpkg',
                  driver='GPKG',
                  layer='socorro_250k')

# %% [markdown]
# #### Os arquivos .gdb sao muito grandes e nao estao sendo inseridos no banco de dados no formato .gpkg ou o formato nao comporta

# %%
an_geoq_pre = gpd.read_file(gdb+'data_geoq_pre.gdb')

an_geoq_pre.to_file(gdb+'geodatabase.gpkg',
                  driver='GPKG',
                  layer='an_geoq_pre')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4216/3592050097.py in <module>
#       1 an_geoq_pre = gpd.read_file(gdb+'data_geoq_pre.gdb')
#       2
# ----> 3 an_geoq_pre.to_file(gdb+'geodatabase.gpkg',
#       4                   driver='GPKG',
#       5                   layer='an_geoq_pre')
#
# ~/anaconda3/envs/geologist_bot/lib/python3.8/site-packages/geopandas/geodataframe.py in to_file(self, filename, driver, schema, index, **kwargs)
#    1084         from geopandas.io.file import _to_file
#    1085
# -> 1086         _to_file(self, filename, driver, schema, index, **kwargs)
#    1087
#    1088     def set_crs(self, crs=None, epsg=None, inplace=False, allow_override=False):
#
# ~/anaconda3/envs/geologist_bot/lib/python3.8/site-packages/geopandas/io/file.py in _to_file(df, filename, driver, schema, index, mode, crs, **kwargs)
#     328             filename, mode=mode, driver=driver, crs_wkt=crs_wkt, schema=schema, **kwargs
#     329         ) as colxn:
# --> 330             colxn.writerecords(df.iterfeatures())
#     331
#     332
#
# ~/anaconda3/envs/geologist_bot/lib/python3.8/site-packages/fiona/collection.py in writerecords(self, records)
#     340         if self.mode not in ('a', 'w'):
#     341             raise IOError("collection not open for writing")
# --> 342         self.session.writerecs(records, self)
#     343         self._len = self.session.get_length()
#     344         self._bounds = self.session.get_extent()
#
# fiona/ogrext.pyx in fiona.ogrext.WritingSession.writerecs()
#
# fiona/ogrext.pyx in fiona.ogrext.OGRFeatureBuilder.build()
#
# KeyboardInterrupt:

# %%
an_geoq_pos = gpd.read_file(gdb+'data_geoq_pos.gdb')

an_geoq_pos.to_file(gdb+'geodatabase.gpkg',
                  driver='GPKG',
                  layer='an_geoq_pos')
# Out:
# "\nan_geoq_pos = gpd.read_file(gdb+'an_geoq/pos_2012/data.gdb')\n\nan_geoq_pos.to_file(gdb+'database.gpkg',\n                  driver='GPKG',\n                  layer='an_geoq_pos')\n"

# %%
an_min_pos = gpd.read_file(gdb+'data_min_pos.gdb')

an_min_pos.to_file(gdb+'geodatabase.gpkg',
                  driver='GPKG',
                  layer='an_min_pos')
# Out:
# "\nan_min_pos = gpd.read_file(gdb+'an_min/pos_2012/data.gdb')\n\nan_min_pos.to_file(gdb+'database.gpkg',\n                  driver='GPKG',\n                  layer='an_min_pos')\n"

# %%
an_min_pre = gpd.read_file(gdb+'data_min_pre.gdb')

an_min_pre.to_file(gdb+'geodatabase.gpkg',
                  driver='GPKG',
                  layer='an_min_pre')
# Out:
# "\nan_min_pre = gpd.read_file(gdb+'an_min/pre_2012/data.gdb')\n\nan_min_pre.to_file(gdb+'database.gpkg',\n                  driver='GPKG',\n                  layer='an_min_pre')\n"

# %% [markdown]
# ## No proximo notebook utilizaremos algumas funçoes da biblioteca GeoPandas para filtrar e plotar nossos dados geologicos.
