# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import os
import pandas as pd

from mpl_toolkits.axes_grid1 import make_axes_locatable

# %matplotlib widget

# %% [markdown]
# # Minério de Interesse
#     - Grafita
#         - Por quê Grafita?

# %% [markdown]
# # Area de Estudo
#
#     - SF23
#         - Por quê SF23?

# %%
def set_gdb(path=None):
    print('')
    gdb =  '/home/ggrl/geodatabase/'
    print(f' Diretório raíz: {gdb}')
    
    if path:
        gdb += path
        print(f' Diretório do Banco de Dados: {gdb}')
        
    return gdb  
# --------------------------------------------------------------------------    

def import_vector(layer=None):
    print('')
    layer = gpd.read_file(set_gdb('geodatabase.gpkg'), layer=layer)
    
    return layer
# --------------------------------------------------------------------------

# %%
malha_cartor_1kk_wgs84 = import_vector('malha_cartog_1kk_wgs84')
# Out:
#  Diretório raíz: /home/ggrl/geodatabase/
#  Diretório do Banco de Dados: /home/ggrl/geodatabase/geodatabase.gpkg

# %%
malha_cartor_1kk_wgs84.head()
# Out:
#    left  top  right  bottom id_folha  \
# 0 -78.0 -4.0  -72.0    -8.0     SB18
# 1 -78.0 -8.0  -72.0   -12.0     SC18
# 2 -72.0  4.0  -66.0     0.0     NA19
# 3 -72.0  0.0  -66.0    -4.0     SA19
# 4 -72.0 -4.0  -66.0    -8.0     SB19
#
#                                             geometry
# 0  POLYGON ((-78.00000 -4.00000, -72.00000 -4.000...
# 1  POLYGON ((-78.00000 -8.00000, -72.00000 -8.000...
# 2  POLYGON ((-72.00000 4.00000, -66.00000 4.00000...
# 3  POLYGON ((-72.00000 0.00000, -66.00000 0.00000...
# 4  POLYGON ((-72.00000 -4.00000, -66.00000 -4.000...

# %%
def plot_layer(gdf=None,column=None,color=None,edgecolor=None,title=None):
    print('')
    fig, ax = plt.subplots(1, 1)
    
    gdf.plot(column=column,ax=ax, legend=True,color=color,edgecolor=edgecolor,
             legend_kwds={'loc': 'center left',
                          'bbox_to_anchor':(1,0.5),
                          'title': title})

# %%
area = malha_cartor_1kk_wgs84.cx[-50:,-25:-20]

plot_layer(area,column='id_folha',edgecolor='black',title='ID da Folha Cartográfica')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Litologia

# %%
litologia_1kk = import_vector('litologia_1kk')
# Out:
#  Diretório raíz: /home/ggrl/geodatabase/
#  Diretório do Banco de Dados: /home/ggrl/geodatabase/geodatabase.gpkg

# %%
litologia_1kk.head()
# Out:
#    ID_UNIDADE SIGLA HIERARQUIA                       NOME  \
# 0        1506   Q1t    Unidade  Unidade Terraços fluviais
# 1        2054  K2ra   Formação          Formação Rio Azul
# 2         214  N12s   Formação          Formação Solimões
# 3        1506   Q1t    Unidade  Unidade Terraços fluviais
# 4         214  N12s   Formação          Formação Solimões
#
#               AMBIENTE_T                        SUB_AMBIEN SIGLA_PAI NOME_PAI  \
# 0  Cobertura superficial  Cobertura transportada(Clástica)     Vazio    Vazio
# 1                  Vazio                             Vazio     Vazio    Vazio
# 2                  Vazio                             Vazio     Vazio    Vazio
# 3  Cobertura superficial  Cobertura transportada(Clástica)     Vazio    Vazio
# 4                  Vazio                             Vazio     Vazio    Vazio
#
#                                              LEGENDA       ESCALA  ...  \
# 0  Correspondem a amplos depósitos sedimentares c...  1:1.000.000  ...
# 1  Folhelho cinza a castanho e arenito fino com n...  1:1.000.000  ...
# 2  Sedimento pelítico, flúvio lacustre, contendo ...  1:1.000.000  ...
# 3  Correspondem a amplos depósitos sedimentares c...  1:1.000.000  ...
# 4  Sedimento pelítico, flúvio lacustre, contendo ...  1:1.000.000  ...
#
#      ERA_MIN    ERA_MAX SISTEMA_MI  SISTEMA_MA  EPOCA_MIN EPOCA_MAX  \
# 0  Cenozóico  Cenozóico    Neogeno     Neogeno   Superior  Superior
# 1  Mesozóico  Mesozóico   Cretáceo    Cretáceo   Inferior  Inferior
# 2  Cenozóico  Cenozóico    Neogeno     Neogeno   Superior  Superior
# 3  Cenozóico  Cenozóico    Neogeno     Neogeno   Superior  Superior
# 4  Cenozóico  Cenozóico    Neogeno     Neogeno   Superior  Superior
#
#   SIGLAS_HIS SHAPE_AREA  SHAPE_LEN  \
# 0      Vazio   0.002355   0.326835
# 1      Vazio   0.005557   0.499255
# 2      E2N2s   0.276915   3.847330
# 3      Vazio   0.033780   1.492084
# 4      E2N2s   2.239930  16.631079
#
#                                             geometry
# 0  POLYGON ((-72.72785 -8.38730, -72.73120 -8.384...
# 1  POLYGON ((-73.73806 -7.33994, -73.73616 -7.343...
# 2  MULTIPOLYGON (((-72.00000 -8.00000, -72.03095 ...
# 3  POLYGON ((-72.00000 -7.25284, -72.00048 -7.253...
# 4  POLYGON ((-68.99004 -8.79511, -68.98310 -8.798...
#
# [5 rows x 27 columns]

# %%
def metadataframe(GeoDataFrame):
    '''
    Recebe : 
        GeoDataFrame Object : Camadas vetoriais de unidades litoestratigráficas;
        
        Retorna :
            DataFrame Object: Planílha com metanálise das camadas vetoriais;
    '''
    print(f'# -- Gerando MetaDataFrame Litoestratigráfico')
    type_dataframe = pd.DataFrame(GeoDataFrame.dtypes)               # Describe the dtype of each column from the DataFrame or, better saying, GeoDataFrame;

    type_dataframe['Valores null']   = GeoDataFrame.isnull().sum()   # Describe the sum of each null value from our object
    type_dataframe['Valores unicos'] = GeoDataFrame.nunique()        # Describe the number of unique values from our object, that is a GeoDataFrame

    meta_dataframe_litologico = type_dataframe.rename(columns = {0 : 'dType'})       # Rename the first column to 'dtype', the name of the function we used.

    print('')
    
    return meta_dataframe_litologico

# %%
metadataframe(litologia_1kk)
# Out:
# # -- Gerando MetaDataFrame Litoestratigráfico
#                dType  Valores null  Valores unicos
# ID_UNIDADE     int64             0            2334
# SIGLA         object             0            2334
# HIERARQUIA    object             0              30
# NOME          object             0            2299
# AMBIENTE_T    object             0              10
# SUB_AMBIEN    object             0              29
# SIGLA_PAI     object             0             381
# NOME_PAI      object             0             381
# LEGENDA       object             0            2096
# ESCALA        object             0               1
# MAPA          object             0              45
# LITOTIPOS     object             0            1637
# RANGE         object             0             112
# IDADE_MIN      int64             0              43
# IDADE_MAX      int64             0              44
# EON_MIN       object             0               3
# EON_MAX       object             0               3
# ERA_MIN       object             0               9
# ERA_MAX       object             0              10
# SISTEMA_MI    object             0              22
# SISTEMA_MA    object             0              22
# EPOCA_MIN     object             0              16
# EPOCA_MAX     object             0              16
# SIGLAS_HIS    object             0            1104
# SHAPE_AREA   float64             0           46705
# SHAPE_LEN    float64             0           46705
# geometry    geometry             0           46705

# %%
litotipos_grafitosos_1kk = litologia_1kk[litologia_1kk['LITOTIPOS'].str.contains('graf')]

print(metadataframe(litotipos_grafitosos_1kk))

plot_layer(litotipos_grafitosos_1kk,'LITOTIPOS')
# Out:
# # -- Gerando MetaDataFrame Litoestratigráfico
#
#                dType  Valores null  Valores unicos
# ID_UNIDADE     int64             0               5
# SIGLA         object             0               5
# HIERARQUIA    object             0               4
# NOME          object             0               5
# AMBIENTE_T    object             0               2
# SUB_AMBIEN    object             0               1
# SIGLA_PAI     object             0               4
# NOME_PAI      object             0               4
# LEGENDA       object             0               5
# ESCALA        object             0               1
# MAPA          object             0               5
# LITOTIPOS     object             0               5
# RANGE         object             0               5
# IDADE_MIN      int64             0               5
# IDADE_MAX      int64             0               5
# EON_MIN       object             0               2
# EON_MAX       object             0               2
# ERA_MIN       object             0               4
# ERA_MAX       object             0               4
# SISTEMA_MI    object             0               4
# SISTEMA_MA    object             0               4
# EPOCA_MIN     object             0               4
# EPOCA_MAX     object             0               4
# SIGLAS_HIS    object             0               3
# SHAPE_AREA   float64             0              29
# SHAPE_LEN    float64             0              29
# geometry    geometry             0              29
# /tmp/ipykernel_22559/782487168.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(1, 1)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
legenda_grafitosa_1kk = litologia_1kk[litologia_1kk['LEGENDA'].str.contains('graf')]
print(metadataframe(legenda_grafitosa_1kk))

plot_layer(legenda_grafitosa_1kk,'LEGENDA')
# Out:
# # -- Gerando MetaDataFrame Litoestratigráfico
#
#                dType  Valores null  Valores unicos
# ID_UNIDADE     int64             0              70
# SIGLA         object             0              70
# HIERARQUIA    object             0              10
# NOME          object             0              70
# AMBIENTE_T    object             0               2
# SUB_AMBIEN    object             0               1
# SIGLA_PAI     object             0              30
# NOME_PAI      object             0              30
# LEGENDA       object             0              70
# ESCALA        object             0               1
# MAPA          object             0              19
# LITOTIPOS     object             0              70
# RANGE         object             0              23
# IDADE_MIN      int64             0              13
# IDADE_MAX      int64             0              14
# EON_MIN       object             0               3
# EON_MAX       object             0               3
# ERA_MIN       object             0               6
# ERA_MAX       object             0               8
# SISTEMA_MI    object             0              11
# SISTEMA_MA    object             0              10
# EPOCA_MIN     object             0              10
# EPOCA_MAX     object             0               9
# SIGLAS_HIS    object             0              32
# SHAPE_AREA   float64             0            1093
# SHAPE_LEN    float64             0            1093
# geometry    geometry             0            1093
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
litotipos_grafita_xisto_1kk = litologia_1kk[litologia_1kk['LITOTIPOS'].str.contains('Graf')]

print(metadataframe(litotipos_grafita_xisto_1kk))

litotipos_grafita_xisto_1kk.plot('LITOTIPOS')
# Out:
# # -- Gerando MetaDataFrame Litoestratigráfico
#
#                dType  Valores null  Valores unicos
# ID_UNIDADE     int64             0              29
# SIGLA         object             0              29
# HIERARQUIA    object             0               7
# NOME          object             0              28
# AMBIENTE_T    object             0               2
# SUB_AMBIEN    object             0               2
# SIGLA_PAI     object             0              17
# NOME_PAI      object             0              17
# LEGENDA       object             0              29
# ESCALA        object             0               1
# MAPA          object             0              14
# LITOTIPOS     object             0              29
# RANGE         object             0              14
# IDADE_MIN      int64             0              10
# IDADE_MAX      int64             0              11
# EON_MIN       object             0               2
# EON_MAX       object             0               2
# ERA_MIN       object             0               5
# ERA_MAX       object             0               6
# SISTEMA_MI    object             0               9
# SISTEMA_MA    object             0               9
# EPOCA_MIN     object             0               9
# EPOCA_MAX     object             0               9
# SIGLAS_HIS    object             0              15
# SHAPE_AREA   float64             0             380
# SHAPE_LEN    float64             0             380
# geometry    geometry             0             380
# <AxesSubplot:>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
legenda_grafita_xisto_1kk = litologia_1kk[litologia_1kk['LEGENDA'].str.contains('Graf')]
print(metadataframe(legenda_grafita_xisto_1kk))
legenda_grafita_xisto_1kk.plot('SIGLA')
# Out:
# # -- Gerando MetaDataFrame Litoestratigráfico
#
#                dType  Valores null  Valores unicos
# ID_UNIDADE     int64             0               4
# SIGLA         object             0               4
# HIERARQUIA    object             0               3
# NOME          object             0               4
# AMBIENTE_T    object             0               2
# SUB_AMBIEN    object             0               1
# SIGLA_PAI     object             0               1
# NOME_PAI      object             0               1
# LEGENDA       object             0               4
# ESCALA        object             0               1
# MAPA          object             0               3
# LITOTIPOS     object             0               4
# RANGE         object             0               4
# IDADE_MIN      int64             0               4
# IDADE_MAX      int64             0               4
# EON_MIN       object             0               2
# EON_MAX       object             0               2
# ERA_MIN       object             0               3
# ERA_MAX       object             0               3
# SISTEMA_MI    object             0               3
# SISTEMA_MA    object             0               3
# EPOCA_MIN     object             0               3
# EPOCA_MAX     object             0               3
# SIGLAS_HIS    object             0               1
# SHAPE_AREA   float64             0               5
# SHAPE_LEN    float64             0               5
# geometry    geometry             0               5
# <AxesSubplot:>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
malha_cartog_250k = import_vector('malha_cartog_250k_wgs84')
SF23_250k = malha_cartog_250k[malha_cartog_250k['id_folha'].str.contains('SF23')]
# Out:
#  Diretório raíz: /home/ggrl/geodatabase/
#  Diretório do Banco de Dados: /home/ggrl/geodatabase/geodatabase.gpkg

# %%
SF23_250k
# Out:
#     id_folha                                           geometry
# 415  SF23_VA  POLYGON ((-48.00000 -20.00000, -46.50000 -20.0...
# 416  SF23_VC  POLYGON ((-48.00000 -21.00000, -46.50000 -21.0...
# 417  SF23_YA  POLYGON ((-48.00000 -22.00000, -46.50000 -22.0...
# 418  SF23_YC  POLYGON ((-48.00000 -23.00000, -46.50000 -23.0...
# 441  SF23_VB  POLYGON ((-46.50000 -20.00000, -45.00000 -20.0...
# 442  SF23_VD  POLYGON ((-46.50000 -21.00000, -45.00000 -21.0...
# 443  SF23_YB  POLYGON ((-46.50000 -22.00000, -45.00000 -22.0...
# 444  SF23_YD  POLYGON ((-46.50000 -23.00000, -45.00000 -23.0...
# 465  SF23_XA  POLYGON ((-45.00000 -20.00000, -43.50000 -20.0...
# 466  SF23_XC  POLYGON ((-45.00000 -21.00000, -43.50000 -21.0...
# 467  SF23_ZA  POLYGON ((-45.00000 -22.00000, -43.50000 -22.0...
# 468  SF23_ZC  POLYGON ((-45.00000 -23.00000, -43.50000 -23.0...
# 487  SF23_XB  POLYGON ((-43.50000 -20.00000, -42.00000 -20.0...
# 488  SF23_XD  POLYGON ((-43.50000 -21.00000, -42.00000 -21.0...
# 489  SF23_ZB  POLYGON ((-43.50000 -22.00000, -42.00000 -22.0...
# 490  SF23_ZD  POLYGON ((-43.50000 -23.00000, -42.00000 -23.0...

# %%
type(litologia_1kk)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
base = litologia_1kk.plot('LITOTIPOS',alpha=.5)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
SF23_250k.boundary.plot(ax=base,color='black')
litotipos_grafitosos_1kk.plot(ax=base,color='red')
# Out:
# <AxesSubplot:>

# %%
SF23_VC = SF23_250k[SF23_250k['id_folha'].str.contains('SF23_VD')]

SF23_VC.plot(ax=base,color='Red')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Aerogefísica

# %% [markdown]
# ## Gamaespectrometria

# %%
def import_xyz():
    xyz = pd.read_csv(set_gdb('geof/gama_3022'))
    return xyz

# %%
gama_3022 = import_xyz()
# Out:
#  Diretório raíz: /home/ggrl/geodatabase/
#  Diretório do Banco de Dados: /home/ggrl/geodatabase/geof/gama_3022

# %%
gama_3022
# Out:
#          CTCOR  eTh   eU  KPERC   LATITUDE  LONGITUDE      MDT  THKRAZAO  \
# 0       644.27  6.9 -0.1  0.791 -21.236695 -47.054024   699.38     8.721
# 1       577.39  6.5 -0.1  0.681 -21.237383 -47.054043   697.18     9.596
# 2       520.33  5.9 -0.1  0.587 -21.238073 -47.054056   707.69    10.073
# 3       494.39  5.3  0.1  0.566 -21.238763 -47.054064   721.80     9.327
# 4       502.44  4.8  0.2  0.634 -21.239452 -47.054070   727.61     7.511
# ...        ...  ...  ...    ...        ...        ...      ...       ...
# 676761  -21.96  0.7 -0.7  0.129 -21.069341 -44.001161  1067.13     6.260
# 676762   10.95  1.0 -0.7  0.127 -21.069324 -44.000478  1058.53     7.817
# 676763   19.16  1.1 -0.6  0.129 -21.069300 -43.999797  1065.43     8.257
# 676764    1.20  0.8 -0.7  0.144 -21.069277 -43.999119  1087.47     5.798
# 676765  -12.08  0.8 -0.8  0.150 -21.069256 -43.998441  1119.46     5.481
#
#         UKRAZAO  UTHRAZAO          X           Y
# 0         0.027     0.003  286856.47  7650282.76
# 1         0.031     0.003  286855.49  7650206.55
# 2         0.036     0.004  286855.13  7650130.13
# 3         0.102     0.011  286855.29  7650053.72
# 4         0.289     0.039  286855.66  7649977.42
# ...         ...       ...        ...         ...
# 676761    0.163     0.026  603787.96  7669863.86
# 676762    0.165     0.021  603858.93  7669865.29
# 676763    0.163     0.020  603929.70  7669867.51
# 676764    0.146     0.025  604000.15  7669869.61
# 676765    0.140     0.026  604070.60  7669871.49
#
# [676766 rows x 12 columns]

# %%
metadataframe(mag_3022)
# Out:
# # -- Gerando MetaDataFrame Litoestratigráfico
#             dType  Valores null  Valores unicos
# ALTURA    float64             0           31988
# LAT_WGS   float64             0          850621
# LONG_WGS  float64             0         1868567
# MAGIGRF   float64             0          467041
# MDT       float64             0           98536
# X         float64             0         3323262
# Y         float64             0         4571897

# %%
gama_3022.describe(percentiles=(0.05,0.1,0.25,0.5,0.75,0.995)).T
# Out:
#               count          mean           std           min            5%  \
# CTCOR      676766.0  1.266228e+03   1345.323409 -1.183413e+04  3.387700e+02
# eTh        676766.0  1.622140e+01     18.263838 -3.800000e+00  4.300000e+00
# eU         676766.0  4.368665e-01      2.349440 -1.293000e+02 -6.000000e-01
# KPERC      676766.0  6.441879e-01      0.815783 -1.493230e+02 -2.300000e-02
# LATITUDE   676766.0 -2.159738e+01      0.223295 -2.216498e+01 -2.194555e+01
# LONGITUDE  676766.0 -4.540110e+01      0.813880 -4.706219e+01 -4.661301e+01
# MDT        676766.0  9.778592e+02    140.620854  4.327700e+02  7.887925e+02
# THKRAZAO   676766.0  1.159785e+02    424.811990  1.550000e-01  5.507000e+00
# UKRAZAO    676766.0  3.012281e+00     53.502275  2.000000e-03  1.600000e-02
# UTHRAZAO   676766.0  3.402377e-02      0.047602  0.000000e+00  1.000000e-03
# X          676766.0  4.584988e+05  84274.017007  2.860137e+05  3.328798e+05
# Y          676766.0  7.611474e+06  24671.727380  7.548586e+06  7.572968e+06
#
#                     10%           25%           50%           75%  \
# CTCOR      4.827200e+02  7.434300e+02  1.079810e+03  1.482310e+03
# eTh        6.000000e+00  9.100000e+00  1.310000e+01  1.870000e+01
# eU        -4.000000e-01 -1.000000e-01  2.000000e-01  7.000000e-01
# KPERC      2.500000e-02  1.310000e-01  3.670000e-01  8.800000e-01
# LATITUDE  -2.190493e+01 -2.179197e+01 -2.159652e+01 -2.140558e+01
# LONGITUDE -4.646669e+01 -4.608319e+01 -4.544705e+01 -4.469730e+01
# MDT        8.185800e+02  8.760300e+02  9.601200e+02  1.056830e+03
# THKRAZAO   7.695000e+00  1.406600e+01  3.287200e+01  1.025078e+02
# UKRAZAO    2.800000e-02  1.090000e-01  6.630000e-01  2.189000e+00
# UTHRAZAO   1.000000e-03  3.000000e-03  1.900000e-02  4.900000e-02
# X          3.483517e+05  3.878714e+05  4.538525e+05  5.313625e+05
# Y          7.577465e+06  7.589901e+06  7.611622e+06  7.632632e+06
#
#                   99.5%           max
# CTCOR      7.197699e+03  4.508950e+05
# eTh        9.730000e+01  6.371400e+03
# eU         7.600000e+00  9.348000e+02
# KPERC      4.213000e+00  2.428600e+01
# LATITUDE  -2.110921e+01 -2.098995e+01
# LONGITUDE -4.400427e+01 -4.398910e+01
# MDT        1.416460e+03  1.782280e+03
# THKRAZAO   1.326767e+03  2.055291e+05
# UKRAZAO    4.619223e+01  3.015609e+04
# UTHRAZAO   2.610000e-01  2.807000e+00
# X          6.030622e+05  6.043273e+05
# Y          7.665505e+06  7.678651e+06

# %% [markdown]
# ### Removendo valores negativos na gamaespectrometria

# %%
df=gama_3022

# %%
df['K_pos'] = df['KPERC'] - df['KPERC'].min() + 0.01
df['eU_pos'] = df['eU'] - df['eU'].min() + 0.01
df['eTh_pos'] = df['eTh'] - df['eTh'].min() + 0.01

#excluindo os canais originais
df.drop(['KPERC','eU','eTh'], axis =1, inplace = True)

#renomeando os positivos para os nomes dos originais
df.rename(columns={'K_pos':'K','eU_pos':'eU','eTh_pos':'eTh','LATITUDE':'LAT_WGS','LONGITUDE':'LONG_WGS'}, inplace=True)
#df = df[['ASA', 'CT', 'eTh','eU','K','MDT','X','Y']] #organizando para ficar como os anteriores
df.describe().T
# Out:
#              count          mean           std           min           25%  \
# CTCOR     676766.0  1.266228e+03   1345.323409 -1.183413e+04  7.434300e+02
# THKRAZAO  676766.0  1.159785e+02    424.811990  1.550000e-01  1.406600e+01
# UKRAZAO   676766.0  3.012281e+00     53.502275  2.000000e-03  1.090000e-01
# UTHRAZAO  676766.0  3.402377e-02      0.047602  0.000000e+00  3.000000e-03
# X         676766.0  4.584988e+05  84274.017007  2.860137e+05  3.878714e+05
# Y         676766.0  7.611474e+06  24671.727380  7.548586e+06  7.589901e+06
# LAT_WGS   676766.0 -2.159738e+01      0.223295 -2.216498e+01 -2.179197e+01
# LONG_WGS  676766.0 -4.540110e+01      0.813880 -4.706219e+01 -4.608319e+01
# K         676766.0  1.499772e+02      0.815783  1.000000e-02  1.494640e+02
# eU        676766.0  1.297469e+02      2.349440  1.000000e-02  1.292100e+02
# eTh       676766.0  2.003140e+01     18.263838  1.000000e-02  1.291000e+01
#
#                    50%           75%           max
# CTCOR     1.079810e+03  1.482310e+03  4.508950e+05
# THKRAZAO  3.287200e+01  1.025078e+02  2.055291e+05
# UKRAZAO   6.630000e-01  2.189000e+00  3.015609e+04
# UTHRAZAO  1.900000e-02  4.900000e-02  2.807000e+00
# X         4.538525e+05  5.313625e+05  6.043273e+05
# Y         7.611622e+06  7.632632e+06  7.678651e+06
# LAT_WGS  -2.159652e+01 -2.140558e+01 -2.098995e+01
# LONG_WGS -4.544705e+01 -4.469730e+01 -4.398910e+01
# K         1.497000e+02  1.502130e+02  1.736190e+02
# eU        1.295100e+02  1.300100e+02  1.064110e+03
# eTh       1.691000e+01  2.251000e+01  6.375210e+03

# %%
df = df[['CTCOR','K','eU','eTh','THKRAZAO','UKRAZAO','UTHRAZAO','X','Y','LAT_WGS','LONG_WGS']]
df.head()
# Out:
#     CTCOR        K      eU    eTh  THKRAZAO  UKRAZAO  UTHRAZAO          X  \
# 0  644.27  150.124  129.21  10.71     8.721    0.027     0.003  286856.47
# 1  577.39  150.014  129.21  10.31     9.596    0.031     0.003  286855.49
# 2  520.33  149.920  129.21   9.71    10.073    0.036     0.004  286855.13
# 3  494.39  149.899  129.41   9.11     9.327    0.102     0.011  286855.29
# 4  502.44  149.967  129.51   8.61     7.511    0.289     0.039  286855.66
#
#             Y    LAT_WGS   LONG_WGS
# 0  7650282.76 -21.236695 -47.054024
# 1  7650206.55 -21.237383 -47.054043
# 2  7650130.13 -21.238073 -47.054056
# 3  7650053.72 -21.238763 -47.054064
# 4  7649977.42 -21.239452 -47.054070

# %%
df['KeTh'] = df.K/df.eTh
df['eUeTh'] = df.eU/df.eTh
df['FF'] = df.K * df.eU / df.eTh
# Out:
# /tmp/ipykernel_43986/3544881874.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['KeTh'] = df.K/df.eTh
# /tmp/ipykernel_43986/3544881874.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['eUeTh'] = df.eU/df.eTh
# /tmp/ipykernel_43986/3544881874.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FF'] = df.K * df.eU / df.eTh

# %%
df.describe(percentiles=(0.05,0.1,0.25,0.5,0.75,0.995)).T
# Out:
#              count          mean           std           min            5%  \
# CTCOR     676766.0  1.266228e+03   1345.323409 -1.183413e+04  3.387700e+02
# K         676766.0  1.499772e+02      0.815783  1.000000e-02  1.493100e+02
# eU        676766.0  1.297469e+02      2.349440  1.000000e-02  1.287100e+02
# eTh       676766.0  2.003140e+01     18.263838  1.000000e-02  8.110000e+00
# THKRAZAO  676766.0  1.159785e+02    424.811990  1.550000e-01  5.507000e+00
# UKRAZAO   676766.0  3.012281e+00     53.502275  2.000000e-03  1.600000e-02
# UTHRAZAO  676766.0  3.402377e-02      0.047602  0.000000e+00  1.000000e-03
# X         676766.0  4.584988e+05  84274.017007  2.860137e+05  3.328798e+05
# Y         676766.0  7.611474e+06  24671.727380  7.548586e+06  7.572968e+06
# LAT_WGS   676766.0 -2.159738e+01      0.223295 -2.216498e+01 -2.194555e+01
# LONG_WGS  676766.0 -4.540110e+01      0.813880 -4.706219e+01 -4.661301e+01
# KeTh      676766.0  9.801284e+00     26.249034  1.568576e-06  3.553708e+00
# eUeTh     676766.0  8.469597e+00     22.605871  4.405092e-05  3.079887e+00
# FF        676766.0  1.269760e+03   3376.113216  1.614080e-03  4.624191e+02
#
#                    10%           25%           50%           75%  \
# CTCOR     4.827200e+02  7.434300e+02  1.079810e+03  1.482310e+03
# K         1.493580e+02  1.494640e+02  1.497000e+02  1.502130e+02
# eU        1.289100e+02  1.292100e+02  1.295100e+02  1.300100e+02
# eTh       9.810000e+00  1.291000e+01  1.691000e+01  2.251000e+01
# THKRAZAO  7.695000e+00  1.406600e+01  3.287200e+01  1.025078e+02
# UKRAZAO   2.800000e-02  1.090000e-01  6.630000e-01  2.189000e+00
# UTHRAZAO  1.000000e-03  3.000000e-03  1.900000e-02  4.900000e-02
# X         3.483517e+05  3.878714e+05  4.538525e+05  5.313625e+05
# Y         7.577465e+06  7.589901e+06  7.611622e+06  7.632632e+06
# LAT_WGS  -2.190493e+01 -2.179197e+01 -2.159652e+01 -2.140558e+01
# LONG_WGS -4.646669e+01 -4.608319e+01 -4.544705e+01 -4.469730e+01
# KeTh      4.731143e+00  6.668496e+00  8.891493e+00  1.160021e+01
# eUeTh     4.097121e+00  5.767802e+00  7.686496e+00  1.002401e+01
# FF        6.140609e+02  8.650776e+02  1.153458e+03  1.503495e+03
#
#                  99.5%           max
# CTCOR     7.197699e+03  4.508950e+05
# K         1.535460e+02  1.736190e+02
# eU        1.369100e+02  1.064110e+03
# eTh       1.011100e+02  6.375210e+03
# THKRAZAO  1.326767e+03  2.055291e+05
# UKRAZAO   4.619223e+01  3.015609e+04
# UTHRAZAO  2.610000e-01  2.807000e+00
# X         6.030622e+05  6.043273e+05
# Y         7.665505e+06  7.678651e+06
# LAT_WGS  -2.110921e+01 -2.098995e+01
# LONG_WGS -4.400427e+01 -4.398910e+01
# KeTh      3.634623e+01  1.493500e+04
# eUeTh     3.143796e+01  1.286100e+04
# FF        4.694284e+03  1.920790e+06

# %%
df.shape
# Out:
# (676766, 14)

# %%
import verde as vd

# %%
vd.get_region()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_43986/3135577827.py in <module>
# ----> 1 vd.get_region()
#
# TypeError: get_region() missing 1 required positional argument: 'coordinates'

# %% [markdown]
# ## Magnetometria

# %%
mag_3022 = pd.read_csv(set_gdb('geof/mag_3022'))
# Out:
#  Diretório raíz: /home/ggrl/geodatabase/
#  Diretório do Banco de Dados: /home/ggrl/geodatabase/geof/mag_3022

# %%
mag_3022
# Out:
#          ALTURA    LAT_WGS   LONG_WGS  MAGIGRF      MDT          X           Y
# 0        173.71 -21.236695 -47.054024  114.455   699.38  286856.47  7650282.78
# 1        174.45 -21.236764 -47.054026  114.657   698.16  286856.37  7650275.15
# 2        174.52 -21.236833 -47.054028  114.859   697.60  286856.27  7650267.53
# 3        175.07 -21.236901 -47.054030  115.041   696.56  286856.17  7650259.90
# 4        175.26 -21.236970 -47.054032  115.213   695.89  286856.08  7650252.27
# ...         ...        ...        ...      ...      ...        ...         ...
# 6760539  102.57 -21.069265 -43.998712   17.757  1106.07  604042.42  7669870.71
# 6760540  100.54 -21.069263 -43.998644   17.668  1108.44  604049.47  7669870.89
# 6760541   97.02 -21.069261 -43.998576   17.589  1112.29  604056.51  7669871.08
# 6760542   94.14 -21.069258 -43.998509   17.501  1115.51  604063.56  7669871.26
# 6760543   90.52 -21.069256 -43.998441   17.402  1119.46  604070.60  7669871.44
#
# [6760544 rows x 7 columns]

# %%
metadataframe(mag_3022)
# Out:
# # -- Gerando MetaDataFrame Litoestratigráfico
#             dType  Valores null  Valores unicos
# ALTURA    float64             0           31988
# LAT_WGS   float64             0          850621
# LONG_WGS  float64             0         1868567
# MAGIGRF   float64             0          467041
# MDT       float64             0           98536
# X         float64             0         3323262
# Y         float64             0         4571897
